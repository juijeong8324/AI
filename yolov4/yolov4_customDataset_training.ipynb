# %% [markdown]
# <a href="https://colab.research.google.com/github/juijeong8324/AI/blob/ubuntu/yolov4/yolov4_customDataset_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Aug 26 12:00:07 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # YOLO v4모델로 colab에서 객체인식(Object detection)

# %% [markdown]
# ### YOLOv3또는 Yolov4모델을 데이터로 학습 시킬 때는 보통 GPU가 내장된 컴퓨터로 진행을 많이 한다. 그러나, GPU가 내장된 PC가 없다고 딥러닝 모델을 학습하지 못할까? Colab으로도 이와같은 학습이 가능하다.(기왕이면 조금 금액을 지불하더라도 Colab Pro로 진행하는 것을 권장한다.)
#
# **실행 환경**
# **1. colab (Pro)**
# **2. darknet(tensorflow나 pytorch와 같은 딥러닝 프레임워크)**
# **3. YOLO v4 (딥러닝 모델)**
#
#
# 참고로 아래와 같이 진행할 경우 YOLO v3모델도 이와같이 실행할 수 있다.

# %% [markdown]
# ### 이 내용을 설명하는 관련 참조 글의 링크는 다음과 같다.
#  (https://medium.com/@techzizou007/training-a-custom-detector-for-mask-detection-using-yolov4-darknet-61a659d4868)

# %% [markdown]
# ### 1. Colab Runtime메뉴에서 Change runtime type을 선택한다.
# ### 2. hardware accelator로 GPU를 선택한다.

# %% [markdown]
# ### 구글 드라이브 마운트

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/drive')
# Out:
# /
# Mounted at /content/drive

# %%
import os 

path = "/content/drive/MyDrive/Advanced_AI/yolov4"
#만약에 path로 설정된 폴더가 존재하지 않으면
if not os.path.isdir(path):                                                           
    os.mkdir(path)
    print('mkdir'+path)
else:
    print('이미 폴더가 존재합니다.')
# Out:
# 이미 폴더가 존재합니다.

# %%
# 아래 PATH는 WEIGHT파일을 저장할 폴더이다.
path = "/content/drive/MyDrive/Advanced_AI/yolov4/training"
if not os.path.isdir(path):                                                           
    os.mkdir(path)
    print('mkdir'+path)
else:
    print('이미 폴더가 존재합니다.')
# Out:
# 이미 폴더가 존재합니다.

# %% [markdown]
# ### 구글 드라이브의 경로를 간단하게 접근하기 위해 /mydrive로 심볼릭 링크를 설정한다.

# %%
# 리눅스에서 SOFT LINK는 바로가기 아이콘과 같은 폴더를 생성
# !ln -s /content/drive/MyDrive/ /mydrive

# %%
# 현재 WORKING디렉토리를 아래 폴더로 이동
# %cd /mydrive/Advanced_AI/yolov4
# Out:
# /content/drive/MyDrive/Advanced_AI/yolov4

# %%
# 현재 내가 작업하는 working dir가 어디인지 확인
# 리눅스 티미널 명령
# !pwd
# Out:
# /content/drive/MyDrive/Advanced_AI/yolov4

# %%
path = '/mydrive/Advanced_AI/yolov4/darknet'
if not os.path.isdir(path):
    # yolo v4의 github에서 소스코드를 복제(다운로드), 나의 구글 드라이브에...
    # !git clone https://github.com/AlexeyAB/darknet
    print('git clone is done!')
else:
    print("이미 git으로부터 파일을 다운로드 했습니다")
# Out:
# 이미 git으로부터 파일을 다운로드 했습니다

# %%
# %cd /mydrive/Advanced_AI/yolov4/darknet/
# Out:
# /content/drive/MyDrive/Advanced_AI/yolov4/darknet

# %%
# !ls
# Out:
# 3rdparty		 darknet_video.py	predictions.jpg
# backup			 data			process.py
# build			 image_yolov3.sh	__pycache__
# build.ps1		 image_yolov4.sh	README.md
# cfg			 include		results
# chart.png		 json_mjpeg_streams.sh	scripts
# chart_yolov4-custom.png  libdarknet.so		src
# cmake			 LICENSE		uselib
# CMakeLists.txt		 Makefile		vcpkg.json
# darknet			 net_cam_v3.sh		video_yolov3.sh
# DarknetConfig.cmake.in	 net_cam_v4.sh		video_yolov4.sh
# darknet_images.py	 obj			weights
# darknet.py		 photo.jpg		yolov4.conv.137

# %% [markdown]
# ### Makefile의 내용을 수정합니다.

# %%
# %cd /mydrive/Advanced_AI/yolov4/
# Out:
# /content/drive/MyDrive/Advanced_AI/yolov4

# %%
# GPU가 있으면... Makefile을 아래와 같이 수정
# %cd darknet/
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile
# !sed -i 's/LIBSO=0/LIBSO=1/' Makefile
# Out:
# /content/drive/My Drive/Advanced_AI/yolov4/darknet

# %%
# 문서 파일의 내용을 화면에 직접 출력
# !cat Makefile
# Out:
# GPU=1
# CUDNN=1
# CUDNN_HALF=1
# OPENCV=1
# AVX=0
# OPENMP=0
# LIBSO=1
# ZED_CAMERA=0
# ZED_CAMERA_v2_8=0
#
# # set GPU=1 and CUDNN=1 to speedup on GPU
# # set CUDNN_HALF=1 to further speedup 3 x times (Mixed-precision on Tensor Cores) GPU: Volta, Xavier, Turing and higher
# # set AVX=1 and OPENMP=1 to speedup on CPU (if error occurs then set AVX=0)
# # set ZED_CAMERA=1 to enable ZED SDK 3.0 and above
# # set ZED_CAMERA_v2_8=1 to enable ZED SDK 2.X
#
# USE_CPP=0
# DEBUG=0
#
# ARCH= -gencode arch=compute_35,code=sm_35 \
#       -gencode arch=compute_50,code=[sm_50,compute_50] \
#       -gencode arch=compute_52,code=[sm_52,compute_52] \
# 	    -gencode arch=compute_61,code=[sm_61,compute_61]
#
# OS := $(shell uname)
#
# # GeForce RTX 3070, 3080, 3090
# # ARCH= -gencode arch=compute_86,code=[sm_86,compute_86]
#
# # Kepler GeForce GTX 770, GTX 760, GT 740
# # ARCH= -gencode arch=compute_30,code=sm_30
#
# # Tesla A100 (GA100), DGX-A100, RTX 3080
# # ARCH= -gencode arch=compute_80,code=[sm_80,compute_80]
#
# # Tesla V100
# # ARCH= -gencode arch=compute_70,code=[sm_70,compute_70]
#
# # GeForce RTX 2080 Ti, RTX 2080, RTX 2070, Quadro RTX 8000, Quadro RTX 6000, Quadro RTX 5000, Tesla T4, XNOR Tensor Cores
# # ARCH= -gencode arch=compute_75,code=[sm_75,compute_75]
#
# # Jetson XAVIER
# # ARCH= -gencode arch=compute_72,code=[sm_72,compute_72]
#
# # GTX 1080, GTX 1070, GTX 1060, GTX 1050, GTX 1030, Titan Xp, Tesla P40, Tesla P4
# # ARCH= -gencode arch=compute_61,code=sm_61 -gencode arch=compute_61,code=compute_61
#
# # GP100/Tesla P100 - DGX-1
# # ARCH= -gencode arch=compute_60,code=sm_60
#
# # For Jetson TX1, Tegra X1, DRIVE CX, DRIVE PX - uncomment:
# # ARCH= -gencode arch=compute_53,code=[sm_53,compute_53]
#
# # For Jetson Tx2 or Drive-PX2 uncomment:
# # ARCH= -gencode arch=compute_62,code=[sm_62,compute_62]
#
# # For Tesla GA10x cards, RTX 3090, RTX 3080, RTX 3070, RTX A6000, RTX A40 uncomment:
# # ARCH= -gencode arch=compute_86,code=[sm_86,compute_86]
#
#
# VPATH=./src/
# EXEC=darknet
# OBJDIR=./obj/
#
# ifeq ($(LIBSO), 1)
# LIBNAMESO=libdarknet.so
# APPNAMESO=uselib
# endif
#
# ifeq ($(USE_CPP), 1)
# CC=g++
# else
# CC=gcc
# endif
#
# CPP=g++ -std=c++11
# NVCC=nvcc
# OPTS=-Ofast
# LDFLAGS= -lm -pthread
# COMMON= -Iinclude/ -I3rdparty/stb/include
# CFLAGS=-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC
#
# ifeq ($(DEBUG), 1)
# #OPTS= -O0 -g
# #OPTS= -Og -g
# COMMON+= -DDEBUG
# CFLAGS+= -DDEBUG
# else
# ifeq ($(AVX), 1)
# CFLAGS+= -ffp-contract=fast -mavx -mavx2 -msse3 -msse4.1 -msse4.2 -msse4a
# endif
# endif
#
# CFLAGS+=$(OPTS)
#
# ifneq (,$(findstring MSYS_NT,$(OS)))
# LDFLAGS+=-lws2_32
# endif
#
# ifeq ($(OPENCV), 1)
# COMMON+= -DOPENCV
# CFLAGS+= -DOPENCV
# LDFLAGS+= `pkg-config --libs opencv 2> /dev/null || pkg-config --libs opencv`
# COMMON+= `pkg-config --cflags opencv 2> /dev/null || pkg-config --cflags opencv`
# endif
#
# ifeq ($(OPENMP), 1)
#     ifeq ($(OS),Darwin) #MAC
# 	    CFLAGS+= -Xpreprocessor -fopenmp
# 	else
# 		CFLAGS+= -fopenmp
# 	endif
# LDFLAGS+= -lgomp
# endif
#
# ifeq ($(GPU), 1)
# COMMON+= -DGPU -I/usr/local/cuda/include/
# CFLAGS+= -DGPU
# ifeq ($(OS),Darwin) #MAC
# LDFLAGS+= -L/usr/local/cuda/lib -lcuda -lcudart -lcublas -lcurand
# else
# LDFLAGS+= -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand
# endif
# endif
#
# ifeq ($(CUDNN), 1)
# COMMON+= -DCUDNN
# ifeq ($(OS),Darwin) #MAC
# CFLAGS+= -DCUDNN -I/usr/local/cuda/include
# LDFLAGS+= -L/usr/local/cuda/lib -lcudnn
# else
# CFLAGS+= -DCUDNN -I/usr/local/cudnn/include
# LDFLAGS+= -L/usr/local/cudnn/lib64 -lcudnn
# endif
# endif
#
# ifeq ($(CUDNN_HALF), 1)
# COMMON+= -DCUDNN_HALF
# CFLAGS+= -DCUDNN_HALF
# ARCH+= -gencode arch=compute_70,code=[sm_70,compute_70]
# endif
#
# ifeq ($(ZED_CAMERA), 1)
# CFLAGS+= -DZED_STEREO -I/usr/local/zed/include
# ifeq ($(ZED_CAMERA_v2_8), 1)
# LDFLAGS+= -L/usr/local/zed/lib -lsl_core -lsl_input -lsl_zed
# #-lstdc++ -D_GLIBCXX_USE_CXX11_ABI=0
# else
# LDFLAGS+= -L/usr/local/zed/lib -lsl_zed
# #-lstdc++ -D_GLIBCXX_USE_CXX11_ABI=0
# endif
# endif
#
# OBJ=image_opencv.o http_stream.o gemm.o utils.o dark_cuda.o convolutional_layer.o list.o image.o activations.o im2col.o col2im.o blas.o crop_layer.o dropout_layer.o maxpool_layer.o softmax_layer.o data.o matrix.o network.o connected_layer.o cost_layer.o parser.o option_list.o darknet.o detection_layer.o captcha.o route_layer.o writing.o box.o nightmare.o normalization_layer.o avgpool_layer.o coco.o dice.o yolo.o detector.o layer.o compare.o classifier.o local_layer.o swag.o shortcut_layer.o representation_layer.o activation_layer.o rnn_layer.o gru_layer.o rnn.o rnn_vid.o crnn_layer.o demo.o tag.o cifar.o go.o batchnorm_layer.o art.o region_layer.o reorg_layer.o reorg_old_layer.o super.o voxel.o tree.o yolo_layer.o gaussian_yolo_layer.o upsample_layer.o lstm_layer.o conv_lstm_layer.o scale_channels_layer.o sam_layer.o
# ifeq ($(GPU), 1)
# LDFLAGS+= -lstdc++
# OBJ+=convolutional_kernels.o activation_kernels.o im2col_kernels.o col2im_kernels.o blas_kernels.o crop_layer_kernels.o dropout_layer_kernels.o maxpool_layer_kernels.o network_kernels.o avgpool_layer_kernels.o
# endif
#
# OBJS = $(addprefix $(OBJDIR), $(OBJ))
# DEPS = $(wildcard src/*.h) Makefile include/darknet.h
#
# all: $(OBJDIR) backup results setchmod $(EXEC) $(LIBNAMESO) $(APPNAMESO)
#
# ifeq ($(LIBSO), 1)
# CFLAGS+= -fPIC
#
# $(LIBNAMESO): $(OBJDIR) $(OBJS) include/yolo_v2_class.hpp src/yolo_v2_class.cpp
# 	$(CPP) -shared -std=c++11 -fvisibility=hidden -DLIB_EXPORTS $(COMMON) $(CFLAGS) $(OBJS) src/yolo_v2_class.cpp -o $@ $(LDFLAGS)
#
# $(APPNAMESO): $(LIBNAMESO) include/yolo_v2_class.hpp src/yolo_console_dll.cpp
# 	$(CPP) -std=c++11 $(COMMON) $(CFLAGS) -o $@ src/yolo_console_dll.cpp $(LDFLAGS) -L ./ -l:$(LIBNAMESO)
# endif
#
# $(EXEC): $(OBJS)
# 	$(CPP) -std=c++11 $(COMMON) $(CFLAGS) $^ -o $@ $(LDFLAGS)
#
# $(OBJDIR)%.o: %.c $(DEPS)
# 	$(CC) $(COMMON) $(CFLAGS) -c $< -o $@
#
# $(OBJDIR)%.o: %.cpp $(DEPS)
# 	$(CPP) -std=c++11 $(COMMON) $(CFLAGS) -c $< -o $@
#
# $(OBJDIR)%.o: %.cu $(DEPS)
# 	$(NVCC) $(ARCH) $(COMMON) --compiler-options "$(CFLAGS)" -c $< -o $@
#
# $(OBJDIR):
# 	mkdir -p $(OBJDIR)
# backup:
# 	mkdir -p backup
# results:
# 	mkdir -p results
# setchmod:
# 	chmod +x *.sh
#
# .PHONY: clean
#
# clean:
# 	rm -rf $(OBJS) $(EXEC) $(LIBNAMESO) $(APPNAMESO)

# %%
import os
# 현재 colab에서 최대로 사용 가능한 cpu core수 확인하기
os.cpu_count()
# Out:
# 2

# %%
# '-j'뒤의 숫자는 make시 활용할 cpu 코어 갯수를 의미한다.
# !make -j2
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -fPIC -c ./src/image_opencv.cpp -o obj/image_opencv.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -fPIC -c ./src/http_stream.cpp -o obj/http_stream.o
# Makefile:182: recipe for target 'obj/image_opencv.o' failed
# make: *** [obj/image_opencv.o] Interrupt
# ^C

# %%
# %cd /mydrive/Advanced_AI/yolov4/darknet/
# Out:
# /content/drive/MyDrive/Advanced_AI/yolov4/darknet

# %%
# darknet, libdarknet.so파일이 보이면
# 컴파일이 잘 된것이다.
# !ls
# Out:
# 3rdparty		 darknet_video.py	predictions.jpg
# backup			 data			process.py
# build			 image_yolov3.sh	__pycache__
# build.ps1		 image_yolov4.sh	README.md
# cfg			 include		results
# chart.png		 json_mjpeg_streams.sh	scripts
# chart_yolov4-custom.png  libdarknet.so		src
# cmake			 LICENSE		uselib
# CMakeLists.txt		 Makefile		vcpkg.json
# darknet			 net_cam_v3.sh		video_yolov3.sh
# DarknetConfig.cmake.in	 net_cam_v4.sh		video_yolov4.sh
# darknet_images.py	 obj			weights
# darknet.py		 photo.jpg		yolov4.conv.137

# %% [markdown]
# ## 여기까지 진행하면 YOLO v4를 위한 darknet(딥러닝 프레임워크)이 준비

# %% [markdown]
# ## 사용자 데이터셋을 준비
# 마스크를 쓴 이미지
# 마스크를 쓰지 않은 이미지

# %%
# 마스크를 쓴 이미지, 쓰지 않은 이미지를 여기 폴더에 넣기위해
path = '/mydrive/Advanced_AI/yolov4/darknet/data/customData'
if not os.path.isdir(path):
    os.mkdir(path)
    print(path+'폴더를 생성했습니다')
else:
    print("이미 폴더가 존재합니다")
# Out:
# 이미 폴더가 존재합니다

# %%
# !pwd
# Out:
# /content/drive/My Drive/Advanced_AI/yolov4/darknet

# %%
# path = '/mydrive/Advanced_AI/yolov4/darknet/data/customData'
# print(len(os.listdir(path)))

# 압축풀기
#!unzip /mydrive/Advanced_AI/yolov4/darknet/data/customData/rock.zip -d data/customData
#!unzip /mydrive/Advanced_AI/yolov4/darknet/data/customData/scissors.zip -d data/customData
# !unzip /mydrive/Advanced_AI/yolov4/darknet/data/customData/paper.zip -d data/customData
# Out:
# Archive:  /mydrive/Advanced_AI/yolov4/darknet/data/customData/paper.zip
#   inflating: data/customData/br1_1.png
#   inflating: data/customData/br1_2.png
#   inflating: data/customData/br1_3.png
#   inflating: data/customData/br1_4.png
#   inflating: data/customData/br1_5.png
#   inflating: data/customData/br1_6.png
#   inflating: data/customData/br1_7.png
#   inflating: data/customData/br1_8.png
#   inflating: data/customData/br1_9.png
#   inflating: data/customData/br1_10.png
#   inflating: data/customData/br1_11.png
#   inflating: data/customData/br1_12.png
#   inflating: data/customData/br1_13.png
#   inflating: data/customData/br1_14.png
#   inflating: data/customData/br1_15.png
#   inflating: data/customData/br1_16.png
#   inflating: data/customData/br1_17.png
#   inflating: data/customData/br1_18.png
#   inflating: data/customData/br1_19.png
#   inflating: data/customData/br1_20.png
#   inflating: data/customData/br1_21.png
#   inflating: data/customData/br1_22.png
#   inflating: data/customData/br1_23.png
#   inflating: data/customData/br1_24.png
#   inflating: data/customData/br1_25.png
#   inflating: data/customData/br1_26.png
#   inflating: data/customData/br1_27.png
#   inflating: data/customData/br1_28.png
#   inflating: data/customData/br1_29.png
#   inflating: data/customData/br1_30.png
#   inflating: data/customData/br1_31.png
#   inflating: data/customData/br1_32.png
#   inflating: data/customData/br1_33.png
#   inflating: data/customData/br1_34.png
#   inflating: data/customData/br1_35.png
#   inflating: data/customData/br1_36.png
#   inflating: data/customData/br1_37.png
#   inflating: data/customData/br1_38.png
#   inflating: data/customData/br1_39.png
#   inflating: data/customData/br1_40.png
#   inflating: data/customData/br1_41.png
#   inflating: data/customData/br1_42.png
#   inflating: data/customData/br1_43.png
#   inflating: data/customData/br1_44.png
#   inflating: data/customData/br1_45.png
#   inflating: data/customData/br1_46.png
#   inflating: data/customData/br1_47.png
#   inflating: data/customData/br1_48.png
#   inflating: data/customData/br1_49.png
#   inflating: data/customData/br1_50.png
#   inflating: data/customData/br1_51.png
#   inflating: data/customData/br1_52.png
#   inflating: data/customData/br1_53.png
#   inflating: data/customData/br1_54.png
#   inflating: data/customData/br1_55.png
#   inflating: data/customData/br1_56.png
#   inflating: data/customData/br1_57.png
#   inflating: data/customData/br1_58.png
#   inflating: data/customData/br1_59.png
#   inflating: data/customData/br1_60.png
#   inflating: data/customData/br1_61.png
#   inflating: data/customData/color3_285.png
#   inflating: data/customData/color3_286.png
#   inflating: data/customData/color3_287.png
#   inflating: data/customData/color3_288.png
#   inflating: data/customData/color3_289.png
#   inflating: data/customData/color3_290.png
#   inflating: data/customData/color3_291.png
#   inflating: data/customData/color3_292.png
#   inflating: data/customData/color3_293.png
#   inflating: data/customData/color3_294.png
#   inflating: data/customData/color3_295.png
#   inflating: data/customData/color3_296.png
#   inflating: data/customData/color3_297.png
#   inflating: data/customData/color3_298.png
#   inflating: data/customData/color3_299.png
#   inflating: data/customData/color3_300.png
#   inflating: data/customData/color3_301.png
#   inflating: data/customData/color3_302.png
# ...
#   inflating: data/customData/im Audio - 121.txt
#   inflating: data/customData/im Audio - 122.txt
#   inflating: data/customData/im Audio - 125.txt
#   inflating: data/customData/im Audio - 127.txt
#   inflating: data/customData/im Audio - 128.txt
#   inflating: data/customData/im Audio - 129.txt
#   inflating: data/customData/im Audio - 130.txt
#   inflating: data/customData/im Audio - 136.txt
#   inflating: data/customData/im Audio - 137.txt
#   inflating: data/customData/im Audio - 138.txt
#   inflating: data/customData/im Audio - 140.txt
#   inflating: data/customData/im Audio - 142.txt
#   inflating: data/customData/im Audio - 144.txt
#   inflating: data/customData/im Audio - 145.txt
#   inflating: data/customData/im Audio - 146.txt
#   inflating: data/customData/im Audio - 147.txt
#   inflating: data/customData/im Audio - 148.txt
#   inflating: data/customData/im Audio - 149.txt
#   inflating: data/customData/im Audio - 150.txt
#   inflating: data/customData/im Audio - 152.txt
#   inflating: data/customData/im Audio - 156.txt
#   inflating: data/customData/im Audio - 157.txt
#   inflating: data/customData/im Audio - 158.txt
#   inflating: data/customData/im Audio - 159.txt
#   inflating: data/customData/im Audio - 160.txt
#   inflating: data/customData/im Audio - 161.txt
#   inflating: data/customData/im Audio - 162.txt
#   inflating: data/customData/im Audio - 163.txt
#   inflating: data/customData/im Audio - 164.txt
#   inflating: data/customData/im Audio - 165.txt
#   inflating: data/customData/im Audio - 166.txt
#   inflating: data/customData/im Audio - 167.txt
#   inflating: data/customData/im Audio - 168.txt
#   inflating: data/customData/im Audio - 169.txt
#   inflating: data/customData/im Audio - 170.txt
#   inflating: data/customData/im Audio - 171.txt
#   inflating: data/customData/im Audio - 172.txt
#   inflating: data/customData/im Audio - 173.txt
#   inflating: data/customData/im Audio - 174.txt
#   inflating: data/customData/im Audio - 175.txt
#   inflating: data/customData/im Audio - 176.txt
#   inflating: data/customData/im Audio - 177.txt
#   inflating: data/customData/im Audio - 178.txt
#   inflating: data/customData/im Audio - 179.txt
#   inflating: data/customData/im Audio - 180.txt
#   inflating: data/customData/im Audio - 181.txt
#   inflating: data/customData/im Audio - 183.txt
#   inflating: data/customData/im Audio - 184.txt
#   inflating: data/customData/im Audio - 185.txt
#   inflating: data/customData/im Audio - 186.txt
#   inflating: data/customData/im Audio - 187.txt
#   inflating: data/customData/im Audio - 188.txt
#   inflating: data/customData/im Audio - 189.txt
#   inflating: data/customData/im Audio - 190.txt
#   inflating: data/customData/im Audio - 191.txt
#   inflating: data/customData/im Audio - 192.txt
#   inflating: data/customData/im Audio - 193.txt
#   inflating: data/customData/im Audio - 194.txt
#   inflating: data/customData/im Audio - 195.txt
#   inflating: data/customData/im Audio - 196.txt
#   inflating: data/customData/im Audio - 197.txt
#   inflating: data/customData/im Audio - 198.txt
#   inflating: data/customData/im Audio - 199.txt
#   inflating: data/customData/im Audio - 200.txt
#   inflating: data/customData/im Audio - 201.txt
#   inflating: data/customData/im Audio - 203.txt
#   inflating: data/customData/im Audio - 204.txt
#   inflating: data/customData/im Audio - 205.txt
#   inflating: data/customData/im Audio - 206.txt
#   inflating: data/customData/im Audio - 207.txt
#   inflating: data/customData/im Audio - 208.txt
#   inflating: data/customData/im Audio - 209.txt
#   inflating: data/customData/im Audio - 210.txt
#   inflating: data/customData/im Audio - 211.txt
#   inflating: data/customData/im Audio - 212.txt
#   inflating: data/customData/im Audio - 213.txt
#   inflating: data/customData/im Audio - 214.txt
#   inflating: data/customData/im Audio - 215.txt
#   inflating: data/customData/im Audio - 216.txt
#   inflating: data/customData/im Audio - 217.txt
#   inflating: data/customData/im Audio - 218.txt
#   inflating: data/customData/im Audio - 219.txt
#   inflating: data/customData/im Audio - 220.txt
#   inflating: data/customData/im Audio - 221.txt
#   inflating: data/customData/im Audio - 222.txt
#   inflating: data/customData/im Audio - 223.txt
#   inflating: data/customData/im Audio - 224.txt
#   inflating: data/customData/im Audio - 225.txt
#   inflating: data/customData/im Audio - 226.txt
#   inflating: data/customData/im Audio - 227.txt
#   inflating: data/customData/im Audio - 228.txt
#   inflating: data/customData/im Audio - 229.txt
#   inflating: data/customData/im Audio - 230.txt
#   inflating: data/customData/im Audio - 231.txt
#   inflating: data/customData/im Audio - 232.txt
#   inflating: data/customData/im Audio - 233.txt
#   inflating: data/customData/im Audio - 234.txt
#   inflating: data/customData/im Audio - 235.txt
#   inflating: data/customData/im Audio - 236.txt
#   inflating: data/customData/im Audio - 237.txt
#   inflating: data/customData/im Audio - 238.txt
#   inflating: data/customData/im Audio - 239.txt
#   inflating: data/customData/im Audio - 240.txt
#   inflating: data/customData/im Audio - 242.txt
#   inflating: data/customData/im Audio - 243.txt
#   inflating: data/customData/im Audio - 244.txt
#   inflating: data/customData/im Audio - 245.txt
#   inflating: data/customData/im Audio - 246.txt
#   inflating: data/customData/im Audio - 247.txt
#   inflating: data/customData/im Audio - 248.txt
#   inflating: data/customData/im Audio - 249.txt
#   inflating: data/customData/im Audio - 250.txt
#   inflating: data/customData/im Audio - 251.txt
#   inflating: data/customData/im Audio - 252.txt
#   inflating: data/customData/im Audio - 253.txt
#   inflating: data/customData/im Audio - 254.txt
#   inflating: data/customData/im Audio - 255.txt
#   inflating: data/customData/im Audio - 256.txt
#   inflating: data/customData/im Audio - 257.txt
#   inflating: data/customData/im Audio - 258.txt
#   inflating: data/customData/im Audio - 260.txt
#   inflating: data/customData/im Audio - 261.txt
#   inflating: data/customData/im Audio - 262.txt
#   inflating: data/customData/im Audio - 264.txt
#   inflating: data/customData/im Audio - 268.txt
#   inflating: data/customData/im Audio - 269.txt
#   inflating: data/customData/im Audio - 270.txt
#   inflating: data/customData/im Audio - 271.txt
#   inflating: data/customData/im Audio - 272.txt
#   inflating: data/customData/im Audio - 273.txt
#   inflating: data/customData/im Audio - 274.txt
#   inflating: data/customData/im Audio - 275.txt
#   inflating: data/customData/im Audio - 276.txt
#   inflating: data/customData/im Audio - 277.txt
#   inflating: data/customData/im Audio - 278.txt
#   inflating: data/customData/im Audio - 279.txt
#   inflating: data/customData/im Audio - 282.txt
#   inflating: data/customData/im Audio - 283.txt
#   inflating: data/customData/im Audio - 284.txt
#   inflating: data/customData/im Audio - 288.txt
#   inflating: data/customData/im Audio - 293.txt
#   inflating: data/customData/im Audio - 295.txt
#   inflating: data/customData/im Audio - 296.txt
#   inflating: data/customData/im Audio - 297.txt
#   inflating: data/customData/im Audio - 298.txt
#   inflating: data/customData/im Audio - 300.txt
#   inflating: data/customData/im Audio - 301.txt
#   inflating: data/customData/im Audio - 302.txt
#   inflating: data/customData/im Audio - 303.txt
#   inflating: data/customData/im Audio - 307.txt
#   inflating: data/customData/im Audio - 308.txt
#   inflating: data/customData/im Audio - 309.txt
#   inflating: data/customData/im Audio - 310.txt
#   inflating: data/customData/im Audio - 311.txt
#   inflating: data/customData/im Audio - 312.txt
#   inflating: data/customData/im Audio - 314.txt
#   inflating: data/customData/im Audio - 315.txt
#   inflating: data/customData/im Audio - 321.txt
#   inflating: data/customData/im Audio - 323.txt
#   inflating: data/customData/im Audio - 324.txt
#   inflating: data/customData/im Audio - 325.txt
#   inflating: data/customData/im Audio - 326.txt
#   inflating: data/customData/im Audio - 327.txt
#   inflating: data/customData/im Audio - 328.txt
#   inflating: data/customData/im Audio - 329.txt
#   inflating: data/customData/im Audio - 330.txt
#   inflating: data/customData/im Audio - 332.txt
#   inflating: data/customData/im Audio - 334.txt
#   inflating: data/customData/im Audio - 335.txt
#   inflating: data/customData/im Audio - 337.txt
#   inflating: data/customData/im Audio - 338.txt
#   inflating: data/customData/im Audio - 339.txt
#   inflating: data/customData/im Audio - 344.txt
#   inflating: data/customData/im Audio - 346.txt
#   inflating: data/customData/im Audio - 347.txt
#   inflating: data/customData/im Audio - 348.txt
#   inflating: data/customData/im Audio - 349.txt
#   inflating: data/customData/im Audio - 350.txt
#   inflating: data/customData/im Audio - 351.txt
#   inflating: data/customData/im Audio - 352.txt
#   inflating: data/customData/im Audio - 353.txt
#   inflating: data/customData/im Audio - 354.txt
#   inflating: data/customData/im Audio - 355.txt
#   inflating: data/customData/im Audio - 356.txt
#   inflating: data/customData/im Audio - 357.txt
#   inflating: data/customData/im Audio - 358.txt
#   inflating: data/customData/im Audio - 359.txt
#   inflating: data/customData/im Audio - 360.txt
#   inflating: data/customData/im Audio - 366.txt
#   inflating: data/customData/im Audio - 368.txt
#   inflating: data/customData/im Audio - 373.txt
#   inflating: data/customData/im Audio - 374.txt
#   inflating: data/customData/im Audio - 375.txt
#   inflating: data/customData/im Audio - 377.txt
#   inflating: data/customData/im Audio - 378.txt
#   inflating: data/customData/im Audio - 380.txt
#   inflating: data/customData/im Audio - 381.txt
#   inflating: data/customData/im Audio - 383.txt
#   inflating: data/customData/im Audio - 384.txt
#   inflating: data/customData/im Audio - 385.txt
#   inflating: data/customData/im Audio - 386.txt
#   inflating: data/customData/im Audio - 387.txt
#   inflating: data/customData/im Audio - 388.txt
#   inflating: data/customData/im Audio - 392.txt
#   inflating: data/customData/im Audio - 394.txt
#   inflating: data/customData/im Audio - 396.txt
#   inflating: data/customData/im Audio - 398.txt
#   inflating: data/customData/im Audio - 399.txt
#   inflating: data/customData/im Audio - 403.txt
#   inflating: data/customData/im Audio - 405.txt
#   inflating: data/customData/im Audio - 406.txt
#   inflating: data/customData/im Audio - 407.txt
#   inflating: data/customData/im Audio - 408.txt
#   inflating: data/customData/im Audio - 409.txt
#   inflating: data/customData/im Audio - 410.txt
#   inflating: data/customData/im Audio - 411.txt
#   inflating: data/customData/im Audio - 412.txt
#   inflating: data/customData/im Audio - 417.txt
#   inflating: data/customData/im Audio - 420.txt
#   inflating: data/customData/im Audio - 421.txt
#   inflating: data/customData/im Audio - 425.txt
#   inflating: data/customData/im Audio - 426.txt
#   inflating: data/customData/im Audio - 427.txt
#   inflating: data/customData/im Audio - 429.txt
#   inflating: data/customData/im Audio - 430.txt
#   inflating: data/customData/im Audio - 431.txt
#   inflating: data/customData/im Audio - 434.txt
#   inflating: data/customData/im Audio - 435.txt
#   inflating: data/customData/im Audio - 436.txt
#   inflating: data/customData/im Audio - 437.txt
#   inflating: data/customData/im Audio - 439.txt
#   inflating: data/customData/im Audio - 440.txt
#   inflating: data/customData/im Audio - 441.txt
#   inflating: data/customData/im Audio - 442.txt
#   inflating: data/customData/im Audio - 444.txt
#   inflating: data/customData/im Audio - 447.txt
#   inflating: data/customData/im Audio - 448.txt
#   inflating: data/customData/im Audio - 452.txt
#   inflating: data/customData/im Audio - 453.txt
#   inflating: data/customData/im Audio - 454.txt
#   inflating: data/customData/im Audio - 455.txt
#   inflating: data/customData/im Audio - 456.txt
#   inflating: data/customData/im Audio - 457.txt
#   inflating: data/customData/im Audio - 459.txt
#   inflating: data/customData/im Audio - 461.txt
#   inflating: data/customData/im Audio - 462.txt
#   inflating: data/customData/im Audio - 464.txt
#   inflating: data/customData/im Audio - 465.txt
#   inflating: data/customData/im Audio - 466.txt
#   inflating: data/customData/im Audio - 467.txt
#   inflating: data/customData/im Audio - 468.txt
#   inflating: data/customData/im Audio - 471.txt
#   inflating: data/customData/im Audio - 472.txt
#   inflating: data/customData/im Audio - 474.txt
#   inflating: data/customData/im Audio - 475.txt
#   inflating: data/customData/im Audio - 476.txt
#   inflating: data/customData/im Audio - 477.txt
#   inflating: data/customData/im Audio - 478.txt
#   inflating: data/customData/im Audio - 479.txt
#   inflating: data/customData/im Audio - 480.txt
#   inflating: data/customData/im Audio - 482.txt
#   inflating: data/customData/im Audio - 484.txt
#   inflating: data/customData/im Audio - 486.txt
#   inflating: data/customData/im Audio - 488.txt
#   inflating: data/customData/im Audio - 492.txt
#   inflating: data/customData/im Audio - 493.txt
#   inflating: data/customData/im Audio - 496.txt
#   inflating: data/customData/im Audio - 497.txt
#   inflating: data/customData/im Audio - 501.txt
#   inflating: data/customData/im Audio - 503.txt
#   inflating: data/customData/im Audio - 506.txt
#   inflating: data/customData/im Audio - 507.txt
#   inflating: data/customData/im Audio - 508.txt
#   inflating: data/customData/im Audio - 512.txt
#   inflating: data/customData/im Audio - 513.txt
#   inflating: data/customData/im Audio - 514.txt
#   inflating: data/customData/im Audio - 517.txt
#   inflating: data/customData/im Audio - 518.txt
#   inflating: data/customData/im Audio - 519.txt
#   inflating: data/customData/im Audio - 520.txt
#   inflating: data/customData/im Audio - 521.txt
#   inflating: data/customData/im Audio - 522.txt
#   inflating: data/customData/im Audio - 523.txt
#   inflating: data/customData/im Audio - 525.txt
#   inflating: data/customData/im Audio - 526.txt
#   inflating: data/customData/im Audio - 531.txt
#   inflating: data/customData/im Audio - 532.txt
#   inflating: data/customData/im Audio - 533.txt
#   inflating: data/customData/im Audio - 534.txt
#   inflating: data/customData/im Audio - 535.txt
#   inflating: data/customData/im Audio - 536.txt
#   inflating: data/customData/im Audio - 537.txt
#   inflating: data/customData/im Audio - 539.txt
#   inflating: data/customData/im Audio - 543.txt
#   inflating: data/customData/im Audio - 544.txt
#   inflating: data/customData/im Audio - 547.txt
#   inflating: data/customData/im Audio - 549.txt
#   inflating: data/customData/im Audio - 550.txt
#   inflating: data/customData/im Audio - 551.txt
#   inflating: data/customData/im Audio - 552.txt
#   inflating: data/customData/im Audio - 553.txt
#   inflating: data/customData/im Audio - 554.txt
#   inflating: data/customData/im Audio - 557.txt
#   inflating: data/customData/im Audio - 560.txt
#   inflating: data/customData/im Audio - 561.txt
#   inflating: data/customData/im Audio - 562.txt
#   inflating: data/customData/im Audio - 563.txt
#   inflating: data/customData/im Audio - 564.txt
#   inflating: data/customData/im Audio - 567.txt
#   inflating: data/customData/im Audio - 568.txt
#   inflating: data/customData/im Audio - 572.txt
#   inflating: data/customData/im Audio - 573.txt
#   inflating: data/customData/im Audio - 574.txt
#   inflating: data/customData/im Audio - 575.txt
#   inflating: data/customData/im Audio - 576.txt
#   inflating: data/customData/im Audio - 577.txt
#   inflating: data/customData/im Audio - 578.txt
#   inflating: data/customData/im Audio - 580.txt
#   inflating: data/customData/im Audio - 588.txt
#   inflating: data/customData/im Audio - 589.txt

# %%
# 압축푼 폴더로 이동하여
# %cd /mydrive/Advanced_AI/yolov4/darknet/data/customData
# Out:
# /content/drive/MyDrive/Advanced_AI/yolov4/darknet/data/customData

# %%
#파일 압축푼것 확인
# !ls
# Out:
# '스크린샷, Audio - 100_sc.png'	 br2_22_sc.png	      'im Audio - 29.png'
# '스크린샷, Audio - 100_sc.txt'	 br2_22_sc.txt	      'im Audio - 29.txt'
# '스크린샷, Audio - 101_sc.png'	 br2_22.txt	      'im Audio - 2.png'
# '스크린샷, Audio - 101_sc.txt'	 br2_230.png	      'im Audio - 2.txt'
# '스크린샷, Audio - 102_sc.png'	 br2_230_sc.png       'im Audio - 300.png'
# '스크린샷, Audio - 102_sc.txt'	 br2_230_sc.txt       'im Audio - 300.txt'
# '스크린샷, Audio - 103_sc.png'	 br2_230.txt	      'im Audio - 301.png'
# '스크린샷, Audio - 103_sc.txt'	 br2_231.png	      'im Audio - 301.txt'
# '스크린샷, Audio - 104_sc.png'	 br2_231_sc.png       'im Audio - 302.png'
# '스크린샷, Audio - 104_sc.txt'	 br2_231_sc.txt       'im Audio - 302.txt'
# '스크린샷, Audio - 105_sc.png'	 br2_231.txt	      'im Audio - 303.png'
# '스크린샷, Audio - 105_sc.txt'	 br2_232.png	      'im Audio - 303.txt'
# '스크린샷, Audio - 106_sc.png'	 br2_232_sc.png       'im Audio - 307.png'
# '스크린샷, Audio - 106_sc.txt'	 br2_232_sc.txt       'im Audio - 307.txt'
# '스크린샷, Audio - 107_sc.png'	 br2_232.txt	      'im Audio - 308.png'
# '스크린샷, Audio - 107_sc.txt'	 br2_233.png	      'im Audio - 308.txt'
# '스크린샷, Audio - 108_sc.png'	 br2_233_sc.png       'im Audio - 309.png'
# '스크린샷, Audio - 108_sc.txt'	 br2_233_sc.txt       'im Audio - 309.txt'
# '스크린샷, Audio - 109_sc.png'	 br2_233.txt	      'im Audio - 30.png'
# '스크린샷, Audio - 109_sc.txt'	 br2_234.png	      'im Audio - 30.txt'
# '스크린샷, Audio - 10_sc.png'	 br2_234_sc.png       'im Audio - 310.png'
# '스크린샷, Audio - 10_sc.txt'	 br2_234_sc.txt       'im Audio - 310.txt'
# '스크린샷, Audio - 110_sc.png'	 br2_234.txt	      'im Audio - 311.png'
# '스크린샷, Audio - 110_sc.txt'	 br2_235.png	      'im Audio - 311.txt'
# '스크린샷, Audio - 111_sc.png'	 br2_235_sc.png       'im Audio - 312.png'
# '스크린샷, Audio - 111_sc.txt'	 br2_235_sc.txt       'im Audio - 312.txt'
# '스크린샷, Audio - 112_sc.png'	 br2_235.txt	      'im Audio - 314.png'
# '스크린샷, Audio - 112_sc.txt'	 br2_236.png	      'im Audio - 314.txt'
# '스크린샷, Audio - 113_sc.png'	 br2_236_sc.png       'im Audio - 315.png'
# '스크린샷, Audio - 113_sc.txt'	 br2_236_sc.txt       'im Audio - 315.txt'
# '스크린샷, Audio - 114_sc.png'	 br2_236.txt	      'im Audio - 321.png'
# '스크린샷, Audio - 114_sc.txt'	 br2_237.png	      'im Audio - 321.txt'
# '스크린샷, Audio - 115_sc.png'	 br2_237_sc.png       'im Audio - 323.png'
# '스크린샷, Audio - 115_sc.txt'	 br2_237_sc.txt       'im Audio - 323.txt'
# '스크린샷, Audio - 116_sc.png'	 br2_237.txt	      'im Audio - 324.png'
# '스크린샷, Audio - 116_sc.txt'	 br2_238.png	      'im Audio - 324.txt'
# '스크린샷, Audio - 117_sc.png'	 br2_238_sc.png       'im Audio - 325.png'
# '스크린샷, Audio - 117_sc.txt'	 br2_238_sc.txt       'im Audio - 325.txt'
# '스크린샷, Audio - 118_sc.png'	 br2_238.txt	      'im Audio - 326.png'
# '스크린샷, Audio - 118_sc.txt'	 br2_239.png	      'im Audio - 326.txt'
# '스크린샷, Audio - 119_sc.png'	 br2_239_sc.png       'im Audio - 327.png'
# '스크린샷, Audio - 119_sc.txt'	 br2_239_sc.txt       'im Audio - 327.txt'
# '스크린샷, Audio - 11_sc.png'	 br2_239.txt	      'im Audio - 328.png'
# '스크린샷, Audio - 11_sc.txt'	 br2_23.png	      'im Audio - 328.txt'
# '스크린샷, Audio - 120_sc.png'	 br2_23_sc.png	      'im Audio - 329.png'
# '스크린샷, Audio - 120_sc.txt'	 br2_23_sc.txt	      'im Audio - 329.txt'
# '스크린샷, Audio - 121_sc.png'	 br2_23.txt	      'im Audio - 32.png'
# '스크린샷, Audio - 121_sc.txt'	 br2_240.png	      'im Audio - 32.txt'
# '스크린샷, Audio - 122_sc.png'	 br2_240_sc.png       'im Audio - 330.png'
# '스크린샷, Audio - 122_sc.txt'	 br2_240_sc.txt       'im Audio - 330.txt'
# '스크린샷, Audio - 123_sc.png'	 br2_240.txt	      'im Audio - 332.png'
# '스크린샷, Audio - 123_sc.txt'	 br2_241.png	      'im Audio - 332.txt'
# '스크린샷, Audio - 124_sc.png'	 br2_241_sc.png       'im Audio - 334.png'
# '스크린샷, Audio - 124_sc.txt'	 br2_241_sc.txt       'im Audio - 334.txt'
# '스크린샷, Audio - 125_sc.png'	 br2_241.txt	      'im Audio - 335.png'
# '스크린샷, Audio - 125_sc.txt'	 br2_242.png	      'im Audio - 335.txt'
# '스크린샷, Audio - 126_sc.png'	 br2_242_sc.png       'im Audio - 337.png'
# '스크린샷, Audio - 126_sc.txt'	 br2_242_sc.txt       'im Audio - 337.txt'
# '스크린샷, Audio - 127_sc.png'	 br2_242.txt	      'im Audio - 338.png'
# '스크린샷, Audio - 127_sc.txt'	 br2_243.png	      'im Audio - 338.txt'
# '스크린샷, Audio - 128_sc.png'	 br2_243_sc.png       'im Audio - 339.png'
# '스크린샷, Audio - 128_sc.txt'	 br2_243_sc.txt       'im Audio - 339.txt'
# '스크린샷, Audio - 129_sc.png'	 br2_243.txt	      'im Audio - 33.png'
# '스크린샷, Audio - 129_sc.txt'	 br2_244.png	      'im Audio - 33.txt'
# '스크린샷, Audio - 12_sc.png'	 br2_244_sc.png       'im Audio - 344.png'
# '스크린샷, Audio - 12_sc.txt'	 br2_244_sc.txt       'im Audio - 344.txt'
# '스크린샷, Audio - 130_sc.png'	 br2_244.txt	      'im Audio - 346.png'
# '스크린샷, Audio - 130_sc.txt'	 br2_245.png	      'im Audio - 346.txt'
# '스크린샷, Audio - 131_sc.png'	 br2_245_sc.png       'im Audio - 347.png'
# '스크린샷, Audio - 131_sc.txt'	 br2_245_sc.txt       'im Audio - 347.txt'
# '스크린샷, Audio - 132_sc.png'	 br2_245.txt	      'im Audio - 348.png'
# '스크린샷, Audio - 132_sc.txt'	 br2_246.png	      'im Audio - 348.txt'
# '스크린샷, Audio - 133_sc.png'	 br2_246_sc.png       'im Audio - 349.png'
# '스크린샷, Audio - 133_sc.txt'	 br2_246_sc.txt       'im Audio - 349.txt'
# '스크린샷, Audio - 134_sc.png'	 br2_246.txt	      'im Audio - 350.png'
# '스크린샷, Audio - 134_sc.txt'	 br2_247.png	      'im Audio - 350.txt'
# '스크린샷, Audio - 135_sc.png'	 br2_247_sc.png       'im Audio - 351.png'
# '스크린샷, Audio - 135_sc.txt'	 br2_247_sc.txt       'im Audio - 351.txt'
# '스크린샷, Audio - 136_sc.png'	 br2_247.txt	      'im Audio - 352.png'
# '스크린샷, Audio - 136_sc.txt'	 br2_248.png	      'im Audio - 352.txt'
# '스크린샷, Audio - 137_sc.png'	 br2_248_sc.png       'im Audio - 353.png'
# '스크린샷, Audio - 137_sc.txt'	 br2_248_sc.txt       'im Audio - 353.txt'
# '스크린샷, Audio - 138_sc.png'	 br2_248.txt	      'im Audio - 354.png'
# '스크린샷, Audio - 138_sc.txt'	 br2_249.png	      'im Audio - 354.txt'
# '스크린샷, Audio - 139_sc.png'	 br2_249_sc.png       'im Audio - 355.png'
# '스크린샷, Audio - 139_sc.txt'	 br2_249_sc.txt       'im Audio - 355.txt'
# '스크린샷, Audio - 13_sc.png'	 br2_249.txt	      'im Audio - 356.png'
# '스크린샷, Audio - 13_sc.txt'	 br2_24.png	      'im Audio - 356.txt'
# '스크린샷, Audio - 140_sc.png'	 br2_24_sc.png	      'im Audio - 357.png'
# '스크린샷, Audio - 140_sc.txt'	 br2_24_sc.txt	      'im Audio - 357.txt'
# '스크린샷, Audio - 141_sc.png'	 br2_24.txt	      'im Audio - 358.png'
# '스크린샷, Audio - 141_sc.txt'	 br2_250.png	      'im Audio - 358.txt'
# '스크린샷, Audio - 142_sc.png'	 br2_250_sc.png       'im Audio - 359.png'
# '스크린샷, Audio - 142_sc.txt'	 br2_250_sc.txt       'im Audio - 359.txt'
# '스크린샷, Audio - 143_sc.png'	 br2_250.txt	      'im Audio - 35.png'
# '스크린샷, Audio - 143_sc.txt'	 br2_251.png	      'im Audio - 35.txt'
# '스크린샷, Audio - 144_sc.png'	 br2_251_sc.png       'im Audio - 360.png'
# '스크린샷, Audio - 144_sc.txt'	 br2_251_sc.txt       'im Audio - 360.txt'
# '스크린샷, Audio - 145_sc.png'	 br2_251.txt	      'im Audio - 366.png'
# '스크린샷, Audio - 145_sc.txt'	 br2_252.png	      'im Audio - 366.txt'
# '스크린샷, Audio - 146_sc.png'	 br2_252_sc.png       'im Audio - 368.png'
# '스크린샷, Audio - 146_sc.txt'	 br2_252_sc.txt       'im Audio - 368.txt'
# '스크린샷, Audio - 147_sc.png'	 br2_252.txt	      'im Audio - 373.png'
# '스크린샷, Audio - 147_sc.txt'	 br2_253.png	      'im Audio - 373.txt'
# '스크린샷, Audio - 148_sc.png'	 br2_253_sc.png       'im Audio - 374.png'
# '스크린샷, Audio - 148_sc.txt'	 br2_253_sc.txt       'im Audio - 374.txt'
# '스크린샷, Audio - 149_sc.png'	 br2_253.txt	      'im Audio - 375.png'
# '스크린샷, Audio - 149_sc.txt'	 br2_254.png	      'im Audio - 375.txt'
# '스크린샷, Audio - 14_sc.png'	 br2_254_sc.png       'im Audio - 377.png'
# '스크린샷, Audio - 14_sc.txt'	 br2_254_sc.txt       'im Audio - 377.txt'
# '스크린샷, Audio - 150_sc.png'	 br2_254.txt	      'im Audio - 378.png'
# '스크린샷, Audio - 150_sc.txt'	 br2_255.png	      'im Audio - 378.txt'
# '스크린샷, Audio - 151_sc.png'	 br2_255_sc.png       'im Audio - 380.png'
# '스크린샷, Audio - 151_sc.txt'	 br2_255_sc.txt       'im Audio - 380.txt'
# '스크린샷, Audio - 152_sc.png'	 br2_255.txt	      'im Audio - 381.png'
# '스크린샷, Audio - 152_sc.txt'	 br2_256.png	      'im Audio - 381.txt'
# '스크린샷, Audio - 153_sc.png'	 br2_256_sc.png       'im Audio - 383.png'
# '스크린샷, Audio - 153_sc.txt'	 br2_256_sc.txt       'im Audio - 383.txt'
# '스크린샷, Audio - 154_sc.png'	 br2_256.txt	      'im Audio - 384.png'
# '스크린샷, Audio - 154_sc.txt'	 br2_257.png	      'im Audio - 384.txt'
# '스크린샷, Audio - 155_sc.png'	 br2_257_sc.png       'im Audio - 385.png'
# '스크린샷, Audio - 155_sc.txt'	 br2_257_sc.txt       'im Audio - 385.txt'
# '스크린샷, Audio - 156_sc.png'	 br2_257.txt	      'im Audio - 386.png'
# '스크린샷, Audio - 156_sc.txt'	 br2_258.png	      'im Audio - 386.txt'
# '스크린샷, Audio - 157_sc.png'	 br2_258_sc.png       'im Audio - 387.png'
# '스크린샷, Audio - 157_sc.txt'	 br2_258_sc.txt       'im Audio - 387.txt'
# '스크린샷, Audio - 158_sc.png'	 br2_258.txt	      'im Audio - 388.png'
# '스크린샷, Audio - 158_sc.txt'	 br2_259.png	      'im Audio - 388.txt'
# '스크린샷, Audio - 159_sc.png'	 br2_259_sc.png       'im Audio - 392.png'
# '스크린샷, Audio - 159_sc.txt'	 br2_259_sc.txt       'im Audio - 392.txt'
# '스크린샷, Audio - 15_sc.png'	 br2_259.txt	      'im Audio - 394.png'
# '스크린샷, Audio - 15_sc.txt'	 br2_25.png	      'im Audio - 394.txt'
# '스크린샷, Audio - 160_sc.png'	 br2_25_sc.png	      'im Audio - 396.png'
# '스크린샷, Audio - 160_sc.txt'	 br2_25_sc.txt	      'im Audio - 396.txt'
# '스크린샷, Audio - 161_sc.png'	 br2_25.txt	      'im Audio - 398.png'
# '스크린샷, Audio - 161_sc.txt'	 br2_260.png	      'im Audio - 398.txt'
# '스크린샷, Audio - 162_sc.png'	 br2_260_sc.png       'im Audio - 399.png'
# '스크린샷, Audio - 162_sc.txt'	 br2_260_sc.txt       'im Audio - 399.txt'
# '스크린샷, Audio - 163_sc.png'	 br2_260.txt	      'im Audio - 3.png'
# '스크린샷, Audio - 163_sc.txt'	 br2_261.png	      'im Audio - 3.txt'
# '스크린샷, Audio - 164_sc.png'	 br2_261_sc.png       'im Audio - 403.png'
# '스크린샷, Audio - 164_sc.txt'	 br2_261_sc.txt       'im Audio - 403.txt'
# '스크린샷, Audio - 165_sc.png'	 br2_261.txt	      'im Audio - 405.png'
# '스크린샷, Audio - 165_sc.txt'	 br2_262.png	      'im Audio - 405.txt'
# '스크린샷, Audio - 166_sc.png'	 br2_262_sc.png       'im Audio - 406.png'
# '스크린샷, Audio - 166_sc.txt'	 br2_262_sc.txt       'im Audio - 406.txt'
# '스크린샷, Audio - 167_sc.png'	 br2_262.txt	      'im Audio - 407.png'
# '스크린샷, Audio - 167_sc.txt'	 br2_263.png	      'im Audio - 407.txt'
# '스크린샷, Audio - 168_sc.png'	 br2_263_sc.png       'im Audio - 408.png'
# '스크린샷, Audio - 168_sc.txt'	 br2_263_sc.txt       'im Audio - 408.txt'
# '스크린샷, Audio - 169_sc.png'	 br2_263.txt	      'im Audio - 409.png'
# '스크린샷, Audio - 169_sc.txt'	 br2_264.png	      'im Audio - 409.txt'
# '스크린샷, Audio - 16_sc.png'	 br2_264_sc.png       'im Audio - 410.png'
# '스크린샷, Audio - 16_sc.txt'	 br2_264_sc.txt       'im Audio - 410.txt'
# '스크린샷, Audio - 170_sc.png'	 br2_264.txt	      'im Audio - 411.png'
# '스크린샷, Audio - 170_sc.txt'	 br2_265.png	      'im Audio - 411.txt'
# '스크린샷, Audio - 171_sc.png'	 br2_265_sc.png       'im Audio - 412.png'
# '스크린샷, Audio - 171_sc.txt'	 br2_265_sc.txt       'im Audio - 412.txt'
# '스크린샷, Audio - 172_sc.png'	 br2_265.txt	      'im Audio - 417.png'
# '스크린샷, Audio - 172_sc.txt'	 br2_266.png	      'im Audio - 417.txt'
# '스크린샷, Audio - 173_sc.png'	 br2_266_sc.png       'im Audio - 420.png'
# '스크린샷, Audio - 173_sc.txt'	 br2_266_sc.txt       'im Audio - 420.txt'
# '스크린샷, Audio - 174_sc.png'	 br2_266.txt	      'im Audio - 421.png'
# '스크린샷, Audio - 174_sc.txt'	 br2_267.png	      'im Audio - 421.txt'
# '스크린샷, Audio - 175_sc.png'	 br2_267_sc.png       'im Audio - 425.png'
# '스크린샷, Audio - 175_sc.txt'	 br2_267_sc.txt       'im Audio - 425.txt'
# '스크린샷, Audio - 176_sc.png'	 br2_267.txt	      'im Audio - 426.png'
# '스크린샷, Audio - 176_sc.txt'	 br2_268.png	      'im Audio - 426.txt'
# '스크린샷, Audio - 177_sc.png'	 br2_268_sc.png       'im Audio - 427.png'
# '스크린샷, Audio - 177_sc.txt'	 br2_268_sc.txt       'im Audio - 427.txt'
# '스크린샷, Audio - 178_sc.png'	 br2_268.txt	      'im Audio - 429.png'
# '스크린샷, Audio - 178_sc.txt'	 br2_269.png	      'im Audio - 429.txt'
# '스크린샷, Audio - 179_sc.png'	 br2_269_sc.png       'im Audio - 42.png'
# '스크린샷, Audio - 179_sc.txt'	 br2_269_sc.txt       'im Audio - 42.txt'
# '스크린샷, Audio - 17_sc.png'	 br2_269.txt	      'im Audio - 430.png'
# '스크린샷, Audio - 17_sc.txt'	 br2_26.png	      'im Audio - 430.txt'
# '스크린샷, Audio - 180_sc.png'	 br2_26_sc.png	      'im Audio - 431.png'
# '스크린샷, Audio - 180_sc.txt'	 br2_26_sc.txt	      'im Audio - 431.txt'
# '스크린샷, Audio - 181_sc.png'	 br2_26.txt	      'im Audio - 434.png'
# '스크린샷, Audio - 181_sc.txt'	 br2_270.png	      'im Audio - 434.txt'
# '스크린샷, Audio - 182_sc.png'	 br2_270_sc.png       'im Audio - 435.png'
# '스크린샷, Audio - 182_sc.txt'	 br2_270_sc.txt       'im Audio - 435.txt'
# '스크린샷, Audio - 183_sc.png'	 br2_270.txt	      'im Audio - 436.png'
# '스크린샷, Audio - 183_sc.txt'	 br2_271.png	      'im Audio - 436.txt'
# '스크린샷, Audio - 184_sc.png'	 br2_271_sc.png       'im Audio - 437.png'
# '스크린샷, Audio - 184_sc.txt'	 br2_271_sc.txt       'im Audio - 437.txt'
# '스크린샷, Audio - 185_sc.png'	 br2_271.txt	      'im Audio - 439.png'
# '스크린샷, Audio - 185_sc.txt'	 br2_272.png	      'im Audio - 439.txt'
# '스크린샷, Audio - 186_sc.png'	 br2_272_sc.png       'im Audio - 440.png'
# '스크린샷, Audio - 186_sc.txt'	 br2_272_sc.txt       'im Audio - 440.txt'
# '스크린샷, Audio - 187_sc.png'	 br2_272.txt	      'im Audio - 441.png'
# '스크린샷, Audio - 187_sc.txt'	 br2_273.png	      'im Audio - 441.txt'
# '스크린샷, Audio - 188_sc.png'	 br2_273_sc.png       'im Audio - 442.png'
# '스크린샷, Audio - 188_sc.txt'	 br2_273_sc.txt       'im Audio - 442.txt'
# '스크린샷, Audio - 189_sc.png'	 br2_273.txt	      'im Audio - 444.png'
# '스크린샷, Audio - 189_sc.txt'	 br2_274.png	      'im Audio - 444.txt'
# '스크린샷, Audio - 18_sc.png'	 br2_274_sc.png       'im Audio - 447.png'
# '스크린샷, Audio - 18_sc.txt'	 br2_274_sc.txt       'im Audio - 447.txt'
# '스크린샷, Audio - 190_sc.png'	 br2_274.txt	      'im Audio - 448.png'
# '스크린샷, Audio - 190_sc.txt'	 br2_275.png	      'im Audio - 448.txt'
# '스크린샷, Audio - 191_sc.png'	 br2_275_sc.png       'im Audio - 452.png'
# '스크린샷, Audio - 191_sc.txt'	 br2_275_sc.txt       'im Audio - 452.txt'
# '스크린샷, Audio - 192_sc.png'	 br2_275.txt	      'im Audio - 453.png'
# '스크린샷, Audio - 192_sc.txt'	 br2_276.png	      'im Audio - 453.txt'
# '스크린샷, Audio - 193_sc.png'	 br2_276_sc.png       'im Audio - 454.png'
# '스크린샷, Audio - 193_sc.txt'	 br2_276_sc.txt       'im Audio - 454.txt'
# '스크린샷, Audio - 194_sc.png'	 br2_276.txt	      'im Audio - 455.png'
# '스크린샷, Audio - 194_sc.txt'	 br2_277.png	      'im Audio - 455.txt'
# '스크린샷, Audio - 195_sc.png'	 br2_277_sc.png       'im Audio - 456.png'
# '스크린샷, Audio - 195_sc.txt'	 br2_277_sc.txt       'im Audio - 456.txt'
# '스크린샷, Audio - 196_sc.png'	 br2_277.txt	      'im Audio - 457.png'
# '스크린샷, Audio - 196_sc.txt'	 br2_278.png	      'im Audio - 457.txt'
# '스크린샷, Audio - 197_sc.png'	 br2_278_sc.png       'im Audio - 459.png'
# '스크린샷, Audio - 197_sc.txt'	 br2_278_sc.txt       'im Audio - 459.txt'
# '스크린샷, Audio - 198_sc.png'	 br2_278.txt	      'im Audio - 45.png'
# '스크린샷, Audio - 198_sc.txt'	 br2_279.png	      'im Audio - 45.txt'
# '스크린샷, Audio - 199_sc.png'	 br2_279_sc.png       'im Audio - 461.png'
# '스크린샷, Audio - 199_sc.txt'	 br2_279_sc.txt       'im Audio - 461.txt'
# '스크린샷, Audio - 19_sc.png'	 br2_279.txt	      'im Audio - 462.png'
# '스크린샷, Audio - 19_sc.txt'	 br2_27.png	      'im Audio - 462.txt'
# '스크린샷, Audio - 1_sc.png'	 br2_27_sc.png	      'im Audio - 464.png'
# '스크린샷, Audio - 1_sc.txt'	 br2_27_sc.txt	      'im Audio - 464.txt'
# '스크린샷, Audio - 200_sc.png'	 br2_27.txt	      'im Audio - 465.png'
# '스크린샷, Audio - 200_sc.txt'	 br2_280.png	      'im Audio - 465.txt'
# '스크린샷, Audio - 201_sc.png'	 br2_280_sc.png       'im Audio - 466.png'
# '스크린샷, Audio - 201_sc.txt'	 br2_280_sc.txt       'im Audio - 466.txt'
# '스크린샷, Audio - 202_sc.png'	 br2_280.txt	      'im Audio - 467.png'
# '스크린샷, Audio - 202_sc.txt'	 br2_281.png	      'im Audio - 467.txt'
# '스크린샷, Audio - 203_sc.png'	 br2_281_sc.png       'im Audio - 468.png'
# '스크린샷, Audio - 203_sc.txt'	 br2_281_sc.txt       'im Audio - 468.txt'
# '스크린샷, Audio - 204_sc.png'	 br2_281.txt	      'im Audio - 46.png'
# '스크린샷, Audio - 204_sc.txt'	 br2_282.png	      'im Audio - 46.txt'
# '스크린샷, Audio - 205_sc.png'	 br2_282_sc.png       'im Audio - 471.png'
# '스크린샷, Audio - 205_sc.txt'	 br2_282_sc.txt       'im Audio - 471.txt'
# '스크린샷, Audio - 206_sc.png'	 br2_282.txt	      'im Audio - 472.png'
# '스크린샷, Audio - 206_sc.txt'	 br2_283.png	      'im Audio - 472.txt'
# '스크린샷, Audio - 207_sc.png'	 br2_283_sc.png       'im Audio - 474.png'
# '스크린샷, Audio - 207_sc.txt'	 br2_283_sc.txt       'im Audio - 474.txt'
# '스크린샷, Audio - 208_sc.png'	 br2_283.txt	      'im Audio - 475.png'
# '스크린샷, Audio - 208_sc.txt'	 br2_284.png	      'im Audio - 475.txt'
# '스크린샷, Audio - 209_sc.png'	 br2_284_sc.png       'im Audio - 476.png'
# '스크린샷, Audio - 209_sc.txt'	 br2_284_sc.txt       'im Audio - 476.txt'
# '스크린샷, Audio - 20_sc.png'	 br2_284.txt	      'im Audio - 477.png'
# '스크린샷, Audio - 20_sc.txt'	 br2_285.png	      'im Audio - 477.txt'
# '스크린샷, Audio - 210_sc.png'	 br2_285_sc.png       'im Audio - 478.png'
# '스크린샷, Audio - 210_sc.txt'	 br2_285_sc.txt       'im Audio - 478.txt'
# '스크린샷, Audio - 211_sc.png'	 br2_285.txt	      'im Audio - 479.png'
# '스크린샷, Audio - 211_sc.txt'	 br2_286.png	      'im Audio - 479.txt'
# '스크린샷, Audio - 212_sc.png'	 br2_286_sc.png       'im Audio - 47.png'
# '스크린샷, Audio - 212_sc.txt'	 br2_286_sc.txt       'im Audio - 47.txt'
# '스크린샷, Audio - 213_sc.png'	 br2_286.txt	      'im Audio - 480.png'
# '스크린샷, Audio - 213_sc.txt'	 br2_287.png	      'im Audio - 480.txt'
# '스크린샷, Audio - 214_sc.png'	 br2_287_sc.png       'im Audio - 482.png'
# '스크린샷, Audio - 214_sc.txt'	 br2_287_sc.txt       'im Audio - 482.txt'
# '스크린샷, Audio - 215_sc.png'	 br2_287.txt	      'im Audio - 484.png'
# '스크린샷, Audio - 215_sc.txt'	 br2_288.png	      'im Audio - 484.txt'
# '스크린샷, Audio - 216_sc.png'	 br2_288_sc.png       'im Audio - 486.png'
# '스크린샷, Audio - 216_sc.txt'	 br2_288_sc.txt       'im Audio - 486.txt'
# '스크린샷, Audio - 217_sc.png'	 br2_288.txt	      'im Audio - 488.png'
# '스크린샷, Audio - 217_sc.txt'	 br2_289.png	      'im Audio - 488.txt'
# '스크린샷, Audio - 218_sc.png'	 br2_289_sc.png       'im Audio - 48.png'
# '스크린샷, Audio - 218_sc.txt'	 br2_289_sc.txt       'im Audio - 48.txt'
# '스크린샷, Audio - 219_sc.png'	 br2_289.txt	      'im Audio - 492.png'
# '스크린샷, Audio - 219_sc.txt'	 br2_28.png	      'im Audio - 492.txt'
# '스크린샷, Audio - 21_sc.png'	 br2_28_sc.png	      'im Audio - 493.png'
# '스크린샷, Audio - 21_sc.txt'	 br2_28_sc.txt	      'im Audio - 493.txt'
# '스크린샷, Audio - 220_sc.png'	 br2_28.txt	      'im Audio - 496.png'
# '스크린샷, Audio - 220_sc.txt'	 br2_290.png	      'im Audio - 496.txt'
# '스크린샷, Audio - 221_sc.png'	 br2_290_sc.png       'im Audio - 497.png'
# '스크린샷, Audio - 221_sc.txt'	 br2_290_sc.txt       'im Audio - 497.txt'
# '스크린샷, Audio - 222_sc.png'	 br2_290.txt	      'im Audio - 4.png'
# '스크린샷, Audio - 222_sc.txt'	 br2_291.png	      'im Audio - 4.txt'
# '스크린샷, Audio - 223_sc.png'	 br2_291_sc.png       'im Audio - 501.png'
# '스크린샷, Audio - 223_sc.txt'	 br2_291_sc.txt       'im Audio - 501.txt'
# '스크린샷, Audio - 224_sc.png'	 br2_291.txt	      'im Audio - 503.png'
# '스크린샷, Audio - 224_sc.txt'	 br2_292.png	      'im Audio - 503.txt'
# '스크린샷, Audio - 225_sc.png'	 br2_292_sc.png       'im Audio - 506.png'
# '스크린샷, Audio - 225_sc.txt'	 br2_292_sc.txt       'im Audio - 506.txt'
# '스크린샷, Audio - 226_sc.png'	 br2_292.txt	      'im Audio - 507.png'
# '스크린샷, Audio - 226_sc.txt'	 br2_293.png	      'im Audio - 507.txt'
# '스크린샷, Audio - 227_sc.png'	 br2_293_sc.png       'im Audio - 508.png'
# '스크린샷, Audio - 227_sc.txt'	 br2_293_sc.txt       'im Audio - 508.txt'
# '스크린샷, Audio - 228_sc.png'	 br2_293.txt	      'im Audio - 512.png'
# '스크린샷, Audio - 228_sc.txt'	 br2_294.png	      'im Audio - 512.txt'
# '스크린샷, Audio - 229_sc.png'	 br2_294_sc.png       'im Audio - 513.png'
# '스크린샷, Audio - 229_sc.txt'	 br2_294_sc.txt       'im Audio - 513.txt'
# '스크린샷, Audio - 22_sc.png'	 br2_294.txt	      'im Audio - 514.png'
# '스크린샷, Audio - 22_sc.txt'	 br2_295.png	      'im Audio - 514.txt'
# '스크린샷, Audio - 230_sc.png'	 br2_295_sc.png       'im Audio - 517.png'
# '스크린샷, Audio - 230_sc.txt'	 br2_295_sc.txt       'im Audio - 517.txt'
# '스크린샷, Audio - 231_sc.png'	 br2_295.txt	      'im Audio - 518.png'
# '스크린샷, Audio - 231_sc.txt'	 br2_296.png	      'im Audio - 518.txt'
# '스크린샷, Audio - 232_sc.png'	 br2_296_sc.png       'im Audio - 519.png'
# '스크린샷, Audio - 232_sc.txt'	 br2_296_sc.txt       'im Audio - 519.txt'
# '스크린샷, Audio - 233_sc.png'	 br2_296.txt	      'im Audio - 51.png'
# '스크린샷, Audio - 233_sc.txt'	 br2_297.png	      'im Audio - 51.txt'
# '스크린샷, Audio - 234_sc.png'	 br2_297_sc.png       'im Audio - 520.png'
# '스크린샷, Audio - 234_sc.txt'	 br2_297_sc.txt       'im Audio - 520.txt'
# '스크린샷, Audio - 235_sc.png'	 br2_297.txt	      'im Audio - 521.png'
# '스크린샷, Audio - 235_sc.txt'	 br2_298.png	      'im Audio - 521.txt'
# '스크린샷, Audio - 236_sc.png'	 br2_298_sc.png       'im Audio - 522.png'
# '스크린샷, Audio - 236_sc.txt'	 br2_298_sc.txt       'im Audio - 522.txt'
# '스크린샷, Audio - 237_sc.png'	 br2_298.txt	      'im Audio - 523.png'
# '스크린샷, Audio - 237_sc.txt'	 br2_299.png	      'im Audio - 523.txt'
# '스크린샷, Audio - 238_sc.png'	 br2_299_sc.png       'im Audio - 525.png'
# '스크린샷, Audio - 238_sc.txt'	 br2_299_sc.txt       'im Audio - 525.txt'
# '스크린샷, Audio - 239_sc.png'	 br2_299.txt	      'im Audio - 526.png'
# '스크린샷, Audio - 239_sc.txt'	 br2_29.png	      'im Audio - 526.txt'
# '스크린샷, Audio - 23_sc.png'	 br2_29_sc.png	      'im Audio - 531.png'
# '스크린샷, Audio - 23_sc.txt'	 br2_29_sc.txt	      'im Audio - 531.txt'
# '스크린샷, Audio - 240_sc.png'	 br2_29.txt	      'im Audio - 532.png'
# '스크린샷, Audio - 240_sc.txt'	 br2_2.png	      'im Audio - 532.txt'
# '스크린샷, Audio - 241_sc.png'	 br2_2_sc.png	      'im Audio - 533.png'
# '스크린샷, Audio - 241_sc.txt'	 br2_2_sc.txt	      'im Audio - 533.txt'
# '스크린샷, Audio - 242_sc.png'	 br2_2.txt	      'im Audio - 534.png'
# '스크린샷, Audio - 242_sc.txt'	 br2_300.png	      'im Audio - 534.txt'
# '스크린샷, Audio - 243_sc.png'	 br2_300_sc.png       'im Audio - 535.png'
# '스크린샷, Audio - 243_sc.txt'	 br2_300_sc.txt       'im Audio - 535.txt'
# '스크린샷, Audio - 244_sc.png'	 br2_300.txt	      'im Audio - 536.png'
# '스크린샷, Audio - 244_sc.txt'	 br2_301.png	      'im Audio - 536.txt'
# '스크린샷, Audio - 245_sc.png'	 br2_301_sc.png       'im Audio - 537.png'
# '스크린샷, Audio - 245_sc.txt'	 br2_301_sc.txt       'im Audio - 537.txt'
# '스크린샷, Audio - 246_sc.png'	 br2_301.txt	      'im Audio - 539.png'
# '스크린샷, Audio - 246_sc.txt'	 br2_302.png	      'im Audio - 539.txt'
# '스크린샷, Audio - 247_sc.png'	 br2_302_sc.png       'im Audio - 543.png'
# '스크린샷, Audio - 247_sc.txt'	 br2_302_sc.txt       'im Audio - 543.txt'
# '스크린샷, Audio - 248_sc.png'	 br2_302.txt	      'im Audio - 544.png'
# '스크린샷, Audio - 248_sc.txt'	 br2_303.png	      'im Audio - 544.txt'
# '스크린샷, Audio - 249_sc.png'	 br2_303_sc.png       'im Audio - 547.png'
# '스크린샷, Audio - 249_sc.txt'	 br2_303_sc.txt       'im Audio - 547.txt'
# '스크린샷, Audio - 24_sc.png'	 br2_303.txt	      'im Audio - 549.png'
# '스크린샷, Audio - 24_sc.txt'	 br2_304.png	      'im Audio - 549.txt'
# '스크린샷, Audio - 250_sc.png'	 br2_304_sc.png       'im Audio - 54.png'
# '스크린샷, Audio - 250_sc.txt'	 br2_304_sc.txt       'im Audio - 54.txt'
# '스크린샷, Audio - 251_sc.png'	 br2_304.txt	      'im Audio - 550.png'
# '스크린샷, Audio - 251_sc.txt'	 br2_305.png	      'im Audio - 550.txt'
# '스크린샷, Audio - 252_sc.png'	 br2_305_sc.png       'im Audio - 551.png'
# '스크린샷, Audio - 252_sc.txt'	 br2_305_sc.txt       'im Audio - 551.txt'
# '스크린샷, Audio - 253_sc.png'	 br2_305.txt	      'im Audio - 552.png'
# '스크린샷, Audio - 253_sc.txt'	 br2_306.png	      'im Audio - 552.txt'
# '스크린샷, Audio - 254_sc.png'	 br2_306_sc.png       'im Audio - 553.png'
# '스크린샷, Audio - 254_sc.txt'	 br2_306_sc.txt       'im Audio - 553.txt'
# '스크린샷, Audio - 255_sc.png'	 br2_306.txt	      'im Audio - 554.png'
# '스크린샷, Audio - 255_sc.txt'	 br2_307.png	      'im Audio - 554.txt'
# '스크린샷, Audio - 256_sc.png'	 br2_307_sc.png       'im Audio - 557.png'
# '스크린샷, Audio - 256_sc.txt'	 br2_307_sc.txt       'im Audio - 557.txt'
# '스크린샷, Audio - 257_sc.png'	 br2_307.txt	      'im Audio - 560.png'
# '스크린샷, Audio - 257_sc.txt'	 br2_308.png	      'im Audio - 560.txt'
# '스크린샷, Audio - 258_sc.png'	 br2_308_sc.png       'im Audio - 561.png'
# '스크린샷, Audio - 258_sc.txt'	 br2_308_sc.txt       'im Audio - 561.txt'
# '스크린샷, Audio - 259_sc.png'	 br2_308.txt	      'im Audio - 562.png'
# '스크린샷, Audio - 259_sc.txt'	 br2_309.png	      'im Audio - 562.txt'
# '스크린샷, Audio - 25_sc.png'	 br2_309_sc.png       'im Audio - 563.png'
# '스크린샷, Audio - 25_sc.txt'	 br2_309_sc.txt       'im Audio - 563.txt'
# '스크린샷, Audio - 260_sc.png'	 br2_309.txt	      'im Audio - 564.png'
# '스크린샷, Audio - 260_sc.txt'	 br2_30.png	      'im Audio - 564.txt'
# '스크린샷, Audio - 261_sc.png'	 br2_30_sc.png	      'im Audio - 567.png'
# '스크린샷, Audio - 261_sc.txt'	 br2_30_sc.txt	      'im Audio - 567.txt'
# '스크린샷, Audio - 262_sc.png'	 br2_30.txt	      'im Audio - 568.png'
# '스크린샷, Audio - 262_sc.txt'	 br2_310.png	      'im Audio - 568.txt'
# '스크린샷, Audio - 263_sc.png'	 br2_310_sc.png       'im Audio - 572.png'
# '스크린샷, Audio - 263_sc.txt'	 br2_310_sc.txt       'im Audio - 572.txt'
# '스크린샷, Audio - 264_sc.png'	 br2_310.txt	      'im Audio - 573.png'
# '스크린샷, Audio - 264_sc.txt'	 br2_311.png	      'im Audio - 573.txt'
# '스크린샷, Audio - 265_sc.png'	 br2_311_sc.png       'im Audio - 574.png'
# '스크린샷, Audio - 265_sc.txt'	 br2_311_sc.txt       'im Audio - 574.txt'
# '스크린샷, Audio - 266_sc.png'	 br2_311.txt	      'im Audio - 575.png'
# '스크린샷, Audio - 266_sc.txt'	 br2_312.png	      'im Audio - 575.txt'
# '스크린샷, Audio - 267_sc.png'	 br2_312_sc.png       'im Audio - 576.png'
# '스크린샷, Audio - 267_sc.txt'	 br2_312_sc.txt       'im Audio - 576.txt'
# '스크린샷, Audio - 268_sc.png'	 br2_312.txt	      'im Audio - 577.png'
# '스크린샷, Audio - 268_sc.txt'	 br2_313.png	      'im Audio - 577.txt'
# '스크린샷, Audio - 269_sc.png'	 br2_313_sc.png       'im Audio - 578.png'
# '스크린샷, Audio - 269_sc.txt'	 br2_313_sc.txt       'im Audio - 578.txt'
# '스크린샷, Audio - 26_sc.png'	 br2_313.txt	      'im Audio - 57.png'
# '스크린샷, Audio - 26_sc.txt'	 br2_314.png	      'im Audio - 57.txt'
# '스크린샷, Audio - 270_sc.png'	 br2_314_sc.png       'im Audio - 580.png'
# '스크린샷, Audio - 270_sc.txt'	 br2_314_sc.txt       'im Audio - 580.txt'
# '스크린샷, Audio - 271_sc.png'	 br2_314.txt	      'im Audio - 588.png'
# '스크린샷, Audio - 271_sc.txt'	 br2_315.png	      'im Audio - 588.txt'
# '스크린샷, Audio - 272_sc.png'	 br2_315_sc.png       'im Audio - 589.png'
# '스크린샷, Audio - 272_sc.txt'	 br2_315_sc.txt       'im Audio - 589.txt'
# '스크린샷, Audio - 273_sc.png'	 br2_315.txt	      'im Audio - 59.png'
# '스크린샷, Audio - 273_sc.txt'	 br2_316.png	      'im Audio - 59.txt'
# '스크린샷, Audio - 274_sc.png'	 br2_316_sc.png       'im Audio - 5.png'
# '스크린샷, Audio - 274_sc.txt'	 br2_316_sc.txt       'im Audio - 5.txt'
# '스크린샷, Audio - 275_sc.png'	 br2_316.txt	      'im Audio - 62.png'
# '스크린샷, Audio - 275_sc.txt'	 br2_317.png	      'im Audio - 62.txt'
# '스크린샷, Audio - 276_sc.png'	 br2_317_sc.png       'im Audio - 63.png'
# '스크린샷, Audio - 276_sc.txt'	 br2_317_sc.txt       'im Audio - 63.txt'
# '스크린샷, Audio - 277_sc.png'	 br2_317.txt	      'im Audio - 64.png'
# '스크린샷, Audio - 277_sc.txt'	 br2_318.png	      'im Audio - 64.txt'
# '스크린샷, Audio - 278_sc.png'	 br2_318_sc.png       'im Audio - 65.png'
# '스크린샷, Audio - 278_sc.txt'	 br2_318_sc.txt       'im Audio - 65.txt'
# '스크린샷, Audio - 279_sc.png'	 br2_318.txt	      'im Audio - 66.png'
# '스크린샷, Audio - 279_sc.txt'	 br2_319.png	      'im Audio - 66.txt'
# '스크린샷, Audio - 27_sc.png'	 br2_319_sc.png       'im Audio - 67.png'
# '스크린샷, Audio - 27_sc.txt'	 br2_319_sc.txt       'im Audio - 67.txt'
# '스크린샷, Audio - 280_sc.png'	 br2_319.txt	      'im Audio - 68.png'
# '스크린샷, Audio - 280_sc.txt'	 br2_31.png	      'im Audio - 68.txt'
# '스크린샷, Audio - 281_sc.png'	 br2_31_sc.png	      'im Audio - 69.png'
# '스크린샷, Audio - 281_sc.txt'	 br2_31_sc.txt	      'im Audio - 69.txt'
# '스크린샷, Audio - 282_sc.png'	 br2_31.txt	      'im Audio - 6.png'
# '스크린샷, Audio - 282_sc.txt'	 br2_320.png	      'im Audio - 6.txt'
# '스크린샷, Audio - 283_sc.png'	 br2_320_sc.png       'im Audio - 70.png'
# '스크린샷, Audio - 283_sc.txt'	 br2_320_sc.txt       'im Audio - 70.txt'
# '스크린샷, Audio - 284_sc.png'	 br2_320.txt	      'im Audio - 71.png'
# '스크린샷, Audio - 284_sc.txt'	 br2_321.png	      'im Audio - 71.txt'
# '스크린샷, Audio - 285_sc.png'	 br2_321_sc.png       'im Audio - 72.png'
# '스크린샷, Audio - 285_sc.txt'	 br2_321_sc.txt       'im Audio - 72.txt'
# '스크린샷, Audio - 286_sc.png'	 br2_321.txt	      'im Audio - 74.png'
# '스크린샷, Audio - 286_sc.txt'	 br2_322.png	      'im Audio - 74.txt'
# '스크린샷, Audio - 287_sc.png'	 br2_322_sc.png       'im Audio - 76.png'
# '스크린샷, Audio - 287_sc.txt'	 br2_322_sc.txt       'im Audio - 76.txt'
# '스크린샷, Audio - 288_sc.png'	 br2_322.txt	      'im Audio - 78.png'
# '스크린샷, Audio - 288_sc.txt'	 br2_323.png	      'im Audio - 78.txt'
# '스크린샷, Audio - 289_sc.png'	 br2_323_sc.png       'im Audio - 79.png'
# '스크린샷, Audio - 289_sc.txt'	 br2_323_sc.txt       'im Audio - 79.txt'
# '스크린샷, Audio - 28_sc.png'	 br2_323.txt	      'im Audio - 81.png'
# '스크린샷, Audio - 28_sc.txt'	 br2_324.png	      'im Audio - 81.txt'
# '스크린샷, Audio - 290_sc.png'	 br2_324_sc.png       'im Audio - 82.png'
# '스크린샷, Audio - 290_sc.txt'	 br2_324_sc.txt       'im Audio - 82.txt'
# '스크린샷, Audio - 291_sc.png'	 br2_324.txt	      'im Audio - 83.png'
# '스크린샷, Audio - 291_sc.txt'	 br2_325.png	      'im Audio - 83.txt'
# '스크린샷, Audio - 292_sc.png'	 br2_325_sc.png       'im Audio - 84.png'
# '스크린샷, Audio - 292_sc.txt'	 br2_325_sc.txt       'im Audio - 84.txt'
# '스크린샷, Audio - 293_sc.png'	 br2_325.txt	      'im Audio - 85.png'
# '스크린샷, Audio - 293_sc.txt'	 br2_326.png	      'im Audio - 85.txt'
# '스크린샷, Audio - 294_sc.png'	 br2_326_sc.png       'im Audio - 87.png'
# '스크린샷, Audio - 294_sc.txt'	 br2_326_sc.txt       'im Audio - 87.txt'
# '스크린샷, Audio - 295_sc.png'	 br2_326.txt	      'im Audio - 88.png'
# '스크린샷, Audio - 295_sc.txt'	 br2_327.png	      'im Audio - 88.txt'
# '스크린샷, Audio - 296_sc.png'	 br2_327_sc.png       'im Audio - 8.png'
# '스크린샷, Audio - 296_sc.txt'	 br2_327_sc.txt       'im Audio - 8.txt'
# '스크린샷, Audio - 297_sc.png'	 br2_327.txt	      'im Audio - 91.png'
# '스크린샷, Audio - 297_sc.txt'	 br2_328.png	      'im Audio - 91.txt'
# '스크린샷, Audio - 298_sc.png'	 br2_328_sc.png       'im Audio - 93.png'
# '스크린샷, Audio - 298_sc.txt'	 br2_328_sc.txt       'im Audio - 93.txt'
# '스크린샷, Audio - 299_sc.png'	 br2_328.txt	      'im Audio - 94.png'
# '스크린샷, Audio - 299_sc.txt'	 br2_329.png	      'im Audio - 94.txt'
# '스크린샷, Audio - 29_sc.png'	 br2_329_sc.png       'im Audio - 95.png'
# '스크린샷, Audio - 29_sc.txt'	 br2_329_sc.txt       'im Audio - 95.txt'
# '스크린샷, Audio - 2_sc.png'	 br2_329.txt	      'im Audio - 96.png'
# '스크린샷, Audio - 2_sc.txt'	 br2_32.png	      'im Audio - 96.txt'
# '스크린샷, Audio - 300_sc.png'	 br2_32_sc.png	      'im Audio - 97.png'
# '스크린샷, Audio - 300_sc.txt'	 br2_32_sc.txt	      'im Audio - 97.txt'
# '스크린샷, Audio - 301_sc.png'	 br2_32.txt	      'im Audio - 98.png'
# '스크린샷, Audio - 301_sc.txt'	 br2_330.png	      'im Audio - 98.txt'
# '스크린샷, Audio - 302_sc.png'	 br2_330_sc.png       'im Audio - 99.png'
# '스크린샷, Audio - 302_sc.txt'	 br2_330_sc.txt       'im Audio - 99.txt'
# '스크린샷, Audio - 303_sc.png'	 br2_330.txt	      'im Audio - 9.png'
# '스크린샷, Audio - 303_sc.txt'	 br2_331.png	      'im Audio - 9.txt'
# '스크린샷, Audio - 304_sc.png'	 br2_331_sc.png       'im Audio.png'
# '스크린샷, Audio - 304_sc.txt'	 br2_331_sc.txt       'im Audio.txt'
# '스크린샷, Audio - 305_sc.png'	 br2_331.txt	       paper.zip
# '스크린샷, Audio - 305_sc.txt'	 br2_332.png	       r_br1_100.png
# '스크린샷, Audio - 306_sc.png'	 br2_332_sc.png        r_br1_100.txt
# '스크린샷, Audio - 306_sc.txt'	 br2_332_sc.txt        r_br1_101.png
# '스크린샷, Audio - 307_sc.png'	 br2_332.txt	       r_br1_101.txt
# '스크린샷, Audio - 307_sc.txt'	 br2_333.png	       r_br1_102.png
# '스크린샷, Audio - 308_sc.png'	 br2_333_sc.png        r_br1_102.txt
# '스크린샷, Audio - 308_sc.txt'	 br2_333_sc.txt        r_br1_103.png
# '스크린샷, Audio - 309_sc.png'	 br2_333.txt	       r_br1_103.txt
# '스크린샷, Audio - 309_sc.txt'	 br2_334.png	       r_br1_104.png
# '스크린샷, Audio - 30_sc.png'	 br2_334_sc.png        r_br1_104.txt
# '스크린샷, Audio - 30_sc.txt'	 br2_334_sc.txt        r_br1_105.png
# '스크린샷, Audio - 310_sc.png'	 br2_334.txt	       r_br1_105.txt
# '스크린샷, Audio - 310_sc.txt'	 br2_335.png	       r_br1_106.png
# '스크린샷, Audio - 311_sc.png'	 br2_335_sc.png        r_br1_106.txt
# '스크린샷, Audio - 311_sc.txt'	 br2_335_sc.txt        r_br1_107.png
# '스크린샷, Audio - 312_sc.png'	 br2_335.txt	       r_br1_107.txt
# '스크린샷, Audio - 312_sc.txt'	 br2_336.png	       r_br1_108.png
# '스크린샷, Audio - 313_sc.png'	 br2_336_sc.png        r_br1_108.txt
# '스크린샷, Audio - 313_sc.txt'	 br2_336_sc.txt        r_br1_109.png
# '스크린샷, Audio - 314_sc.png'	 br2_336.txt	       r_br1_109.txt
# '스크린샷, Audio - 314_sc.txt'	 br2_337.png	       r_br1_10.png
# '스크린샷, Audio - 315_sc.png'	 br2_337_sc.png        r_br1_10.txt
# '스크린샷, Audio - 315_sc.txt'	 br2_337_sc.txt        r_br1_110.png
# '스크린샷, Audio - 316_sc.png'	 br2_337.txt	       r_br1_110.txt
# '스크린샷, Audio - 316_sc.txt'	 br2_338.png	       r_br1_111.png
# '스크린샷, Audio - 317_sc.png'	 br2_338_sc.png        r_br1_111.txt
# '스크린샷, Audio - 317_sc.txt'	 br2_338_sc.txt        r_br1_112.png
# '스크린샷, Audio - 318_sc.png'	 br2_338.txt	       r_br1_112.txt
# '스크린샷, Audio - 318_sc.txt'	 br2_339.png	       r_br1_113.png
# '스크린샷, Audio - 319_sc.png'	 br2_339_sc.png        r_br1_113.txt
# '스크린샷, Audio - 319_sc.txt'	 br2_339_sc.txt        r_br1_114.png
# '스크린샷, Audio - 31_sc.png'	 br2_339.txt	       r_br1_114.txt
# '스크린샷, Audio - 31_sc.txt'	 br2_33.png	       r_br1_115.png
# '스크린샷, Audio - 320_sc.png'	 br2_33_sc.png	       r_br1_115.txt
# '스크린샷, Audio - 320_sc.txt'	 br2_33_sc.txt	       r_br1_116.png
# '스크린샷, Audio - 321_sc.png'	 br2_33.txt	       r_br1_116.txt
# '스크린샷, Audio - 321_sc.txt'	 br2_340.png	       r_br1_117.png
# '스크린샷, Audio - 322_sc.png'	 br2_340_sc.png        r_br1_117.txt
# '스크린샷, Audio - 322_sc.txt'	 br2_340_sc.txt        r_br1_118.png
# '스크린샷, Audio - 323_sc.png'	 br2_340.txt	       r_br1_118.txt
# '스크린샷, Audio - 323_sc.txt'	 br2_341.png	       r_br1_119.png
# '스크린샷, Audio - 324_sc.png'	 br2_341_sc.png        r_br1_119.txt
# '스크린샷, Audio - 324_sc.txt'	 br2_341_sc.txt        r_br1_11.png
# '스크린샷, Audio - 325_sc.png'	 br2_341.txt	       r_br1_11.txt
# '스크린샷, Audio - 325_sc.txt'	 br2_342.png	       r_br1_120.png
# '스크린샷, Audio - 326_sc.png'	 br2_342_sc.png        r_br1_120.txt
# '스크린샷, Audio - 326_sc.txt'	 br2_342_sc.txt        r_br1_121.png
# '스크린샷, Audio - 327_sc.png'	 br2_342.txt	       r_br1_121.txt
# '스크린샷, Audio - 327_sc.txt'	 br2_343.png	       r_br1_122.png
# '스크린샷, Audio - 328_sc.png'	 br2_343_sc.png        r_br1_122.txt
# '스크린샷, Audio - 328_sc.txt'	 br2_343_sc.txt        r_br1_123.png
# '스크린샷, Audio - 329_sc.png'	 br2_343.txt	       r_br1_123.txt
# '스크린샷, Audio - 329_sc.txt'	 br2_344.png	       r_br1_124.png
# '스크린샷, Audio - 32_sc.png'	 br2_344_sc.png        r_br1_124.txt
# '스크린샷, Audio - 32_sc.txt'	 br2_344_sc.txt        r_br1_125.png
# '스크린샷, Audio - 330_sc.png'	 br2_344.txt	       r_br1_125.txt
# '스크린샷, Audio - 330_sc.txt'	 br2_345.png	       r_br1_126.png
# '스크린샷, Audio - 331_sc.png'	 br2_345_sc.png        r_br1_126.txt
# '스크린샷, Audio - 331_sc.txt'	 br2_345_sc.txt        r_br1_127.png
# '스크린샷, Audio - 332_sc.png'	 br2_345.txt	       r_br1_127.txt
# '스크린샷, Audio - 332_sc.txt'	 br2_346.png	       r_br1_128.png
# '스크린샷, Audio - 333_sc.png'	 br2_346_sc.png        r_br1_128.txt
# '스크린샷, Audio - 333_sc.txt'	 br2_346_sc.txt        r_br1_129.png
# '스크린샷, Audio - 334_sc.png'	 br2_346.txt	       r_br1_129.txt
# '스크린샷, Audio - 334_sc.txt'	 br2_347.png	       r_br1_12.png
# '스크린샷, Audio - 335_sc.png'	 br2_347_sc.png        r_br1_12.txt
# '스크린샷, Audio - 335_sc.txt'	 br2_347_sc.txt        r_br1_130.png
# '스크린샷, Audio - 336_sc.png'	 br2_347.txt	       r_br1_130.txt
# '스크린샷, Audio - 336_sc.txt'	 br2_348.png	       r_br1_131.png
# '스크린샷, Audio - 337_sc.png'	 br2_348_sc.png        r_br1_131.txt
# '스크린샷, Audio - 337_sc.txt'	 br2_348_sc.txt        r_br1_132.png
# '스크린샷, Audio - 338_sc.png'	 br2_348.txt	       r_br1_132.txt
# '스크린샷, Audio - 338_sc.txt'	 br2_349.png	       r_br1_133.png
# '스크린샷, Audio - 339_sc.png'	 br2_349_sc.png        r_br1_133.txt
# '스크린샷, Audio - 339_sc.txt'	 br2_349_sc.txt        r_br1_134.png
# '스크린샷, Audio - 33_sc.png'	 br2_349.txt	       r_br1_134.txt
# '스크린샷, Audio - 33_sc.txt'	 br2_34.png	       r_br1_135.png
# '스크린샷, Audio - 340_sc.png'	 br2_34_sc.png	       r_br1_135.txt
# '스크린샷, Audio - 340_sc.txt'	 br2_34_sc.txt	       r_br1_136.png
# '스크린샷, Audio - 341_sc.png'	 br2_34.txt	       r_br1_136.txt
# '스크린샷, Audio - 341_sc.txt'	 br2_350.png	       r_br1_137.png
# '스크린샷, Audio - 342_sc.png'	 br2_350_sc.png        r_br1_137.txt
# '스크린샷, Audio - 342_sc.txt'	 br2_350_sc.txt        r_br1_138.png
# '스크린샷, Audio - 343_sc.png'	 br2_350.txt	       r_br1_138.txt
# '스크린샷, Audio - 343_sc.txt'	 br2_351.png	       r_br1_139.png
# '스크린샷, Audio - 344_sc.png'	 br2_351_sc.png        r_br1_139.txt
# '스크린샷, Audio - 344_sc.txt'	 br2_351_sc.txt        r_br1_13.png
# '스크린샷, Audio - 345_sc.png'	 br2_351.txt	       r_br1_13.txt
# '스크린샷, Audio - 345_sc.txt'	 br2_352.png	       r_br1_140.png
# '스크린샷, Audio - 346_sc.png'	 br2_352_sc.png        r_br1_140.txt
# '스크린샷, Audio - 346_sc.txt'	 br2_352_sc.txt        r_br1_141.png
# '스크린샷, Audio - 347_sc.png'	 br2_352.txt	       r_br1_141.txt
# '스크린샷, Audio - 347_sc.txt'	 br2_353.png	       r_br1_142.png
# '스크린샷, Audio - 348_sc.png'	 br2_353_sc.png        r_br1_142.txt
# '스크린샷, Audio - 348_sc.txt'	 br2_353_sc.txt        r_br1_143.png
# '스크린샷, Audio - 349_sc.png'	 br2_353.txt	       r_br1_143.txt
# '스크린샷, Audio - 349_sc.txt'	 br2_354.png	       r_br1_144.png
# '스크린샷, Audio - 34_sc.png'	 br2_354_sc.png        r_br1_144.txt
# '스크린샷, Audio - 34_sc.txt'	 br2_354_sc.txt        r_br1_145.png
# '스크린샷, Audio - 350_sc.png'	 br2_354.txt	       r_br1_145.txt
# '스크린샷, Audio - 350_sc.txt'	 br2_355.png	       r_br1_146.png
# '스크린샷, Audio - 351_sc.png'	 br2_355_sc.png        r_br1_146.txt
# '스크린샷, Audio - 351_sc.txt'	 br2_355_sc.txt        r_br1_147.png
# '스크린샷, Audio - 352_sc.png'	 br2_355.txt	       r_br1_147.txt
# '스크린샷, Audio - 352_sc.txt'	 br2_356.png	       r_br1_148.png
# '스크린샷, Audio - 353_sc.png'	 br2_356_sc.png        r_br1_148.txt
# '스크린샷, Audio - 353_sc.txt'	 br2_356_sc.txt        r_br1_149.png
# '스크린샷, Audio - 354_sc.png'	 br2_356.txt	       r_br1_149.txt
# '스크린샷, Audio - 354_sc.txt'	 br2_357.png	       r_br1_14.png
# '스크린샷, Audio - 355_sc.png'	 br2_357_sc.png        r_br1_14.txt
# '스크린샷, Audio - 355_sc.txt'	 br2_357_sc.txt        r_br1_150.png
# '스크린샷, Audio - 356_sc.png'	 br2_357.txt	       r_br1_150.txt
# '스크린샷, Audio - 356_sc.txt'	 br2_358.png	       r_br1_151.png
# '스크린샷, Audio - 357_sc.png'	 br2_358_sc.png        r_br1_151.txt
# '스크린샷, Audio - 357_sc.txt'	 br2_358_sc.txt        r_br1_152.png
# '스크린샷, Audio - 358_sc.png'	 br2_358.txt	       r_br1_152.txt
# '스크린샷, Audio - 358_sc.txt'	 br2_359.png	       r_br1_153.png
# '스크린샷, Audio - 359_sc.png'	 br2_359_sc.png        r_br1_153.txt
# '스크린샷, Audio - 359_sc.txt'	 br2_359_sc.txt        r_br1_154.png
# '스크린샷, Audio - 35_sc.png'	 br2_359.txt	       r_br1_154.txt
# '스크린샷, Audio - 35_sc.txt'	 br2_35.png	       r_br1_155.png
# '스크린샷, Audio - 360_sc.png'	 br2_35_sc.png	       r_br1_155.txt
# '스크린샷, Audio - 360_sc.txt'	 br2_35_sc.txt	       r_br1_156.png
# '스크린샷, Audio - 361_sc.png'	 br2_35.txt	       r_br1_156.txt
# '스크린샷, Audio - 361_sc.txt'	 br2_360.png	       r_br1_157.png
# '스크린샷, Audio - 362_sc.png'	 br2_360_sc.png        r_br1_157.txt
# '스크린샷, Audio - 362_sc.txt'	 br2_360_sc.txt        r_br1_158.png
# '스크린샷, Audio - 363_sc.png'	 br2_360.txt	       r_br1_158.txt
# '스크린샷, Audio - 363_sc.txt'	 br2_361.png	       r_br1_159.png
# '스크린샷, Audio - 364_sc.png'	 br2_361_sc.png        r_br1_159.txt
# '스크린샷, Audio - 364_sc.txt'	 br2_361_sc.txt        r_br1_15.png
# '스크린샷, Audio - 365_sc.png'	 br2_361.txt	       r_br1_15.txt
# '스크린샷, Audio - 365_sc.txt'	 br2_362.png	       r_br1_160.png
# '스크린샷, Audio - 366_sc.png'	 br2_362_sc.png        r_br1_160.txt
# '스크린샷, Audio - 366_sc.txt'	 br2_362_sc.txt        r_br1_161.png
# '스크린샷, Audio - 367_sc.png'	 br2_362.txt	       r_br1_161.txt
# '스크린샷, Audio - 367_sc.txt'	 br2_363.png	       r_br1_162.png
# '스크린샷, Audio - 368_sc.png'	 br2_363_sc.png        r_br1_162.txt
# '스크린샷, Audio - 368_sc.txt'	 br2_363_sc.txt        r_br1_163.png
# '스크린샷, Audio - 369_sc.png'	 br2_363.txt	       r_br1_163.txt
# '스크린샷, Audio - 369_sc.txt'	 br2_364.png	       r_br1_164.png
# '스크린샷, Audio - 36_sc.png'	 br2_364_sc.png        r_br1_164.txt
# '스크린샷, Audio - 36_sc.txt'	 br2_364_sc.txt        r_br1_165.png
# '스크린샷, Audio - 370_sc.png'	 br2_364.txt	       r_br1_165.txt
# '스크린샷, Audio - 370_sc.txt'	 br2_365.png	       r_br1_166.png
# '스크린샷, Audio - 371_sc.png'	 br2_365_sc.png        r_br1_166.txt
# '스크린샷, Audio - 371_sc.txt'	 br2_365_sc.txt        r_br1_167.png
# '스크린샷, Audio - 372_sc.png'	 br2_365.txt	       r_br1_167.txt
# '스크린샷, Audio - 372_sc.txt'	 br2_366.png	       r_br1_168.png
# '스크린샷, Audio - 373_sc.png'	 br2_366_sc.png        r_br1_168.txt
# '스크린샷, Audio - 373_sc.txt'	 br2_366_sc.txt        r_br1_169.png
# '스크린샷, Audio - 374_sc.png'	 br2_366.txt	       r_br1_169.txt
# '스크린샷, Audio - 374_sc.txt'	 br2_367.png	       r_br1_16.png
# '스크린샷, Audio - 375_sc.png'	 br2_367_sc.png        r_br1_16.txt
# '스크린샷, Audio - 375_sc.txt'	 br2_367_sc.txt        r_br1_170.png
# '스크린샷, Audio - 376_sc.png'	 br2_367.txt	       r_br1_170.txt
# '스크린샷, Audio - 376_sc.txt'	 br2_368.png	       r_br1_171.png
# '스크린샷, Audio - 377_sc.png'	 br2_368_sc.png        r_br1_171.txt
# '스크린샷, Audio - 377_sc.txt'	 br2_368_sc.txt        r_br1_172.png
# '스크린샷, Audio - 378_sc.png'	 br2_368.txt	       r_br1_172.txt
# '스크린샷, Audio - 378_sc.txt'	 br2_369.png	       r_br1_173.png
# '스크린샷, Audio - 379_sc.png'	 br2_369_sc.png        r_br1_173.txt
# '스크린샷, Audio - 379_sc.txt'	 br2_369_sc.txt        r_br1_174.png
# '스크린샷, Audio - 37_sc.png'	 br2_369.txt	       r_br1_174.txt
# '스크린샷, Audio - 37_sc.txt'	 br2_36.png	       r_br1_175.png
# '스크린샷, Audio - 380_sc.png'	 br2_36_sc.png	       r_br1_175.txt
# '스크린샷, Audio - 380_sc.txt'	 br2_36_sc.txt	       r_br1_176.png
# '스크린샷, Audio - 381_sc.png'	 br2_36.txt	       r_br1_176.txt
# '스크린샷, Audio - 381_sc.txt'	 br2_370.png	       r_br1_177.png
# '스크린샷, Audio - 382_sc.png'	 br2_370_sc.png        r_br1_177.txt
# '스크린샷, Audio - 382_sc.txt'	 br2_370_sc.txt        r_br1_178.png
# '스크린샷, Audio - 383_sc.png'	 br2_370.txt	       r_br1_178.txt
# '스크린샷, Audio - 383_sc.txt'	 br2_371.png	       r_br1_179.png
# '스크린샷, Audio - 384_sc.png'	 br2_371_sc.png        r_br1_179.txt
# '스크린샷, Audio - 384_sc.txt'	 br2_371_sc.txt        r_br1_17.png
# '스크린샷, Audio - 385_sc.png'	 br2_371.txt	       r_br1_17.txt
# '스크린샷, Audio - 385_sc.txt'	 br2_372.png	       r_br1_180.png
# '스크린샷, Audio - 386_sc.png'	 br2_372_sc.png        r_br1_180.txt
# '스크린샷, Audio - 386_sc.txt'	 br2_372_sc.txt        r_br1_181.png
# '스크린샷, Audio - 387_sc.png'	 br2_372.txt	       r_br1_181.txt
# '스크린샷, Audio - 387_sc.txt'	 br2_373.png	       r_br1_182.png
# '스크린샷, Audio - 388_sc.png'	 br2_373_sc.png        r_br1_182.txt
# '스크린샷, Audio - 388_sc.txt'	 br2_373_sc.txt        r_br1_183.png
# '스크린샷, Audio - 389_sc.png'	 br2_373.txt	       r_br1_183.txt
# '스크린샷, Audio - 389_sc.txt'	 br2_374.png	       r_br1_184.png
# '스크린샷, Audio - 38_sc.png'	 br2_374_sc.png        r_br1_184.txt
# '스크린샷, Audio - 38_sc.txt'	 br2_374_sc.txt        r_br1_185.png
# '스크린샷, Audio - 390_sc.png'	 br2_374.txt	       r_br1_185.txt
# '스크린샷, Audio - 390_sc.txt'	 br2_375.png	       r_br1_186.png
# '스크린샷, Audio - 391_sc.png'	 br2_375_sc.png        r_br1_186.txt
# '스크린샷, Audio - 391_sc.txt'	 br2_375_sc.txt        r_br1_187.png
# '스크린샷, Audio - 392_sc.png'	 br2_375.txt	       r_br1_187.txt
# '스크린샷, Audio - 392_sc.txt'	 br2_376.png	       r_br1_188.png
# '스크린샷, Audio - 393_sc.png'	 br2_376_sc.png        r_br1_188.txt
# '스크린샷, Audio - 393_sc.txt'	 br2_376_sc.txt        r_br1_189.png
# '스크린샷, Audio - 394_sc.png'	 br2_376.txt	       r_br1_189.txt
# '스크린샷, Audio - 394_sc.txt'	 br2_377.png	       r_br1_18.png
# '스크린샷, Audio - 395_sc.png'	 br2_377_sc.png        r_br1_18.txt
# '스크린샷, Audio - 395_sc.txt'	 br2_377_sc.txt        r_br1_190.png
# '스크린샷, Audio - 396_sc.png'	 br2_377.txt	       r_br1_190.txt
# '스크린샷, Audio - 396_sc.txt'	 br2_378.png	       r_br1_191.png
# '스크린샷, Audio - 397_sc.png'	 br2_378_sc.png        r_br1_191.txt
# '스크린샷, Audio - 397_sc.txt'	 br2_378_sc.txt        r_br1_192.png
# '스크린샷, Audio - 398_sc.png'	 br2_378.txt	       r_br1_192.txt
# '스크린샷, Audio - 398_sc.txt'	 br2_379.png	       r_br1_193.png
# '스크린샷, Audio - 399_sc.png'	 br2_379_sc.png        r_br1_193.txt
# '스크린샷, Audio - 399_sc.txt'	 br2_379_sc.txt        r_br1_194.png
# '스크린샷, Audio - 39_sc.png'	 br2_379.txt	       r_br1_194.txt
# '스크린샷, Audio - 39_sc.txt'	 br2_37.png	       r_br1_195.png
# '스크린샷, Audio - 3_sc.png'	 br2_37_sc.png	       r_br1_195.txt
# ...
#  br2_164.txt			'im Audio - 142.png'  'r_rr - 135.png'
#  br2_165.png			'im Audio - 142.txt'  'r_rr - 135.txt'
#  br2_165_sc.png			'im Audio - 144.png'  'r_rr - 136.png'
#  br2_165_sc.txt			'im Audio - 144.txt'  'r_rr - 136.txt'
#  br2_165.txt			'im Audio - 145.png'  'r_rr - 137.png'
#  br2_166.png			'im Audio - 145.txt'  'r_rr - 137.txt'
#  br2_166_sc.png			'im Audio - 146.png'  'r_rr - 138.png'
#  br2_166_sc.txt			'im Audio - 146.txt'  'r_rr - 138.txt'
#  br2_166.txt			'im Audio - 147.png'  'r_rr - 139.png'
#  br2_167.png			'im Audio - 147.txt'  'r_rr - 139.txt'
#  br2_167_sc.png			'im Audio - 148.png'  'r_rr - 140.png'
#  br2_167_sc.txt			'im Audio - 148.txt'  'r_rr - 140.txt'
#  br2_167.txt			'im Audio - 149.png'  'r_rr - 143.png'
#  br2_168.png			'im Audio - 149.txt'  'r_rr - 143.txt'
#  br2_168_sc.png			'im Audio - 150.png'  'r_rr - 155.png'
#  br2_168_sc.txt			'im Audio - 150.txt'  'r_rr - 155.txt'
#  br2_168.txt			'im Audio - 152.png'  'r_rr - 156.png'
#  br2_169.png			'im Audio - 152.txt'  'r_rr - 156.txt'
#  br2_169_sc.png			'im Audio - 156.png'  'r_rr - 157.png'
#  br2_169_sc.txt			'im Audio - 156.txt'  'r_rr - 157.txt'
#  br2_169.txt			'im Audio - 157.png'  'r_rr - 158.png'
#  br2_16.png			'im Audio - 157.txt'  'r_rr - 158.txt'
#  br2_16_sc.png			'im Audio - 158.png'  'r_rr - 166.png'
#  br2_16_sc.txt			'im Audio - 158.txt'  'r_rr - 166.txt'
#  br2_16.txt			'im Audio - 159.png'  'r_rr - 167.png'
#  br2_170.png			'im Audio - 159.txt'  'r_rr - 167.txt'
#  br2_170_sc.png			'im Audio - 160.png'  'r_rr - 168.png'
#  br2_170_sc.txt			'im Audio - 160.txt'  'r_rr - 168.txt'
#  br2_170.txt			'im Audio - 161.png'  'r_rr - 169.png'
#  br2_171.png			'im Audio - 161.txt'  'r_rr - 169.txt'
#  br2_171_sc.png			'im Audio - 162.png'  'r_rr - 170.png'
#  br2_171_sc.txt			'im Audio - 162.txt'  'r_rr - 170.txt'
#  br2_171.txt			'im Audio - 163.png'  'r_rr - 176.png'
#  br2_172.png			'im Audio - 163.txt'  'r_rr - 176.txt'
#  br2_172_sc.png			'im Audio - 164.png'  'r_rr - 177.png'
#  br2_172_sc.txt			'im Audio - 164.txt'  'r_rr - 177.txt'
#  br2_172.txt			'im Audio - 165.png'  'r_rr - 178.png'
#  br2_173.png			'im Audio - 165.txt'  'r_rr - 178.txt'
#  br2_173_sc.png			'im Audio - 166.png'  'r_rr - 179.png'
#  br2_173_sc.txt			'im Audio - 166.txt'  'r_rr - 179.txt'
#  br2_173.txt			'im Audio - 167.png'  'r_rr - 180.png'
#  br2_174.png			'im Audio - 167.txt'  'r_rr - 180.txt'
#  br2_174_sc.png			'im Audio - 168.png'  'r_rr - 181.png'
#  br2_174_sc.txt			'im Audio - 168.txt'  'r_rr - 181.txt'
#  br2_174.txt			'im Audio - 169.png'  'r_rr - 182.png'
#  br2_175.png			'im Audio - 169.txt'  'r_rr - 182.txt'
#  br2_175_sc.png			'im Audio - 16.png'   'r_rr - 191.png'
#  br2_175_sc.txt			'im Audio - 16.txt'   'r_rr - 191.txt'
#  br2_175.txt			'im Audio - 170.png'  'r_rr - 197.png'
#  br2_176.png			'im Audio - 170.txt'  'r_rr - 197.txt'
#  br2_176_sc.png			'im Audio - 171.png'  'r_rr - 1.png'
#  br2_176_sc.txt			'im Audio - 171.txt'  'r_rr - 1.txt'
#  br2_176.txt			'im Audio - 172.png'  'r_rr - 206.png'
#  br2_177.png			'im Audio - 172.txt'  'r_rr - 206.txt'
#  br2_177_sc.png			'im Audio - 173.png'  'r_rr - 207.png'
#  br2_177_sc.txt			'im Audio - 173.txt'  'r_rr - 207.txt'
#  br2_177.txt			'im Audio - 174.png'  'r_rr - 208.png'
#  br2_178.png			'im Audio - 174.txt'  'r_rr - 208.txt'
#  br2_178_sc.png			'im Audio - 175.png'  'r_rr - 210.png'
#  br2_178_sc.txt			'im Audio - 175.txt'  'r_rr - 210.txt'
#  br2_178.txt			'im Audio - 176.png'  'r_rr - 212.png'
#  br2_179.png			'im Audio - 176.txt'  'r_rr - 212.txt'
#  br2_179_sc.png			'im Audio - 177.png'  'r_rr - 213.png'
#  br2_179_sc.txt			'im Audio - 177.txt'  'r_rr - 213.txt'
#  br2_179.txt			'im Audio - 178.png'  'r_rr - 217.png'
#  br2_17.png			'im Audio - 178.txt'  'r_rr - 217.txt'
#  br2_17_sc.png			'im Audio - 179.png'  'r_rr - 218.png'
#  br2_17_sc.txt			'im Audio - 179.txt'  'r_rr - 218.txt'
#  br2_17.txt			'im Audio - 17.png'   'r_rr - 224.png'
#  br2_180.png			'im Audio - 17.txt'   'r_rr - 224.txt'
#  br2_180_sc.png			'im Audio - 180.png'  'r_rr - 230.png'
#  br2_180_sc.txt			'im Audio - 180.txt'  'r_rr - 230.txt'
#  br2_180.txt			'im Audio - 181.png'  'r_rr - 231.png'
#  br2_181.png			'im Audio - 181.txt'  'r_rr - 231.txt'
#  br2_181_sc.png			'im Audio - 183.png'  'r_rr - 232.png'
#  br2_181_sc.txt			'im Audio - 183.txt'  'r_rr - 232.txt'
#  br2_181.txt			'im Audio - 184.png'  'r_rr - 233.png'
#  br2_182.png			'im Audio - 184.txt'  'r_rr - 233.txt'
#  br2_182_sc.png			'im Audio - 185.png'  'r_rr - 234.png'
#  br2_182_sc.txt			'im Audio - 185.txt'  'r_rr - 234.txt'
#  br2_182.txt			'im Audio - 186.png'  'r_rr - 241.png'
#  br2_183.png			'im Audio - 186.txt'  'r_rr - 241.txt'
#  br2_183_sc.png			'im Audio - 187.png'  'r_rr - 25.png'
#  br2_183_sc.txt			'im Audio - 187.txt'  'r_rr - 25.txt'
#  br2_183.txt			'im Audio - 188.png'  'r_rr - 265.png'
#  br2_184.png			'im Audio - 188.txt'  'r_rr - 265.txt'
#  br2_184_sc.png			'im Audio - 189.png'  'r_rr - 268.png'
#  br2_184_sc.txt			'im Audio - 189.txt'  'r_rr - 268.txt'
#  br2_184.txt			'im Audio - 190.png'  'r_rr - 269.png'
#  br2_185.png			'im Audio - 190.txt'  'r_rr - 269.txt'
#  br2_185_sc.png			'im Audio - 191.png'  'r_rr - 26.png'
#  br2_185_sc.txt			'im Audio - 191.txt'  'r_rr - 26.txt'
#  br2_185.txt			'im Audio - 192.png'  'r_rr - 27.png'
#  br2_186.png			'im Audio - 192.txt'  'r_rr - 27.txt'
#  br2_186_sc.png			'im Audio - 193.png'  'r_rr - 28.png'
#  br2_186_sc.txt			'im Audio - 193.txt'  'r_rr - 28.txt'
#  br2_186.txt			'im Audio - 194.png'  'r_rr - 293.png'
#  br2_187.png			'im Audio - 194.txt'  'r_rr - 293.txt'
#  br2_187_sc.png			'im Audio - 195.png'  'r_rr - 294.png'
#  br2_187_sc.txt			'im Audio - 195.txt'  'r_rr - 294.txt'
#  br2_187.txt			'im Audio - 196.png'  'r_rr - 295.png'
#  br2_188.png			'im Audio - 196.txt'  'r_rr - 295.txt'
#  br2_188_sc.png			'im Audio - 197.png'  'r_rr - 296.png'
#  br2_188_sc.txt			'im Audio - 197.txt'  'r_rr - 296.txt'
#  br2_188.txt			'im Audio - 198.png'  'r_rr - 29.png'
#  br2_189.png			'im Audio - 198.txt'  'r_rr - 29.txt'
#  br2_189_sc.png			'im Audio - 199.png'   r_rr-2.png
#  br2_189_sc.txt			'im Audio - 199.txt'   r_rr-2.txt
#  br2_189.txt			'im Audio - 1.png'    'r_rr - 303.png'
#  br2_18.png			'im Audio - 1.txt'    'r_rr - 303.txt'
#  br2_18_sc.png			'im Audio - 200.png'  'r_rr - 30.png'
#  br2_18_sc.txt			'im Audio - 200.txt'  'r_rr - 30.txt'
#  br2_18.txt			'im Audio - 201.png'  'r_rr - 31.png'
#  br2_190.png			'im Audio - 201.txt'  'r_rr - 31.txt'
#  br2_190_sc.png			'im Audio - 203.png'  'r_rr - 324.png'
#  br2_190_sc.txt			'im Audio - 203.txt'  'r_rr - 324.txt'
#  br2_190.txt			'im Audio - 204.png'  'r_rr - 331.png'
#  br2_191.png			'im Audio - 204.txt'  'r_rr - 331.txt'
#  br2_191_sc.png			'im Audio - 205.png'  'r_rr - 335.png'
#  br2_191_sc.txt			'im Audio - 205.txt'  'r_rr - 335.txt'
#  br2_191.txt			'im Audio - 206.png'  'r_rr - 33.png'
#  br2_192.png			'im Audio - 206.txt'  'r_rr - 33.txt'
#  br2_192_sc.png			'im Audio - 207.png'  'r_rr - 340.png'
#  br2_192_sc.txt			'im Audio - 207.txt'  'r_rr - 340.txt'
#  br2_192.txt			'im Audio - 208.png'  'r_rr - 341.png'
#  br2_193.png			'im Audio - 208.txt'  'r_rr - 341.txt'
#  br2_193_sc.png			'im Audio - 209.png'  'r_rr - 342.png'
#  br2_193_sc.txt			'im Audio - 209.txt'  'r_rr - 342.txt'
#  br2_193.txt			'im Audio - 20.png'   'r_rr - 343.png'
#  br2_194.png			'im Audio - 20.txt'   'r_rr - 343.txt'
#  br2_194_sc.png			'im Audio - 210.png'  'r_rr - 344.png'
#  br2_194_sc.txt			'im Audio - 210.txt'  'r_rr - 344.txt'
#  br2_194.txt			'im Audio - 211.png'  'r_rr - 354.png'
#  br2_195.png			'im Audio - 211.txt'  'r_rr - 354.txt'
#  br2_195_sc.png			'im Audio - 212.png'  'r_rr - 359.png'
#  br2_195_sc.txt			'im Audio - 212.txt'  'r_rr - 359.txt'
#  br2_195.txt			'im Audio - 213.png'  'r_rr - 360.png'
#  br2_196.png			'im Audio - 213.txt'  'r_rr - 360.txt'
#  br2_196_sc.png			'im Audio - 214.png'  'r_rr - 361.png'
#  br2_196_sc.txt			'im Audio - 214.txt'  'r_rr - 361.txt'
#  br2_196.txt			'im Audio - 215.png'  'r_rr - 365.png'
#  br2_197.png			'im Audio - 215.txt'  'r_rr - 365.txt'
#  br2_197_sc.png			'im Audio - 216.png'  'r_rr - 366.png'
#  br2_197_sc.txt			'im Audio - 216.txt'  'r_rr - 366.txt'
#  br2_197.txt			'im Audio - 217.png'  'r_rr - 367.png'
#  br2_198.png			'im Audio - 217.txt'  'r_rr - 367.txt'
#  br2_198_sc.png			'im Audio - 218.png'  'r_rr - 374.png'
#  br2_198_sc.txt			'im Audio - 218.txt'  'r_rr - 374.txt'
#  br2_198.txt			'im Audio - 219.png'  'r_rr - 375.png'
#  br2_199.png			'im Audio - 219.txt'  'r_rr - 375.txt'
#  br2_199_sc.png			'im Audio - 21.png'   'r_rr - 376.png'
#  br2_199_sc.txt			'im Audio - 21.txt'   'r_rr - 376.txt'
#  br2_199.txt			'im Audio - 220.png'  'r_rr - 377.png'
#  br2_19.png			'im Audio - 220.txt'  'r_rr - 377.txt'
#  br2_19_sc.png			'im Audio - 221.png'  'r_rr - 378.png'
#  br2_19_sc.txt			'im Audio - 221.txt'  'r_rr - 378.txt'
#  br2_19.txt			'im Audio - 222.png'  'r_rr - 379.png'
#  br2_1.png			'im Audio - 222.txt'  'r_rr - 379.txt'
#  br2_1_sc.png			'im Audio - 223.png'  'r_rr - 388.png'
#  br2_1_sc.txt			'im Audio - 223.txt'  'r_rr - 388.txt'
#  br2_1.txt			'im Audio - 224.png'  'r_rr - 389.png'
#  br2_200.png			'im Audio - 224.txt'  'r_rr - 389.txt'
#  br2_200_sc.png			'im Audio - 225.png'  'r_rr - 390.png'
#  br2_200_sc.txt			'im Audio - 225.txt'  'r_rr - 390.txt'
#  br2_200.txt			'im Audio - 226.png'   r_rr3.png
#  br2_201.png			'im Audio - 226.txt'   r_rr3.txt
#  br2_201_sc.png			'im Audio - 227.png'  'r_rr - 400.png'
#  br2_201_sc.txt			'im Audio - 227.txt'  'r_rr - 400.txt'
#  br2_201.txt			'im Audio - 228.png'  'r_rr - 403.png'
#  br2_202.png			'im Audio - 228.txt'  'r_rr - 403.txt'
#  br2_202_sc.png			'im Audio - 229.png'  'r_rr - 404.png'
#  br2_202_sc.txt			'im Audio - 229.txt'  'r_rr - 404.txt'
#  br2_202.txt			'im Audio - 22.png'   'r_rr - 405.png'
#  br2_203.png			'im Audio - 22.txt'   'r_rr - 405.txt'
#  br2_203_sc.png			'im Audio - 230.png'  'r_rr - 40.png'
#  br2_203_sc.txt			'im Audio - 230.txt'  'r_rr - 40.txt'
#  br2_203.txt			'im Audio - 231.png'  'r_rr - 413.png'
#  br2_204.png			'im Audio - 231.txt'  'r_rr - 413.txt'
#  br2_204_sc.png			'im Audio - 232.png'  'r_rr - 414.png'
#  br2_204_sc.txt			'im Audio - 232.txt'  'r_rr - 414.txt'
#  br2_204.txt			'im Audio - 233.png'  'r_rr - 419.png'
#  br2_205.png			'im Audio - 233.txt'  'r_rr - 419.txt'
#  br2_205_sc.png			'im Audio - 234.png'  'r_rr - 41.png'
#  br2_205_sc.txt			'im Audio - 234.txt'  'r_rr - 41.txt'
#  br2_205.txt			'im Audio - 235.png'  'r_rr - 420.png'
#  br2_206.png			'im Audio - 235.txt'  'r_rr - 420.txt'
#  br2_206_sc.png			'im Audio - 236.png'  'r_rr - 421.png'
#  br2_206_sc.txt			'im Audio - 236.txt'  'r_rr - 421.txt'
#  br2_206.txt			'im Audio - 237.png'  'r_rr - 422.png'
#  br2_207.png			'im Audio - 237.txt'  'r_rr - 422.txt'
#  br2_207_sc.png			'im Audio - 238.png'  'r_rr - 423.png'
#  br2_207_sc.txt			'im Audio - 238.txt'  'r_rr - 423.txt'
#  br2_207.txt			'im Audio - 239.png'  'r_rr - 424.png'
#  br2_208.png			'im Audio - 239.txt'  'r_rr - 424.txt'
#  br2_208_sc.png			'im Audio - 240.png'  'r_rr - 429.png'
#  br2_208_sc.txt			'im Audio - 240.txt'  'r_rr - 429.txt'
#  br2_208.txt			'im Audio - 242.png'  'r_rr - 42.png'
#  br2_209.png			'im Audio - 242.txt'  'r_rr - 42.txt'
#  br2_209_sc.png			'im Audio - 243.png'  'r_rr - 431.png'
#  br2_209_sc.txt			'im Audio - 243.txt'  'r_rr - 431.txt'
#  br2_209.txt			'im Audio - 244.png'  'r_rr - 432.png'
#  br2_20.png			'im Audio - 244.txt'  'r_rr - 432.txt'
#  br2_20_sc.png			'im Audio - 245.png'  'r_rr - 433.png'
#  br2_20_sc.txt			'im Audio - 245.txt'  'r_rr - 433.txt'
#  br2_20.txt			'im Audio - 246.png'  'r_rr - 438.png'
#  br2_210.png			'im Audio - 246.txt'  'r_rr - 438.txt'
#  br2_210_sc.png			'im Audio - 247.png'  'r_rr - 440.png'
#  br2_210_sc.txt			'im Audio - 247.txt'  'r_rr - 440.txt'
#  br2_210.txt			'im Audio - 248.png'  'r_rr - 441.png'
#  br2_211.png			'im Audio - 248.txt'  'r_rr - 441.txt'
#  br2_211_sc.png			'im Audio - 249.png'  'r_rr - 442.png'
#  br2_211_sc.txt			'im Audio - 249.txt'  'r_rr - 442.txt'
#  br2_211.txt			'im Audio - 24.png'   'r_rr - 457.png'
#  br2_212.png			'im Audio - 24.txt'   'r_rr - 457.txt'
#  br2_212_sc.png			'im Audio - 250.png'  'r_rr - 458.png'
#  br2_212_sc.txt			'im Audio - 250.txt'  'r_rr - 458.txt'
#  br2_212.txt			'im Audio - 251.png'  'r_rr - 459.png'
#  br2_213.png			'im Audio - 251.txt'  'r_rr - 459.txt'
#  br2_213_sc.png			'im Audio - 252.png'  'r_rr - 47.png'
#  br2_213_sc.txt			'im Audio - 252.txt'  'r_rr - 47.txt'
#  br2_213.txt			'im Audio - 253.png'  'r_rr - 481.png'
#  br2_214.png			'im Audio - 253.txt'  'r_rr - 481.txt'
#  br2_214_sc.png			'im Audio - 254.png'  'r_rr - 482.png'
#  br2_214_sc.txt			'im Audio - 254.txt'  'r_rr - 482.txt'
#  br2_214.txt			'im Audio - 255.png'  'r_rr - 483.png'
#  br2_215.png			'im Audio - 255.txt'  'r_rr - 483.txt'
#  br2_215_sc.png			'im Audio - 256.png'  'r_rr - 484.png'
#  br2_215_sc.txt			'im Audio - 256.txt'  'r_rr - 484.txt'
#  br2_215.txt			'im Audio - 257.png'  'r_rr - 485.png'
#  br2_216.png			'im Audio - 257.txt'  'r_rr - 485.txt'
#  br2_216_sc.png			'im Audio - 258.png'  'r_rr - 486.png'
#  br2_216_sc.txt			'im Audio - 258.txt'  'r_rr - 486.txt'
#  br2_216.txt			'im Audio - 25.png'   'r_rr - 487.png'
#  br2_217.png			'im Audio - 25.txt'   'r_rr - 487.txt'
#  br2_217_sc.png			'im Audio - 260.png'  'r_rr - 488.png'
#  br2_217_sc.txt			'im Audio - 260.txt'  'r_rr - 488.txt'
#  br2_217.txt			'im Audio - 261.png'  'r_rr - 489.png'
#  br2_218.png			'im Audio - 261.txt'  'r_rr - 489.txt'
#  br2_218_sc.png			'im Audio - 262.png'  'r_rr - 48.png'
#  br2_218_sc.txt			'im Audio - 262.txt'  'r_rr - 48.txt'
#  br2_218.txt			'im Audio - 264.png'  'r_rr - 490.png'
#  br2_219.png			'im Audio - 264.txt'  'r_rr - 490.txt'
#  br2_219_sc.png			'im Audio - 268.png'  'r_rr - 491.png'
#  br2_219_sc.txt			'im Audio - 268.txt'  'r_rr - 491.txt'
#  br2_219.txt			'im Audio - 269.png'  'r_rr - 49.png'
#  br2_21.png			'im Audio - 269.txt'  'r_rr - 49.txt'
#  br2_21_sc.png			'im Audio - 26.png'   'r_rr - 4.png'
#  br2_21_sc.txt			'im Audio - 26.txt'   'r_rr - 4.txt'
#  br2_21.txt			'im Audio - 270.png'  'r_rr - 508.png'
#  br2_220.png			'im Audio - 270.txt'  'r_rr - 508.txt'
#  br2_220_sc.png			'im Audio - 271.png'  'r_rr - 509.png'
#  br2_220_sc.txt			'im Audio - 271.txt'  'r_rr - 509.txt'
#  br2_220.txt			'im Audio - 272.png'  'r_rr - 50.png'
#  br2_221.png			'im Audio - 272.txt'  'r_rr - 50.txt'
#  br2_221_sc.png			'im Audio - 273.png'  'r_rr - 512.png'
#  br2_221_sc.txt			'im Audio - 273.txt'  'r_rr - 512.txt'
#  br2_221.txt			'im Audio - 274.png'  'r_rr - 51.png'
#  br2_222.png			'im Audio - 274.txt'  'r_rr - 51.txt'
#  br2_222_sc.png			'im Audio - 275.png'  'r_rr - 61.png'
#  br2_222_sc.txt			'im Audio - 275.txt'  'r_rr - 61.txt'
#  br2_222.txt			'im Audio - 276.png'  'r_rr - 62.png'
#  br2_223.png			'im Audio - 276.txt'  'r_rr - 62.txt'
#  br2_223_sc.png			'im Audio - 277.png'  'r_rr - 63.png'
#  br2_223_sc.txt			'im Audio - 277.txt'  'r_rr - 63.txt'
#  br2_223.txt			'im Audio - 278.png'  'r_rr - 64.png'
#  br2_224.png			'im Audio - 278.txt'  'r_rr - 64.txt'
#  br2_224_sc.png			'im Audio - 279.png'  'r_rr - 65.png'
#  br2_224_sc.txt			'im Audio - 279.txt'  'r_rr - 65.txt'
#  br2_224.txt			'im Audio - 27.png'   'r_rr - 74.png'
#  br2_225.png			'im Audio - 27.txt'   'r_rr - 74.txt'
#  br2_225_sc.png			'im Audio - 282.png'  'r_rr - 75.png'
#  br2_225_sc.txt			'im Audio - 282.txt'  'r_rr - 75.txt'
#  br2_225.txt			'im Audio - 283.png'  'r_rr - 76.png'
#  br2_226.png			'im Audio - 283.txt'  'r_rr - 76.txt'
#  br2_226_sc.png			'im Audio - 284.png'  'r_rr - 77.png'
#  br2_226_sc.txt			'im Audio - 284.txt'  'r_rr - 77.txt'
#  br2_226.txt			'im Audio - 288.png'  'r_rr - 78.png'
#  br2_227.png			'im Audio - 288.txt'  'r_rr - 78.txt'
#  br2_227_sc.png			'im Audio - 28.png'   'r_rr - 88.png'
#  br2_227_sc.txt			'im Audio - 28.txt'   'r_rr - 88.txt'
#  br2_227.txt			'im Audio - 293.png'  'r_rr - 92.png'
#  br2_228.png			'im Audio - 293.txt'  'r_rr - 92.txt'
#  br2_228_sc.png			'im Audio - 295.png'  'r_rr - 97.png'
#  br2_228_sc.txt			'im Audio - 295.txt'  'r_rr - 97.txt'
#  br2_228.txt			'im Audio - 296.png'  'r_rr - 98.png'
#  br2_229.png			'im Audio - 296.txt'  'r_rr - 98.txt'
#  br2_229_sc.png			'im Audio - 297.png'  'r_rr - 99.png'
#  br2_229_sc.txt			'im Audio - 297.txt'  'r_rr - 99.txt'
#  br2_229.txt			'im Audio - 298.png'   yolo_mark.cmd
#  br2_22.png			'im Audio - 298.txt'

# %% [markdown]
# ### custom dataset을 위해
# ### "custom.data", "yolov4-custom.cfg", "custom.names" 파일을 수정하고 yolov4 폴더에 업로드한다.
#
# 그리고 process.py파일을 yolov4폴더로 업로드한다.

# %%
# %cd /mydrive/Advanced_AI/yolov4/darknet
# Out:
# /content/drive/MyDrive/Advanced_AI/yolov4/darknet

# %% [markdown]
# ### 데이터셋 생성하기

# %% [markdown]
# ### **yolov4-custom.cfg파일 설정**
# **[Training]**
# **batch=64**로 설정한다.<br> 그러나, 데이터셋의 **이미지 크기가 클 경우**,<br> batch=32나 16으로 줄여야 할 수도 있다.  <br><br>
# **max_batches**는 본인 데이터의 클래스 갯수 * (2000 or 3000)
# <br>
# (mat_batches는 데이터셋의 특성에 따라 달라질
# 수 있다.)
# <br><br>
# **steps**는 max_batches*0.8,  max_batches*0.9로 설정.
# <br><br>
# **filter**는 [yolo]의 바로 앞의 있는 filter크기만 수정한다. filter의 계산식은 다음과 같다.
# (classes+5)*3, 클래스가 2인경우 (2+5)*3=21이다.
# <br><br>
# **classes**는 [yolo]에 있는 classes만 수정해준다.
#
# <br><br>
#
# **[Inference]**
# 테스트를 위해서는 batch=1로 설정한다.<br>

# %% [markdown]
# 데이터셋을 준비한 뒤 process.py를 실행한다.
# process.py파일은 데이터셋을 train과 test의 비율을 9:1로 나누어준다.

# %% [markdown]
# #### process.py파일을 실행하면 data폴더안에 train.txt와 test.txt파일을 생성해준다.

# %%
# data폴더에 train.txt와 test.txt파일을 만들어준다.
# train.txt파일은 학습에 사용되고,
# test.txt 파일은 validation에 사용된다.
#!python process.py

# %%
import glob, os

# Current directory
#current_dir = os.path.dirname(os.path.abspath('/mydrive/Advanced_AI/yolov4/darknet/data/'))

#print(current_dir)

current_dir = 'data/customData'

# Percentage of images to be used for the test set
percentage_test = 10;

# Create and/or truncate train.txt and test.txt
file_train = open('data/train.txt', 'w')
file_test = open('data/test.txt', 'w')

# Populate train.txt and test.txt
counter = 1
index_test = round(100 / percentage_test)
for pathAndFilename in glob.iglob(os.path.join(current_dir, "*.png")):
    #print(pathAndFilename)
    title, ext = os.path.splitext(os.path.basename(pathAndFilename))
    if counter == index_test:
        counter = 1
        file_test.write("data/customData" + "/" + title + '.png' + "\n")
    else:
        file_train.write("data/customData" + "/" + title + '.png' + "\n")
        counter = counter + 1

# %%
# !ls data/
# Out:
# 9k.tree       dog.jpg		    imagenet.shortnames.list  test.txt
# coco9k.map    eagle.jpg		    labels		      train.txt
# coco.names    giraffe.jpg	    maskData		      voc.names
# custom.data   goal.txt		    openimages.names
# customData    horses.jpg	    person.jpg
# custom.names  imagenet.labels.list  scream.jpg

# %% [markdown]
# ### 생성된 train.txt파일의 내용을 한번 확인해보자

# %%
# !cat data/train.txt
# Out:
# data/customData/br2_189_sc.png
# data/customData/r_br2_128.png
# data/customData/r_br2_131.png
# data/customData/br2_194_sc.png
# data/customData/br2_193_sc.png
# data/customData/br2_191_sc.png
# data/customData/br2_192_sc.png
# data/customData/r_br2_132.png
# data/customData/br2_196_sc.png
# data/customData/r_br2_134.png
# data/customData/br2_197_sc.png
# data/customData/br2_198_sc.png
# data/customData/r_br2_133.png
# data/customData/br2_201_sc.png
# data/customData/br2_203_sc.png
# data/customData/br2_200_sc.png
# data/customData/br2_199_sc.png
# data/customData/br2_202_sc.png
# data/customData/r_br2_136.png
# data/customData/r_br2_137.png
# data/customData/br2_207_sc.png
# data/customData/br2_208_sc.png
# data/customData/br2_205_sc.png
# data/customData/br2_204_sc.png
# data/customData/br2_206_sc.png
# data/customData/r_br2_138.png
# data/customData/br2_210_sc.png
# data/customData/br2_209_sc.png
# data/customData/br2_211_sc.png
# data/customData/r_br2_140.png
# data/customData/br2_212_sc.png
# data/customData/br2_215_sc.png
# data/customData/br2_217_sc.png
# data/customData/r_br2_142.png
# data/customData/r_br2_141.png
# data/customData/br2_213_sc.png
# data/customData/br2_216_sc.png
# data/customData/r_br2_143.png
# data/customData/br2_220_sc.png
# data/customData/br2_222_sc.png
# data/customData/br2_218_sc.png
# data/customData/br2_219_sc.png
# data/customData/br2_221_sc.png
# data/customData/r_br2_144.png
# data/customData/r_br2_145.png
# data/customData/br2_223_sc.png
# data/customData/br2_227_sc.png
# data/customData/br2_226_sc.png
# data/customData/br2_225_sc.png
# data/customData/r_br2_146.png
# data/customData/r_br2_147.png
# data/customData/br2_232_sc.png
# data/customData/br2_231_sc.png
# data/customData/br2_307_sc.png
# data/customData/br2_304_sc.png
# data/customData/r_br2_181.png
# data/customData/r_br2_183.png
# data/customData/br2_310_sc.png
# data/customData/br2_308_sc.png
# data/customData/br2_309_sc.png
# data/customData/r_br2_185.png
# data/customData/br2_311_sc.png
# data/customData/r_br2_184.png
# data/customData/br2_312_sc.png
# data/customData/r_br2_187.png
# data/customData/br2_314_sc.png
# data/customData/br2_316_sc.png
# data/customData/br2_313_sc.png
# data/customData/br2_315_sc.png
# data/customData/r_br2_186.png
# data/customData/r_br2_190.png
# data/customData/r_br2_188.png
# data/customData/br2_319_sc.png
# data/customData/br2_323_sc.png
# data/customData/br2_322_sc.png
# data/customData/br2_318_sc.png
# data/customData/r_br2_189.png
# data/customData/br2_320_sc.png
# data/customData/br2_324_sc.png
# data/customData/r_br2_191.png
# data/customData/br2_327_sc.png
# data/customData/br2_326_sc.png
# data/customData/br2_328_sc.png
# data/customData/r_br2_192.png
# data/customData/br2_329_sc.png
# data/customData/br2_333_sc.png
# data/customData/r_br2_193.png
# data/customData/br2_330_sc.png
# data/customData/br2_332_sc.png
# data/customData/br2_331_sc.png
# data/customData/r_br2_194.png
# data/customData/r_br2_196.png
# data/customData/br2_335_sc.png
# data/customData/br2_334_sc.png
# data/customData/br2_336_sc.png
# data/customData/br2_338_sc.png
# data/customData/r_br2_195.png
# data/customData/br2_340_sc.png
# data/customData/br2_343_sc.png
# data/customData/br2_342_sc.png
# data/customData/br2_339_sc.png
# data/customData/r_br2_197.png
# data/customData/br2_348_sc.png
# data/customData/br2_346_sc.png
# data/customData/br2_344_sc.png
# data/customData/r_br2_198.png
# data/customData/br2_347_sc.png
# data/customData/r_br2_199.png
# data/customData/br2_345_sc.png
# data/customData/br2_353_sc.png
# data/customData/br2_351_sc.png
# data/customData/br2_350_sc.png
# data/customData/br2_352_sc.png
# data/customData/r_br2_201.png
# data/customData/br2_349_sc.png
# data/customData/r_br2_202.png
# data/customData/r_br2_203.png
# data/customData/br2_356_sc.png
# data/customData/br2_355_sc.png
# data/customData/br2_354_sc.png
# data/customData/r_br2_204.png
# data/customData/br2_360_sc.png
# data/customData/br2_363_sc.png
# data/customData/br2_359_sc.png
# data/customData/br2_358_sc.png
# data/customData/br2_361_sc.png
# data/customData/br2_362_sc.png
# data/customData/br2_364_sc.png
# data/customData/br2_368_sc.png
# data/customData/br2_366_sc.png
# data/customData/r_br2_208.png
# data/customData/br2_365_sc.png
# data/customData/br2_367_sc.png
# data/customData/r_br2_207.png
# data/customData/r_br2_206.png
# data/customData/br2_369_sc.png
# data/customData/br2_370_sc.png
# data/customData/br2_372_sc.png
# data/customData/br2_371_sc.png
# data/customData/br2_373_sc.png
# data/customData/r_br2_210.png
# data/customData/r_br2_209.png
# data/customData/br2_375_sc.png
# data/customData/r_br2_212.png
# data/customData/br2_380_sc.png
# data/customData/r_br2_211.png
# data/customData/br2_379_sc.png
# data/customData/br2_377_sc.png
# data/customData/br2_376_sc.png
# data/customData/br2_382_sc.png
# data/customData/br2_386_sc.png
# data/customData/br1_52_sc.png
# data/customData/br1_49_sc.png
# data/customData/br1_51_sc.png
# data/customData/br1_48_sc.png
# data/customData/br1_54_sc.png
# data/customData/br1_55_sc.png
# data/customData/br1_57_sc.png
# data/customData/br1_56_sc.png
# data/customData/br1_53_sc.png
# data/customData/br1_59_sc.png
# data/customData/br1_61_sc.png
# data/customData/br1_60_sc.png
# data/customData/br1_58_sc.png
# data/customData/br1_64_sc.png
# data/customData/br1_66_sc.png
# data/customData/br1_65_sc.png
# data/customData/br1_63_sc.png
# data/customData/br1_68_sc.png
# data/customData/br1_70_sc.png
# data/customData/br1_71_sc.png
# data/customData/br1_69_sc.png
# data/customData/br1_73_sc.png
# data/customData/br1_76_sc.png
# data/customData/br1_72_sc.png
# data/customData/br1_74_sc.png
# data/customData/br1_75_sc.png
# data/customData/br1_80_sc.png
# data/customData/br1_81_sc.png
# data/customData/br1_79_sc.png
# data/customData/br1_78_sc.png
# data/customData/br1_82_sc.png
# data/customData/br1_84_sc.png
# data/customData/br1_83_sc.png
# data/customData/br1_85_sc.png
# data/customData/br1_87_sc.png
# data/customData/br1_88_sc.png
# data/customData/br1_86_sc.png
# data/customData/br1_90_sc.png
# data/customData/br1_89_sc.png
# data/customData/br1_93_sc.png
# data/customData/br1_92_sc.png
# data/customData/br1_94_sc.png
# data/customData/br1_99_sc.png
# data/customData/br1_96_sc.png
# data/customData/br1_95_sc.png
# data/customData/br1_98_sc.png
# data/customData/br1_97_sc.png
# data/customData/br1_104_sc.png
# data/customData/br1_101_sc.png
# data/customData/br1_102_sc.png
# data/customData/br1_103_sc.png
# data/customData/br1_107_sc.png
# data/customData/br1_108_sc.png
# data/customData/br1_105_sc.png
# data/customData/br1_106_sc.png
# data/customData/br1_111_sc.png
# data/customData/br1_113_sc.png
# data/customData/br1_110_sc.png
# data/customData/br1_109_sc.png
# data/customData/br1_116_sc.png
# data/customData/br1_117_sc.png
# data/customData/br1_115_sc.png
# data/customData/br1_114_sc.png
# data/customData/br1_118_sc.png
# data/customData/br1_119_sc.png
# data/customData/br1_120_sc.png
# data/customData/br1_122_sc.png
# data/customData/br1_121_sc.png
# data/customData/br1_123_sc.png
# data/customData/br1_127_sc.png
# data/customData/br1_126_sc.png
# data/customData/br1_125_sc.png
# data/customData/br1_128_sc.png
# data/customData/br1_132_sc.png
# data/customData/br1_129_sc.png
# data/customData/br1_131_sc.png
# data/customData/br1_133_sc.png
# data/customData/br1_135_sc.png
# data/customData/br1_134_sc.png
# data/customData/br1_137_sc.png
# data/customData/br1_136_sc.png
# data/customData/br1_140_sc.png
# data/customData/br1_139_sc.png
# data/customData/br1_138_sc.png
# data/customData/br1_146_sc.png
# data/customData/br1_142_sc.png
# data/customData/br1_145_sc.png
# data/customData/br1_144_sc.png
# data/customData/br1_143_sc.png
# data/customData/br1_150_sc.png
# data/customData/br1_147_sc.png
# data/customData/br1_148_sc.png
# data/customData/br1_149_sc.png
# data/customData/br1_154_sc.png
# data/customData/br1_151_sc.png
# data/customData/br1_155_sc.png
# data/customData/br1_153_sc.png
# data/customData/br1_159_sc.png
# data/customData/br1_156_sc.png
# data/customData/br1_158_sc.png
# data/customData/br1_160_sc.png
# data/customData/br1_157_sc.png
# data/customData/br1_165_sc.png
# data/customData/br1_164_sc.png
# data/customData/br1_161_sc.png
# data/customData/br1_163_sc.png
# data/customData/br1_166_sc.png
# data/customData/br1_168_sc.png
# data/customData/br1_167_sc.png
# data/customData/br1_169_sc.png
# data/customData/br1_174_sc.png
# data/customData/br1_170_sc.png
# data/customData/br1_172_sc.png
# data/customData/br1_173_sc.png
# data/customData/br1_175_sc.png
# data/customData/br1_178_sc.png
# data/customData/br1_177_sc.png
# data/customData/br1_176_sc.png
# data/customData/br1_180_sc.png
# data/customData/br1_181_sc.png
# data/customData/br1_182_sc.png
# data/customData/br1_183_sc.png
# data/customData/br1_184_sc.png
# data/customData/br1_187_sc.png
# data/customData/br1_186_sc.png
# data/customData/br1_185_sc.png
# data/customData/br1_188_sc.png
# data/customData/br1_190_sc.png
# data/customData/br1_192_sc.png
# data/customData/br1_189_sc.png
# data/customData/br1_197_sc.png
# data/customData/br1_194_sc.png
# data/customData/br1_193_sc.png
# data/customData/br1_196_sc.png
# data/customData/br1_195_sc.png
# data/customData/br1_199_sc.png
# data/customData/br1_198_sc.png
# data/customData/br1_202_sc.png
# data/customData/br1_200_sc.png
# data/customData/br1_204_sc.png
# data/customData/br1_205_sc.png
# data/customData/br1_206_sc.png
# data/customData/br1_203_sc.png
# data/customData/br1_207_sc.png
# data/customData/br1_211_sc.png
# data/customData/br1_210_sc.png
# data/customData/br1_208_sc.png
# data/customData/br1_213_sc.png
# data/customData/br1_216_sc.png
# data/customData/br1_212_sc.png
# data/customData/br1_215_sc.png
# data/customData/br1_214_sc.png
# data/customData/br1_219_sc.png
# data/customData/br1_220_sc.png
# data/customData/br1_218_sc.png
# data/customData/br1_217_sc.png
# data/customData/br1_221_sc.png
# data/customData/br1_222_sc.png
# data/customData/br1_223_sc.png
# data/customData/br1_225_sc.png
# data/customData/br1_226_sc.png
# data/customData/br1_228_sc.png
# data/customData/br1_227_sc.png
# data/customData/br1_229_sc.png
# data/customData/br1_232_sc.png
# data/customData/br1_231_sc.png
# data/customData/br1_233_sc.png
# data/customData/br1_236_sc.png
# data/customData/br1_237_sc.png
# data/customData/br1_238_sc.png
# data/customData/br1_235_sc.png
# data/customData/br1_234_sc.png
# data/customData/br1_241_sc.png
# data/customData/br1_242_sc.png
# data/customData/br1_240_sc.png
# data/customData/br1_244_sc.png
# data/customData/br1_243_sc.png
# data/customData/br1_245_sc.png
# data/customData/br1_248_sc.png
# data/customData/br1_249_sc.png
# data/customData/br1_246_sc.png
# data/customData/br1_250_sc.png
# data/customData/br1_247_sc.png
# data/customData/br1_253_sc.png
# data/customData/br1_252_sc.png
# data/customData/br1_254_sc.png
# data/customData/br1_257_sc.png
# data/customData/br1_256_sc.png
# data/customData/br1_255_sc.png
# data/customData/br1_258_sc.png
# data/customData/br1_261_sc.png
# data/customData/br1_260_sc.png
# data/customData/br1_259_sc.png
# data/customData/br1_266_sc.png
# data/customData/br1_263_sc.png
# data/customData/br1_265_sc.png
# data/customData/br1_264_sc.png
# data/customData/br1_271_sc.png
# data/customData/br1_268_sc.png
# data/customData/br1_270_sc.png
# data/customData/br1_269_sc.png
# data/customData/br1_274_sc.png
# data/customData/br1_273_sc.png
# data/customData/br1_276_sc.png
# data/customData/br1_272_sc.png
# data/customData/br1_275_sc.png
# data/customData/br1_279_sc.png
# data/customData/br1_277_sc.png
# data/customData/br1_280_sc.png
# data/customData/br1_281_sc.png
# data/customData/br1_283_sc.png
# data/customData/br1_282_sc.png
# data/customData/br1_284_sc.png
# data/customData/br1_285_sc.png
# data/customData/br1_286_sc.png
# data/customData/br1_289_sc.png
# data/customData/br1_287_sc.png
# data/customData/br1_288_sc.png
# data/customData/br1_290_sc.png
# data/customData/br1_292_sc.png
# data/customData/br1_293_sc.png
# data/customData/br1_291_sc.png
# data/customData/br1_295_sc.png
# data/customData/br1_298_sc.png
# data/customData/br1_296_sc.png
# data/customData/br1_297_sc.png
# data/customData/br1_299_sc.png
# data/customData/br1_301_sc.png
# data/customData/br1_300_sc.png
# data/customData/br1_305_sc.png
# data/customData/br1_304_sc.png
# data/customData/br1_303_sc.png
# data/customData/br1_306_sc.png
# data/customData/br1_308_sc.png
# data/customData/br1_310_sc.png
# data/customData/br1_309_sc.png
# data/customData/br1_307_sc.png
# data/customData/br1_312_sc.png
# data/customData/br1_311_sc.png
# data/customData/br1_313_sc.png
# data/customData/br1_316_sc.png
# data/customData/br1_315_sc.png
# data/customData/br1_317_sc.png
# data/customData/br1_318_sc.png
# data/customData/br1_322_sc.png
# data/customData/br1_319_sc.png
# data/customData/br1_321_sc.png
# data/customData/br1_323_sc.png
# data/customData/br1_324_sc.png
# data/customData/br1_326_sc.png
# data/customData/br1_325_sc.png
# data/customData/br1_328_sc.png
# data/customData/br1_327_sc.png
# data/customData/br1_329_sc.png
# data/customData/br1_330_sc.png
# data/customData/br1_331_sc.png
# data/customData/br1_333_sc.png
# data/customData/br1_332_sc.png
# data/customData/br1_335_sc.png
# data/customData/br1_337_sc.png
# data/customData/br1_338_sc.png
# data/customData/br1_336_sc.png
# data/customData/br1_342_sc.png
# data/customData/br1_340_sc.png
# data/customData/br1_341_sc.png
# data/customData/br1_344_sc.png
# data/customData/br1_345_sc.png
# data/customData/br1_343_sc.png
# data/customData/br1_350_sc.png
# data/customData/br1_346_sc.png
# data/customData/br1_349_sc.png
# data/customData/br1_348_sc.png
# data/customData/br1_347_sc.png
# data/customData/br1_353_sc.png
# data/customData/br1_351_sc.png
# data/customData/br1_354_sc.png
# data/customData/br1_357_sc.png
# data/customData/br1_355_sc.png
# data/customData/br1_356_sc.png
# data/customData/br1_358_sc.png
# data/customData/br1_359_sc.png
# data/customData/br1_360_sc.png
# data/customData/br1_361_sc.png
# data/customData/br1_362_sc.png
# data/customData/br1_367_sc.png
# data/customData/br1_366_sc.png
# data/customData/br1_365_sc.png
# data/customData/r_br2_123.png
# data/customData/br2_171_sc.png
# data/customData/br2_172_sc.png
# data/customData/br2_173_sc.png
# data/customData/r_br2_122.png
# data/customData/br2_178_sc.png
# data/customData/br2_176_sc.png
# data/customData/br2_179_sc.png
# data/customData/br2_175_sc.png
# data/customData/br2_177_sc.png
# data/customData/r_br2_126.png
# data/customData/r_br2_125.png
# data/customData/br2_184_sc.png
# data/customData/r_br2_127.png
# data/customData/br2_183_sc.png
# data/customData/br2_181_sc.png
# data/customData/br2_182_sc.png
# data/customData/br2_186_sc.png
# data/customData/br2_188_sc.png
# data/customData/br2_185_sc.png
# data/customData/br2_187_sc.png
# data/customData/br2_190_sc.png
# data/customData/r_br2_129.png
# data/customData/r_br2_130.png
# data/customData/스크린샷, Audio - 341_sc.png
# data/customData/스크린샷, Audio - 343_sc.png
# data/customData/스크린샷, Audio - 344_sc.png
# data/customData/스크린샷, Audio - 342_sc.png
# data/customData/스크린샷, Audio - 346_sc.png
# data/customData/스크린샷, Audio - 347_sc.png
# data/customData/스크린샷, Audio - 345_sc.png
# data/customData/스크린샷, Audio - 348_sc.png
# data/customData/스크린샷, Audio - 349_sc.png
# data/customData/스크린샷, Audio - 350_sc.png
# data/customData/스크린샷, Audio - 352_sc.png
# data/customData/스크린샷, Audio - 353_sc.png
# data/customData/스크린샷, Audio - 354_sc.png
# data/customData/스크린샷, Audio - 356_sc.png
# data/customData/스크린샷, Audio - 355_sc.png
# data/customData/스크린샷, Audio - 358_sc.png
# data/customData/스크린샷, Audio - 359_sc.png
# data/customData/스크린샷, Audio - 357_sc.png
# data/customData/스크린샷, Audio - 361_sc.png
# data/customData/스크린샷, Audio - 362_sc.png
# data/customData/스크린샷, Audio - 365_sc.png
# data/customData/스크린샷, Audio - 366_sc.png
# data/customData/스크린샷, Audio - 364_sc.png
# data/customData/스크린샷, Audio - 363_sc.png
# data/customData/스크린샷, Audio - 367_sc.png
# data/customData/스크린샷, Audio - 369_sc.png
# data/customData/스크린샷, Audio - 368_sc.png
# data/customData/스크린샷, Audio - 371_sc.png
# data/customData/스크린샷, Audio - 370_sc.png
# data/customData/스크린샷, Audio - 373_sc.png
# data/customData/스크린샷, Audio - 376_sc.png
# data/customData/스크린샷, Audio - 375_sc.png
# data/customData/스크린샷, Audio - 374_sc.png
# data/customData/스크린샷, Audio - 377_sc.png
# data/customData/스크린샷, Audio - 378_sc.png
# data/customData/스크린샷, Audio - 379_sc.png
# data/customData/스크린샷, Audio - 380_sc.png
# data/customData/스크린샷, Audio - 382_sc.png
# data/customData/스크린샷, Audio - 381_sc.png
# data/customData/스크린샷, Audio - 384_sc.png
# data/customData/스크린샷, Audio - 385_sc.png
# data/customData/스크린샷, Audio - 386_sc.png
# data/customData/스크린샷, Audio - 387_sc.png
# data/customData/스크린샷, Audio - 388_sc.png
# data/customData/스크린샷, Audio - 391_sc.png
# data/customData/스크린샷, Audio - 392_sc.png
# data/customData/스크린샷, Audio - 390_sc.png
# data/customData/스크린샷, Audio - 396_sc.png
# data/customData/color3_370.png
# data/customData/color3_371.png
# data/customData/color3_372.png
# data/customData/color3_373.png
# data/customData/color3_374.png
# data/customData/color3_375.png
# data/customData/color3_376.png
# data/customData/color3_378.png
# data/customData/color3_379.png
# data/customData/color3_380.png
# data/customData/color3_381.png
# data/customData/color3_382.png
# data/customData/color3_383.png
# data/customData/color3_384.png
# data/customData/color3_385.png
# data/customData/color3_386.png
# data/customData/color3_388.png
# data/customData/color3_389.png
# data/customData/color3_390.png
# data/customData/color3_391.png
# data/customData/color3_392.png
# data/customData/color3_393.png
# data/customData/color3_394.png
# data/customData/color3_395.png
# data/customData/color3_396.png
# data/customData/color3_398.png
# data/customData/color3_399.png
# data/customData/color3_400.png
# data/customData/color3_401.png
# data/customData/im Audio.png
# data/customData/im Audio - 1.png
# data/customData/im Audio - 2.png
# data/customData/im Audio - 3.png
# data/customData/im Audio - 4.png
# data/customData/im Audio - 6.png
# data/customData/im Audio - 8.png
# data/customData/im Audio - 9.png
# data/customData/im Audio - 10.png
# data/customData/im Audio - 11.png
# data/customData/im Audio - 12.png
# data/customData/im Audio - 13.png
# data/customData/im Audio - 16.png
# data/customData/im Audio - 17.png
# data/customData/im Audio - 21.png
# data/customData/im Audio - 22.png
# data/customData/im Audio - 24.png
# data/customData/im Audio - 25.png
# data/customData/im Audio - 26.png
# data/customData/im Audio - 27.png
# data/customData/im Audio - 28.png
# data/customData/im Audio - 29.png
# data/customData/im Audio - 30.png
# data/customData/im Audio - 33.png
# data/customData/im Audio - 35.png
# data/customData/im Audio - 42.png
# data/customData/im Audio - 45.png
# data/customData/im Audio - 46.png
# data/customData/im Audio - 47.png
# data/customData/im Audio - 48.png
# data/customData/im Audio - 51.png
# data/customData/im Audio - 54.png
# data/customData/im Audio - 59.png
# data/customData/im Audio - 62.png
# data/customData/im Audio - 63.png
# data/customData/im Audio - 64.png
# data/customData/im Audio - 65.png
# data/customData/im Audio - 66.png
# data/customData/im Audio - 67.png
# data/customData/im Audio - 68.png
# data/customData/im Audio - 69.png
# data/customData/im Audio - 71.png
# data/customData/im Audio - 72.png
# data/customData/im Audio - 74.png
# data/customData/im Audio - 76.png
# data/customData/im Audio - 78.png
# data/customData/im Audio - 79.png
# data/customData/im Audio - 81.png
# data/customData/im Audio - 82.png
# data/customData/im Audio - 83.png
# data/customData/im Audio - 85.png
# data/customData/im Audio - 87.png
# data/customData/im Audio - 88.png
# data/customData/im Audio - 91.png
# data/customData/im Audio - 93.png
# data/customData/im Audio - 94.png
# data/customData/im Audio - 95.png
# data/customData/im Audio - 96.png
# data/customData/im Audio - 97.png
# data/customData/im Audio - 99.png
# data/customData/im Audio - 100.png
# data/customData/im Audio - 104.png
# data/customData/im Audio - 105.png
# data/customData/im Audio - 106.png
# data/customData/im Audio - 107.png
# data/customData/im Audio - 110.png
# data/customData/im Audio - 111.png
# data/customData/im Audio - 112.png
# data/customData/im Audio - 115.png
# data/customData/im Audio - 117.png
# data/customData/im Audio - 119.png
# data/customData/im Audio - 120.png
# data/customData/im Audio - 121.png
# data/customData/im Audio - 122.png
# data/customData/im Audio - 125.png
# data/customData/im Audio - 127.png
# data/customData/im Audio - 128.png
# data/customData/im Audio - 130.png
# data/customData/im Audio - 136.png
# data/customData/im Audio - 137.png
# data/customData/im Audio - 138.png
# data/customData/im Audio - 140.png
# data/customData/im Audio - 142.png
# data/customData/im Audio - 144.png
# data/customData/im Audio - 145.png
# data/customData/im Audio - 146.png
# data/customData/im Audio - 148.png
# data/customData/im Audio - 149.png
# data/customData/im Audio - 150.png
# data/customData/im Audio - 152.png
# data/customData/im Audio - 156.png
# data/customData/im Audio - 157.png
# data/customData/im Audio - 158.png
# data/customData/im Audio - 159.png
# data/customData/im Audio - 160.png
# data/customData/im Audio - 162.png
# data/customData/im Audio - 163.png
# data/customData/im Audio - 164.png
# data/customData/im Audio - 165.png
# data/customData/im Audio - 166.png
# data/customData/im Audio - 167.png
# data/customData/im Audio - 168.png
# data/customData/im Audio - 169.png
# data/customData/im Audio - 170.png
# data/customData/im Audio - 172.png
# data/customData/im Audio - 173.png
# data/customData/im Audio - 174.png
# data/customData/im Audio - 175.png
# data/customData/im Audio - 176.png
# data/customData/im Audio - 177.png
# data/customData/im Audio - 178.png
# data/customData/im Audio - 179.png
# data/customData/im Audio - 180.png
# data/customData/im Audio - 183.png
# data/customData/im Audio - 184.png
# data/customData/im Audio - 185.png
# data/customData/im Audio - 186.png
# data/customData/im Audio - 187.png
# data/customData/im Audio - 188.png
# data/customData/im Audio - 189.png
# data/customData/im Audio - 190.png
# data/customData/im Audio - 191.png
# data/customData/im Audio - 193.png
# data/customData/im Audio - 194.png
# data/customData/im Audio - 195.png
# data/customData/im Audio - 196.png
# data/customData/im Audio - 197.png
# data/customData/im Audio - 198.png
# data/customData/im Audio - 199.png
# data/customData/im Audio - 200.png
# data/customData/im Audio - 201.png
# data/customData/im Audio - 204.png
# data/customData/im Audio - 205.png
# data/customData/im Audio - 206.png
# data/customData/im Audio - 207.png
# data/customData/im Audio - 208.png
# data/customData/im Audio - 209.png
# data/customData/im Audio - 210.png
# data/customData/im Audio - 211.png
# data/customData/im Audio - 212.png
# data/customData/im Audio - 214.png
# data/customData/im Audio - 215.png
# data/customData/im Audio - 216.png
# data/customData/im Audio - 217.png
# data/customData/im Audio - 218.png
# data/customData/im Audio - 219.png
# data/customData/im Audio - 220.png
# data/customData/im Audio - 221.png
# data/customData/im Audio - 222.png
# data/customData/im Audio - 224.png
# data/customData/im Audio - 225.png
# data/customData/im Audio - 226.png
# data/customData/im Audio - 227.png
# data/customData/im Audio - 228.png
# data/customData/im Audio - 229.png
# data/customData/im Audio - 230.png
# data/customData/im Audio - 231.png
# data/customData/im Audio - 232.png
# data/customData/im Audio - 234.png
# data/customData/im Audio - 235.png
# data/customData/im Audio - 236.png
# data/customData/im Audio - 237.png
# data/customData/im Audio - 238.png
# data/customData/im Audio - 239.png
# data/customData/im Audio - 240.png
# data/customData/im Audio - 242.png
# data/customData/im Audio - 243.png
# data/customData/im Audio - 245.png
# data/customData/im Audio - 246.png
# data/customData/im Audio - 247.png
# data/customData/im Audio - 248.png
# data/customData/im Audio - 249.png
# data/customData/im Audio - 250.png
# data/customData/im Audio - 251.png
# data/customData/im Audio - 252.png
# data/customData/im Audio - 253.png
# data/customData/im Audio - 255.png
# data/customData/im Audio - 256.png
# data/customData/im Audio - 257.png
# data/customData/im Audio - 258.png
# data/customData/im Audio - 260.png
# data/customData/im Audio - 261.png
# data/customData/im Audio - 262.png
# data/customData/im Audio - 264.png
# data/customData/im Audio - 268.png
# data/customData/im Audio - 270.png
# data/customData/im Audio - 271.png
# data/customData/im Audio - 272.png
# data/customData/im Audio - 273.png
# data/customData/im Audio - 274.png
# data/customData/im Audio - 275.png
# data/customData/im Audio - 276.png
# data/customData/im Audio - 277.png
# data/customData/im Audio - 278.png
# data/customData/im Audio - 282.png
# data/customData/im Audio - 283.png
# data/customData/im Audio - 284.png
# data/customData/im Audio - 288.png
# data/customData/im Audio - 293.png
# data/customData/im Audio - 295.png
# data/customData/im Audio - 296.png
# data/customData/im Audio - 297.png
# data/customData/im Audio - 298.png
# data/customData/im Audio - 301.png
# data/customData/im Audio - 302.png
# data/customData/im Audio - 303.png
# data/customData/im Audio - 307.png
# data/customData/im Audio - 308.png
# data/customData/im Audio - 309.png
# data/customData/im Audio - 310.png
# data/customData/im Audio - 311.png
# data/customData/im Audio - 312.png
# data/customData/im Audio - 315.png
# data/customData/im Audio - 321.png
# data/customData/im Audio - 323.png
# data/customData/im Audio - 324.png
# data/customData/im Audio - 325.png
# data/customData/im Audio - 326.png
# data/customData/im Audio - 327.png
# data/customData/im Audio - 328.png
# data/customData/im Audio - 329.png
# data/customData/im Audio - 332.png
# data/customData/im Audio - 334.png
# data/customData/im Audio - 335.png
# data/customData/im Audio - 337.png
# data/customData/im Audio - 338.png
# data/customData/im Audio - 339.png
# data/customData/im Audio - 344.png
# data/customData/im Audio - 346.png
# data/customData/im Audio - 347.png
# data/customData/im Audio - 349.png
# data/customData/im Audio - 350.png
# data/customData/im Audio - 351.png
# data/customData/im Audio - 352.png
# data/customData/im Audio - 353.png
# data/customData/im Audio - 354.png
# data/customData/im Audio - 355.png
# data/customData/im Audio - 356.png
# data/customData/im Audio - 357.png
# data/customData/im Audio - 359.png
# data/customData/im Audio - 360.png
# data/customData/im Audio - 366.png
# data/customData/im Audio - 368.png
# data/customData/im Audio - 373.png
# data/customData/im Audio - 374.png
# data/customData/im Audio - 375.png
# data/customData/im Audio - 377.png
# data/customData/im Audio - 378.png
# data/customData/im Audio - 381.png
# data/customData/im Audio - 383.png
# data/customData/im Audio - 384.png
# data/customData/im Audio - 385.png
# data/customData/im Audio - 386.png
# data/customData/im Audio - 387.png
# data/customData/im Audio - 388.png
# data/customData/im Audio - 392.png
# data/customData/im Audio - 394.png
# data/customData/im Audio - 398.png
# data/customData/im Audio - 399.png
# data/customData/im Audio - 403.png
# data/customData/im Audio - 405.png
# data/customData/im Audio - 406.png
# data/customData/im Audio - 407.png
# data/customData/im Audio - 408.png
# data/customData/im Audio - 409.png
# data/customData/im Audio - 410.png
# data/customData/im Audio - 412.png
# data/customData/im Audio - 417.png
# data/customData/im Audio - 420.png
# data/customData/im Audio - 421.png
# data/customData/im Audio - 425.png
# data/customData/im Audio - 426.png
# data/customData/im Audio - 427.png
# data/customData/im Audio - 429.png
# data/customData/im Audio - 430.png
# data/customData/im Audio - 434.png
# data/customData/im Audio - 435.png
# data/customData/im Audio - 436.png
# data/customData/im Audio - 437.png
# data/customData/im Audio - 439.png
# data/customData/im Audio - 440.png
# data/customData/im Audio - 441.png
# data/customData/im Audio - 442.png
# data/customData/im Audio - 444.png
# data/customData/im Audio - 448.png
# data/customData/im Audio - 452.png
# data/customData/im Audio - 453.png
# data/customData/im Audio - 454.png
# data/customData/im Audio - 455.png
# data/customData/im Audio - 456.png
# data/customData/im Audio - 457.png
# data/customData/im Audio - 459.png
# data/customData/im Audio - 461.png
# data/customData/im Audio - 464.png
# data/customData/im Audio - 465.png
# data/customData/im Audio - 466.png
# data/customData/im Audio - 467.png
# data/customData/im Audio - 468.png
# data/customData/im Audio - 471.png
# data/customData/im Audio - 472.png
# data/customData/im Audio - 474.png
# data/customData/im Audio - 475.png
# data/customData/im Audio - 477.png
# data/customData/im Audio - 478.png
# data/customData/im Audio - 479.png
# data/customData/im Audio - 480.png
# data/customData/im Audio - 482.png
# data/customData/im Audio - 484.png
# data/customData/im Audio - 486.png
# data/customData/im Audio - 488.png
# data/customData/im Audio - 492.png
# data/customData/im Audio - 496.png
# data/customData/im Audio - 497.png
# data/customData/im Audio - 501.png
# data/customData/im Audio - 503.png
# data/customData/im Audio - 506.png
# data/customData/im Audio - 507.png
# data/customData/im Audio - 508.png
# data/customData/im Audio - 512.png
# data/customData/im Audio - 513.png
# data/customData/im Audio - 517.png
# data/customData/im Audio - 518.png
# data/customData/im Audio - 519.png
# data/customData/im Audio - 520.png
# data/customData/im Audio - 521.png
# data/customData/im Audio - 522.png
# data/customData/im Audio - 523.png
# data/customData/im Audio - 525.png
# data/customData/im Audio - 526.png
# data/customData/im Audio - 532.png
# data/customData/im Audio - 533.png
# data/customData/im Audio - 534.png
# data/customData/im Audio - 535.png
# data/customData/im Audio - 536.png
# data/customData/im Audio - 537.png
# data/customData/im Audio - 539.png
# data/customData/im Audio - 543.png
# data/customData/im Audio - 544.png
# data/customData/im Audio - 549.png
# data/customData/im Audio - 550.png
# data/customData/im Audio - 551.png
# data/customData/im Audio - 552.png
# data/customData/im Audio - 553.png
# data/customData/im Audio - 554.png
# data/customData/im Audio - 557.png
# data/customData/im Audio - 560.png
# data/customData/im Audio - 561.png
# data/customData/im Audio - 563.png
# data/customData/im Audio - 564.png
# data/customData/im Audio - 567.png
# data/customData/im Audio - 568.png
# data/customData/im Audio - 572.png
# data/customData/im Audio - 573.png
# data/customData/im Audio - 574.png
# data/customData/im Audio - 575.png
# data/customData/im Audio - 576.png
# data/customData/im Audio - 578.png
# data/customData/im Audio - 580.png
# data/customData/im Audio - 588.png
# data/customData/im Audio - 589.png

# %% [markdown]
# ### pre-trained yolov4 weight파일을 다운로드 하자.

# %%
# yolo v4를 ms coco데이터셋에 사전학습된 파일 
# 현재 경로 위치가 /content/gdrive/My Drive/Advanced_AI/yolov4/darknet에 다운로드
if not os.path.isfile('yolov4.conv.137'):
    # !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137
else:
    print('이미 파일이 존재합니다')
# Out:
# 이미 파일이 존재합니다

# %%
# !pwd
# Out:
# /content/drive/My Drive/Advanced_AI/yolov4/darknet

# %% [markdown]
# ### 학습 진행하기

# %%
# !ls -al
# Out:
# total 595676
# drwx------ 2 root root      4096 Aug  6 16:52 3rdparty
# drwx------ 2 root root      4096 Aug 16 06:39 backup
# drwx------ 2 root root      4096 Aug  6 16:52 build
# -rw------- 1 root root     27008 Aug  6 16:52 build.ps1
# drwx------ 3 root root      4096 Aug 23 11:22 cfg
# drwx------ 2 root root      4096 Aug  6 16:52 .circleci
# drwx------ 2 root root      4096 Aug  6 16:52 cmake
# -rw------- 1 root root     24576 Aug  6 16:52 CMakeLists.txt
# -rw------- 1 root root   6587336 Aug 23 03:38 darknet
# -rw------- 1 root root      1406 Aug  6 16:52 DarknetConfig.cmake.in
# -rw------- 1 root root      9469 Aug  6 16:52 darknet_images.py
# -rw------- 1 root root      8207 Aug  6 16:52 darknet.py
# -rw------- 1 root root      6747 Aug  6 16:52 darknet_video.py
# drwx------ 4 root root      4096 Aug  6 16:52 data
# drwx------ 2 root root      4096 Aug  6 16:52 .github
# -rw------- 1 root root       686 Aug  6 16:52 .gitignore
# -rw------- 1 root root       110 Aug  6 16:52 image_yolov3.sh
# -rw------- 1 root root       110 Aug  6 16:52 image_yolov4.sh
# drwx------ 2 root root      4096 Aug  6 16:52 include
# drwx------ 2 root root      4096 Aug  9 14:50 .ipynb_checkpoints
# -rw------- 1 root root       345 Aug  6 16:52 json_mjpeg_streams.sh
# -rw------- 1 root root   6860400 Aug 23 03:38 libdarknet.so
# -rw------- 1 root root       515 Aug  6 16:52 LICENSE
# -rw------- 1 root root      6158 Aug 23 10:58 Makefile
# -rw------- 1 root root       159 Aug  6 16:52 net_cam_v3.sh
# -rw------- 1 root root       159 Aug  6 16:52 net_cam_v4.sh
# drwx------ 2 root root      4096 Aug  6 16:58 obj
# -rw------- 1 root root     27858 Aug 17 06:01 predictions.jpg
# -rw------- 1 root root       845 Aug 23 09:11 process.py
# drwx------ 2 root root      4096 Aug 16 10:45 __pycache__
# -rw------- 1 root root     65518 Aug  6 16:52 README.md
# drwx------ 2 root root      4096 Aug  6 16:52 results
# drwx------ 2 root root      4096 Aug  6 16:52 scripts
# drwx------ 2 root root      4096 Aug 16 06:36 src
# -rw------- 1 root root      5865 Aug  6 16:52 .travis.yml
# -rw------- 1 root root    147624 Aug 23 03:38 uselib
# -rw------- 1 root root      2609 Aug  6 16:52 vcpkg.json
# -rw------- 1 root root       108 Aug  6 16:52 video_yolov3.sh
# -rw------- 1 root root       108 Aug  6 16:52 video_yolov4.sh
# drwx------ 2 root root      4096 Aug  9 14:50 weights
# -rw------- 1 root root 170038676 Apr 27  2020 yolov4.conv.137
# -rw------- 1 root root 170038676 Apr 27  2020 yolov4.conv.137.1
# -rw------- 1 root root 256037520 Aug 17 05:55 yolov4-custom_best.weights

# %%
# darknet파일의 실행권한 설정
# 7  111 -> rwx   110 -> rw-
# !chmod 700 darknet

# %%
# train your custom detector! (uncomment %%capture below if you run into memory issues or your Colab is crashing)
# %%cap
hours left
# Resizing, random_coef = 1.40
#
#  608 x 608

# %% [markdown]
# ## **Colab의 Session을 유지하기 위해서는 아래의 코드를 추가해 주자.**
# 웹브라우저에서 (Ctrl + Shift + i)키를 입력하면 창이 뜬다.
# console탭으로 이동해서 아래의 코드를 추가 해주자.
#
# ```
# function ClickConnect(){
# console.log("Working");
# document
#   .querySelector('#top-toolbar > colab-connect-button')
#   .shadowRoot.querySelector('#connect')
#   .click()
# }
# setInterval(ClickConnect,60000)
# ```

# %%
# define helper function imShow
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %%
# %cd /mydrive/Advanced_AI/yolov4/darknet/

#only works if the training does not get interrupted
imShow('chart.png')
# Out:
# /content/drive/MyDrive/Advanced_AI/yolov4/darknet

# %%
# !pwd
# Out:
# /content/drive/My Drive/Advanced_AI/yolov4/darknet

# %% [markdown]
# # 학습이 중단된 경우 아래 코드 실행

# %% [markdown]
# ### 학습 도중 colab세션이 끊겼을 때 이어서 학습을 진행하려면 다시 구글 드라이브를 마운트 하고 학습을 진행한다.

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/drive')

# !ln -s /content/drive/MyDrive/ /mydrive

# %cd /mydrive/Advanced_AI/yolov4/darknet/

# !chmod 700 darknet
# Out:
# /content/drive/My Drive/Advanced_AI/yolov4
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ln: failed to create symbolic link '/mydrive/MyDrive': File exists
# /content/drive/MyDrive/Advanced_AI/yolov4/darknet

# %% [markdown]
# ### 이어서 학습을 진행할 때는  yolov4.conv.137파일 대신, 가장 마지막까지 학습을 했던 weights파일명을 적어준다.

# %%
# !./darknet detector train data/custom.data cfg/yolov4-custom.cfg ../training/yolov4-custom_last.weights -dont_show -map
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  Prepare additional network for mAP calculation...
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    8 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    9 route  8 2 	                           ->  208 x 208 x 128
#   10 conv     64       1 x 1/ 1    208 x 208 x 128 ->  208 x 208 x  64 0.709 BF
#   11 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#   12 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   13 route  11 		                           ->  104 x 104 x 128
#   14 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   15 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#   16 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#   17 Shortcut Layer: 14,  wt = 0, wn = 0, outputs: 104 x 104 x  64 0.001 BF
#   18 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#   19 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#   20 Shortcut Layer: 17,  wt = 0, wn = 0, outputs: 104 x 104 x  64 0.001 BF
#   21 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#   22 route  21 12 	                           ->  104 x 104 x 128
#   23 conv    128       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x 128 0.354 BF
#   24 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
#   25 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   26 route  24 		                           ->   52 x  52 x 256
#   27 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   28 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   29 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   31 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   32 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   34 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   35 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   37 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   38 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   39 Shortcut Layer: 36,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   40 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   41 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   42 Shortcut Layer: 39,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   43 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   44 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   45 Shortcut Layer: 42,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   46 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   47 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   48 Shortcut Layer: 45,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   49 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   50 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   51 Shortcut Layer: 48,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   52 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   53 route  52 25 	                           ->   52 x  52 x 256
#   54 conv    256       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 256 0.354 BF
#   55 conv    512       3 x 3/ 2     52 x  52 x 256 ->   26 x  26 x 512 1.595 BF
#   56 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   57 route  55 		                           ->   26 x  26 x 512
#   58 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   59 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   60 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   62 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   63 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   64 Shortcut Layer: 61,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   65 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   66 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   67 Shortcut Layer: 64,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   68 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   69 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   70 Shortcut Layer: 67,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   71 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   72 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   73 Shortcut Layer: 70,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   74 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   75 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   76 Shortcut Layer: 73,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   77 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   78 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   79 Shortcut Layer: 76,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   80 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   81 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   82 Shortcut Layer: 79,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   83 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   84 route  83 56 	                           ->   26 x  26 x 512
#   85 conv    512       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 512 0.354 BF
#   86 conv   1024       3 x 3/ 2     26 x  26 x 512 ->   13 x  13 x1024 1.595 BF
#   87 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   88 route  86 		                           ->   13 x  13 x1024
#   89 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   90 conv    512       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.089 BF
#   91 conv    512       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.797 BF
#   92 Shortcut Layer: 89,  wt = 0, wn = 0, outputs:  13 x  13 x 512 0.000 BF
#   93 conv    512       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.089 BF
#   94 conv    512       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.797 BF
#   95 Shortcut Layer: 92,  wt = 0, wn = 0, outputs:  13 x  13 x 512 0.000 BF
#   96 conv    512       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.089 BF
#   97 conv    512       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.797 BF
#   98 Shortcut Layer: 95,  wt = 0, wn = 0, outputs:  13 x  13 x 512 0.000 BF
#   99 conv    512       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.089 BF
#  100 conv    512       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.797 BF
#  101 Shortcut Layer: 98,  wt = 0, wn = 0, outputs:  13 x  13 x 512 0.000 BF
#  102 conv    512       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.089 BF
#  103 route  102 87 	                           ->   13 x  13 x1024
#  104 conv   1024       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x1024 0.354 BF
#  105 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  106 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#  107 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  108 max                5x 5/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.002 BF
#  109 route  107 		                           ->   13 x  13 x 512
#  110 max                9x 9/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.007 BF
#  111 route  107 		                           ->   13 x  13 x 512
#  112 max               13x13/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.015 BF
#  113 route  112 110 108 107 	                   ->   13 x  13 x2048
#  114 conv    512       1 x 1/ 1     13 x  13 x2048 ->   13 x  13 x 512 0.354 BF
#  115 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#  116 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  117 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#  118 upsample                 2x    13 x  13 x 256 ->   26 x  26 x 256
#  119 route  85 		                           ->   26 x  26 x 512
#  120 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  121 route  120 118 	                           ->   26 x  26 x 512
#  122 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  123 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#  124 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  125 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#  126 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  127 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
#  128 upsample                 2x    26 x  26 x 128 ->   52 x  52 x 128
#  129 route  54 		                           ->   52 x  52 x 256
#  130 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  131 route  130 128 	                           ->   52 x  52 x 256
#  132 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  133 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  134 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  135 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  136 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  137 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  138 conv     21       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x  21 0.029 BF
#  139 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.20
# nms_kind: greedynms (1), beta = 0.600000
#  140 route  136 		                           ->   52 x  52 x 128
#  141 conv    256       3 x 3/ 2     52 x  52 x 128 ->   26 x  26 x 256 0.399 BF
#  142 route  141 126 	                           ->   26 x  26 x 512
#  143 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  144 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#  145 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  146 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#  147 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  148 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#  149 conv     21       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x  21 0.015 BF
#  150 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.10
# nms_kind: greedynms (1), beta = 0.600000
#  151 route  147 		                           ->   26 x  26 x 256
#  152 conv    512       3 x 3/ 2     26 x  26 x 256 ->   13 x  13 x 512 0.399 BF
#  153 route  152 116 	                           ->   13 x  13 x1024
#  154 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  155 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#  156 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  157 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#  158 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  159 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#  160 conv     21       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x  21 0.007 BF
#  161 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
# Total BFLOPS 59.570
# avg_outputs = 489910
#  Allocate additional workspace_size = 52.43 MB
# yolov4-custom
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 4, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    8 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    9 route  8 2 	                           ->  208 x 208 x 128
#   10 conv     64       1 x 1/ 1    208 x 208 x 128 ->  208 x 208 x  64 0.709 BF
#   11 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#   12 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   13 route  11 		                           ->  104 x 104 x 128
#   14 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   15 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#   16 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#   17 Shortcut Layer: 14,  wt = 0, wn = 0, outputs: 104 x 104 x  64 0.001 BF
#   18 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#   19 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#   20 Shortcut Layer: 17,  wt = 0, wn = 0, outputs: 104 x 104 x  64 0.001 BF
#   21 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#   22 route  21 12 	                           ->  104 x 104 x 128
#   23 conv    128       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x 128 0.354 BF
#   24 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
#   25 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   26 route  24 		                           ->   52 x  52 x 256
#   27 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   28 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   29 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   31 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   32 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   34 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   35 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   37 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   38 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   39 Shortcut Layer: 36,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   40 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   41 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   42 Shortcut Layer: 39,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   43 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   44 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   45 Shortcut Layer: 42,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   46 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   47 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   48 Shortcut Layer: 45,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   49 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   50 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   51 Shortcut Layer: 48,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   52 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   53 route  52 25 	                           ->   52 x  52 x 256
#   54 conv    256       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 256 0.354 BF
#   55 conv    512       3 x 3/ 2     52 x  52 x 256 ->   26 x  26 x 512 1.595 BF
#   56 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   57 route  55 		                           ->   26 x  26 x 512
#   58 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   59 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   60 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   62 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   63 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   64 Shortcut Layer: 61,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   65 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   66 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   67 Shortcut Layer: 64,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   68 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   69 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   70 Shortcut Layer: 67,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   71 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   72 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   73 Shortcut Layer: 70,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   74 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   75 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   76 Shortcut Layer: 73,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   77 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   78 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   79 Shortcut Layer: 76,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   80 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   81 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   82 Shortcut Layer: 79,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   83 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   84 route  83 56 	                           ->   26 x  26 x 512
#   85 conv    512       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 512 0.354 BF
#   86 conv   1024       3 x 3/ 2     26 x  26 x 512 ->   13 x  13 x1024 1.595 BF
#   87 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   88 route  86 		                           ->   13 x  13 x1024
#   89 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   90 conv    512       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.089 BF
#   91 conv    512       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.797 BF
#   92 Shortcut Layer: 89,  wt = 0, wn = 0, outputs:  13 x  13 x 512 0.000 BF
#   93 conv    512       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.089 BF
#   94 conv    512       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.797 BF
#   95 Shortcut Layer: 92,  wt = 0, wn = 0, outputs:  13 x  13 x 512 0.000 BF
#   96 conv    512       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.089 BF
#   97 conv    512       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.797 BF
#   98 Shortcut Layer: 95,  wt = 0, wn = 0, outputs:  13 x  13 x 512 0.000 BF
#   99 conv    512       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.089 BF
#  100 conv    512       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.797 BF
#  101 Shortcut Layer: 98,  wt = 0, wn = 0, outputs:  13 x  13 x 512 0.000 BF
#  102 conv    512       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.089 BF
#  103 route  102 87 	                           ->   13 x  13 x1024
#  104 conv   1024       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x1024 0.354 BF
#  105 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  106 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#  107 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  108 max                5x 5/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.002 BF
#  109 route  107 		                           ->   13 x  13 x 512
#  110 max                9x 9/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.007 BF
#  111 route  107 		                           ->   13 x  13 x 512
#  112 max               13x13/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.015 BF
#  113 route  112 110 108 107 	                   ->   13 x  13 x2048
#  114 conv    512       1 x 1/ 1     13 x  13 x2048 ->   13 x  13 x 512 0.354 BF
#  115 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#  116 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  117 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#  118 upsample                 2x    13 x  13 x 256 ->   26 x  26 x 256
#  119 route  85 		                           ->   26 x  26 x 512
#  120 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  121 route  120 118 	                           ->   26 x  26 x 512
#  122 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  123 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#  124 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  125 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#  126 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  127 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
#  128 upsample                 2x    26 x  26 x 128 ->   52 x  52 x 128
#  129 route  54 		                           ->   52 x  52 x 256
#  130 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  131 route  130 128 	                           ->   52 x  52 x 256
#  132 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  133 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  134 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  135 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  136 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  137 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  138 conv     21       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x  21 0.029 BF
#  139 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.20
# nms_kind: greedynms (1), beta = 0.600000
#  140 route  136 		                           ->   52 x  52 x 128
#  141 conv    256       3 x 3/ 2     52 x  52 x 128 ->   26 x  26 x 256 0.399 BF
#  142 route  141 126 	                           ->   26 x  26 x 512
#  143 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  144 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#  145 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  146 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#  147 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  148 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#  149 conv     21       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x  21 0.015 BF
#  150 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.10
# nms_kind: greedynms (1), beta = 0.600000
#  151 route  147 		                           ->   26 x  26 x 256
#  152 conv    512       3 x 3/ 2     26 x  26 x 256 ->   13 x  13 x 512 0.399 BF
#  153 route  152 116 	                           ->   13 x  13 x1024
#  154 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  155 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#  156 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  157 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#  158 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  159 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#  160 conv     21       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x  21 0.007 BF
#  161 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
# Total BFLOPS 59.570
# avg_outputs = 489910
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from ../training/yolov4-custom_last.weights...
#  seen 64, trained: 531 K-images (8 Kilo-batches_64)
# Done! Loaded 162 layers from weights-file
# Learning Rate: 0.001, Momentum: 0.949, Decay: 0.0005
#  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
# Saving weights to /mydrive/Advanced_AI/yolov4/training/yolov4-custom_final.weights
#  Create 6 permanent cpu-threads
# If you want to train from the beginning, then use flag in the end of training command: -clear

# %%
# !ls -al
# Out:
# total 179732
# drwx------ 2 root root      4096 Aug  6 16:52 3rdparty
# drwx------ 2 root root      4096 Aug  6 16:58 backup
# drwx------ 2 root root      4096 Aug  6 16:52 build
# -rw------- 1 root root     27008 Aug  6 16:52 build.ps1
# drwx------ 2 root root      4096 Aug  6 16:52 cfg
# -rw------- 1 root root     92684 Aug  7 01:04 chart.png
# -rw------- 1 root root     92684 Aug  7 01:04 chart_yolov4-custom.png
# drwx------ 2 root root      4096 Aug  6 16:52 .circleci
# drwx------ 2 root root      4096 Aug  6 16:52 cmake
# -rw------- 1 root root     24576 Aug  6 16:52 CMakeLists.txt
# -rwx------ 1 root root   6587336 Aug  6 17:00 darknet
# -rw------- 1 root root      1406 Aug  6 16:52 DarknetConfig.cmake.in
# -rw------- 1 root root      9469 Aug  6 16:52 darknet_images.py
# -rw------- 1 root root      8207 Aug  6 16:52 darknet.py
# -rw------- 1 root root      6747 Aug  6 16:52 darknet_video.py
# drwx------ 2 root root      4096 Aug  6 16:52 data
# drwx------ 2 root root      4096 Aug  6 16:52 .git
# drwx------ 2 root root      4096 Aug  6 16:52 .github
# -rw------- 1 root root       686 Aug  6 16:52 .gitignore
# -rw------- 1 root root       110 Aug  6 16:52 image_yolov3.sh
# -rw------- 1 root root       110 Aug  6 16:52 image_yolov4.sh
# drwx------ 2 root root      4096 Aug  6 16:52 include
# -rw------- 1 root root       345 Aug  6 16:52 json_mjpeg_streams.sh
# -rw------- 1 root root   6860400 Aug  6 17:01 libdarknet.so
# -rw------- 1 root root       515 Aug  6 16:52 LICENSE
# -rw------- 1 root root      5961 Aug  6 16:58 Makefile
# -rw------- 1 root root       159 Aug  6 16:52 net_cam_v3.sh
# -rw------- 1 root root       159 Aug  6 16:52 net_cam_v4.sh
# drwx------ 2 root root      4096 Aug  6 16:58 obj
# -rw------- 1 root root       892 Aug  6 17:20 process.py
# -rw------- 1 root root     65518 Aug  6 16:52 README.md
# drwx------ 2 root root      4096 Aug  6 16:52 results
# drwx------ 2 root root      4096 Aug  6 16:52 scripts
# drwx------ 2 root root      4096 Aug  6 16:52 src
# -rw------- 1 root root      5865 Aug  6 16:52 .travis.yml
# -rw------- 1 root root    147624 Aug  6 17:01 uselib
# -rw------- 1 root root      2609 Aug  6 16:52 vcpkg.json
# -rw------- 1 root root       108 Aug  6 16:52 video_yolov3.sh
# -rw------- 1 root root       108 Aug  6 16:52 video_yolov4.sh
# -rw------- 1 root root 170038676 Apr 27  2020 yolov4.conv.137

# %% [markdown]
# ## 학습된 weight파일을 테스트해보자

# %% [markdown]
# ### 학습에 맞춰 설정했던 설정을 테스트 조건으로 변경하자.

# %%
# %cd cfg
# !sed -i 's/batch=64/batch=1/' yolov4-custom.cfg
# !sed -i 's/subdivisions=16/subdivisions=1/' yolov4-custom.cfg
# %cd ..
# Out:
# /content/drive/MyDrive/Advanced_AI/yolov4/darknet/cfg
# /content/drive/My Drive/Advanced_AI/yolov4/darknet

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Advanced_AI/yolov4/darknet

# %%
# %cd /mydrive/Advanced_AI/yolov4/darknet/
# Out:
# /content/drive/MyDrive/Advanced_AI/yolov4/darknet

# %%
# weight파일 복사 (구글 드라이브에서 colab서버로 파일을 가져오기) (원래는 best인데유ㅠㅠㅠ)
# !cp /mydrive/Advanced_AI/yolov4/training/yolov4-custom_best.weights weights/

# %%
# !./darknet detector test data/custom.data cfg/yolov4-custom.cfg weights/yolov4-custom_best.weights /mydrive/Advanced_AI/mask_test_images/image1.jpg -thresh 0.5
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    8 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    9 route  8 2 	                           ->  208 x 208 x 128
#   10 conv     64       1 x 1/ 1    208 x 208 x 128 ->  208 x 208 x  64 0.709 BF
#   11 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#   12 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   13 route  11 		                           ->  104 x 104 x 128
#   14 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   15 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#   16 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#   17 Shortcut Layer: 14,  wt = 0, wn = 0, outputs: 104 x 104 x  64 0.001 BF
#   18 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#   19 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#   20 Shortcut Layer: 17,  wt = 0, wn = 0, outputs: 104 x 104 x  64 0.001 BF
#   21 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#   22 route  21 12 	                           ->  104 x 104 x 128
#   23 conv    128       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x 128 0.354 BF
#   24 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
#   25 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   26 route  24 		                           ->   52 x  52 x 256
#   27 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   28 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   29 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   31 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   32 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   34 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   35 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   37 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   38 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   39 Shortcut Layer: 36,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   40 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   41 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   42 Shortcut Layer: 39,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   43 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   44 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   45 Shortcut Layer: 42,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   46 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   47 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   48 Shortcut Layer: 45,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   49 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   50 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   51 Shortcut Layer: 48,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   52 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   53 route  52 25 	                           ->   52 x  52 x 256
#   54 conv    256       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 256 0.354 BF
#   55 conv    512       3 x 3/ 2     52 x  52 x 256 ->   26 x  26 x 512 1.595 BF
#   56 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   57 route  55 		                           ->   26 x  26 x 512
#   58 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   59 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   60 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   62 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   63 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   64 Shortcut Layer: 61,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   65 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   66 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   67 Shortcut Layer: 64,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   68 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   69 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   70 Shortcut Layer: 67,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   71 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   72 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   73 Shortcut Layer: 70,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   74 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   75 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   76 Shortcut Layer: 73,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   77 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   78 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   79 Shortcut Layer: 76,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   80 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   81 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   82 Shortcut Layer: 79,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   83 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   84 route  83 56 	                           ->   26 x  26 x 512
#   85 conv    512       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 512 0.354 BF
#   86 conv   1024       3 x 3/ 2     26 x  26 x 512 ->   13 x  13 x1024 1.595 BF
#   87 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   88 route  86 		                           ->   13 x  13 x1024
#   89 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   90 conv    512       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.089 BF
#   91 conv    512       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.797 BF
#   92 Shortcut Layer: 89,  wt = 0, wn = 0, outputs:  13 x  13 x 512 0.000 BF
#   93 conv    512       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.089 BF
#   94 conv    512       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.797 BF
#   95 Shortcut Layer: 92,  wt = 0, wn = 0, outputs:  13 x  13 x 512 0.000 BF
#   96 conv    512       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.089 BF
#   97 conv    512       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.797 BF
#   98 Shortcut Layer: 95,  wt = 0, wn = 0, outputs:  13 x  13 x 512 0.000 BF
#   99 conv    512       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.089 BF
#  100 conv    512       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.797 BF
#  101 Shortcut Layer: 98,  wt = 0, wn = 0, outputs:  13 x  13 x 512 0.000 BF
#  102 conv    512       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.089 BF
#  103 route  102 87 	                           ->   13 x  13 x1024
#  104 conv   1024       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x1024 0.354 BF
#  105 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  106 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#  107 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  108 max                5x 5/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.002 BF
#  109 route  107 		                           ->   13 x  13 x 512
#  110 max                9x 9/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.007 BF
#  111 route  107 		                           ->   13 x  13 x 512
#  112 max               13x13/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.015 BF
#  113 route  112 110 108 107 	                   ->   13 x  13 x2048
#  114 conv    512       1 x 1/ 1     13 x  13 x2048 ->   13 x  13 x 512 0.354 BF
#  115 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#  116 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  117 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#  118 upsample                 2x    13 x  13 x 256 ->   26 x  26 x 256
#  119 route  85 		                           ->   26 x  26 x 512
#  120 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  121 route  120 118 	                           ->   26 x  26 x 512
#  122 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  123 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#  124 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  125 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#  126 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  127 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
#  128 upsample                 2x    26 x  26 x 128 ->   52 x  52 x 128
#  129 route  54 		                           ->   52 x  52 x 256
#  130 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  131 route  130 128 	                           ->   52 x  52 x 256
#  132 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  133 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  134 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  135 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  136 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  137 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  138 conv     21       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x  21 0.029 BF
#  139 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.20
# nms_kind: greedynms (1), beta = 0.600000
#  140 route  136 		                           ->   52 x  52 x 128
#  141 conv    256       3 x 3/ 2     52 x  52 x 128 ->   26 x  26 x 256 0.399 BF
#  142 route  141 126 	                           ->   26 x  26 x 512
#  143 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  144 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#  145 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  146 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#  147 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  148 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#  149 conv     21       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x  21 0.015 BF
#  150 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.10
# nms_kind: greedynms (1), beta = 0.600000
#  151 route  147 		                           ->   26 x  26 x 256
#  152 conv    512       3 x 3/ 2     26 x  26 x 256 ->   13 x  13 x 512 0.399 BF
#  153 route  152 116 	                           ->   13 x  13 x1024
#  154 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  155 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#  156 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  157 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#  158 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  159 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#  160 conv     21       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x  21 0.007 BF
#  161 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
# Total BFLOPS 59.570
# avg_outputs = 489910
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from weights/yolov4-custom_best.weights...
#  seen 64, trained: 448 K-images (7 Kilo-batches_64)
# Done! Loaded 162 layers from weights-file
#  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
# /mydrive/Advanced_AI/mask_test_images/image1.jpg: Predicted in 20.325000 milli-seconds.
# with_mask: 86%
# Unable to init server: Could not connect: Connection refused
#
# (predictions:1075): Gtk-WARNING **: 02:11:33.127: cannot open display:

# %%
# define helper function imShow
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %%
imShow('predictions.jpg')

# %% [markdown]
# ### PC의 웹캠을 연결하고 웹캡의 영상을 colab으로 전송하여 사진을 촬영하고, 결과를 확인해보자.

# %%
#run detector on images captured by webcam for your custom YOLOv4 trained model
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# Saved to photo.jpg

# %%
# !pwd
# Out:
# /content/drive/My Drive/Advanced_AI/yolov4/darknet

# %%
# !./darknet detector test data/custom.data cfg/yolov4-custom.cfg /mydrive/Advanced_AI/yolov4/training/yolov4-custom_best.weights photo.jpg -thresh 0.5
imShow('predictions.jpg')
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    8 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    9 route  8 2 	                           ->  208 x 208 x 128
#   10 conv     64       1 x 1/ 1    208 x 208 x 128 ->  208 x 208 x  64 0.709 BF
#   11 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#   12 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   13 route  11 		                           ->  104 x 104 x 128
#   14 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   15 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#   16 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#   17 Shortcut Layer: 14,  wt = 0, wn = 0, outputs: 104 x 104 x  64 0.001 BF
#   18 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#   19 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#   20 Shortcut Layer: 17,  wt = 0, wn = 0, outputs: 104 x 104 x  64 0.001 BF
#   21 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#   22 route  21 12 	                           ->  104 x 104 x 128
#   23 conv    128       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x 128 0.354 BF
#   24 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
#   25 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   26 route  24 		                           ->   52 x  52 x 256
#   27 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   28 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   29 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   31 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   32 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   34 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   35 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   37 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   38 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   39 Shortcut Layer: 36,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   40 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   41 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   42 Shortcut Layer: 39,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   43 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   44 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   45 Shortcut Layer: 42,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   46 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   47 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   48 Shortcut Layer: 45,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   49 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   50 conv    128       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.797 BF
#   51 Shortcut Layer: 48,  wt = 0, wn = 0, outputs:  52 x  52 x 128 0.000 BF
#   52 conv    128       1 x 1/ 1     52 x  52 x 128 ->   52 x  52 x 128 0.089 BF
#   53 route  52 25 	                           ->   52 x  52 x 256
#   54 conv    256       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 256 0.354 BF
#   55 conv    512       3 x 3/ 2     52 x  52 x 256 ->   26 x  26 x 512 1.595 BF
#   56 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   57 route  55 		                           ->   26 x  26 x 512
#   58 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   59 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   60 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   62 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   63 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   64 Shortcut Layer: 61,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   65 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   66 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   67 Shortcut Layer: 64,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   68 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   69 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   70 Shortcut Layer: 67,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   71 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   72 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   73 Shortcut Layer: 70,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   74 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   75 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   76 Shortcut Layer: 73,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   77 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   78 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   79 Shortcut Layer: 76,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   80 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   81 conv    256       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.797 BF
#   82 Shortcut Layer: 79,  wt = 0, wn = 0, outputs:  26 x  26 x 256 0.000 BF
#   83 conv    256       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 256 0.089 BF
#   84 route  83 56 	                           ->   26 x  26 x 512
#   85 conv    512       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 512 0.354 BF
#   86 conv   1024       3 x 3/ 2     26 x  26 x 512 ->   13 x  13 x1024 1.595 BF
#   87 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   88 route  86 		                           ->   13 x  13 x1024
#   89 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   90 conv    512       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.089 BF
#   91 conv    512       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.797 BF
#   92 Shortcut Layer: 89,  wt = 0, wn = 0, outputs:  13 x  13 x 512 0.000 BF
#   93 conv    512       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.089 BF
#   94 conv    512       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.797 BF
#   95 Shortcut Layer: 92,  wt = 0, wn = 0, outputs:  13 x  13 x 512 0.000 BF
#   96 conv    512       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.089 BF
#   97 conv    512       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.797 BF
#   98 Shortcut Layer: 95,  wt = 0, wn = 0, outputs:  13 x  13 x 512 0.000 BF
#   99 conv    512       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.089 BF
#  100 conv    512       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.797 BF
#  101 Shortcut Layer: 98,  wt = 0, wn = 0, outputs:  13 x  13 x 512 0.000 BF
#  102 conv    512       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.089 BF
#  103 route  102 87 	                           ->   13 x  13 x1024
#  104 conv   1024       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x1024 0.354 BF
#  105 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  106 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#  107 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  108 max                5x 5/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.002 BF
#  109 route  107 		                           ->   13 x  13 x 512
#  110 max                9x 9/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.007 BF
#  111 route  107 		                           ->   13 x  13 x 512
#  112 max               13x13/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.015 BF
#  113 route  112 110 108 107 	                   ->   13 x  13 x2048
#  114 conv    512       1 x 1/ 1     13 x  13 x2048 ->   13 x  13 x 512 0.354 BF
#  115 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#  116 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  117 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#  118 upsample                 2x    13 x  13 x 256 ->   26 x  26 x 256
#  119 route  85 		                           ->   26 x  26 x 512
#  120 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  121 route  120 118 	                           ->   26 x  26 x 512
#  122 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  123 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#  124 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  125 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#  126 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  127 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
#  128 upsample                 2x    26 x  26 x 128 ->   52 x  52 x 128
#  129 route  54 		                           ->   52 x  52 x 256
#  130 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  131 route  130 128 	                           ->   52 x  52 x 256
#  132 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  133 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  134 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  135 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  136 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  137 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  138 conv     24       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x  24 0.033 BF
#  139 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.20
# nms_kind: greedynms (1), beta = 0.600000
#  140 route  136 		                           ->   52 x  52 x 128
#  141 conv    256       3 x 3/ 2     52 x  52 x 128 ->   26 x  26 x 256 0.399 BF
#  142 route  141 126 	                           ->   26 x  26 x 512
#  143 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  144 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#  145 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  146 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#  147 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#  148 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#  149 conv     24       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x  24 0.017 BF
#  150 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.10
# nms_kind: greedynms (1), beta = 0.600000
#  151 route  147 		                           ->   26 x  26 x 256
#  152 conv    512       3 x 3/ 2     26 x  26 x 256 ->   13 x  13 x 512 0.399 BF
#  153 route  152 116 	                           ->   13 x  13 x1024
#  154 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  155 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#  156 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  157 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#  158 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#  159 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#  160 conv     24       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x  24 0.008 BF
#  161 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
# Total BFLOPS 59.578
# avg_outputs = 490041
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from /mydrive/Advanced_AI/yolov4/training/yolov4-custom_best.weights...
#  seen 64, trained: 112 K-images (1 Kilo-batches_64)
# Done! Loaded 162 layers from weights-file
#  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
# photo.jpg: Predicted in 20.358000 milli-seconds.
# scissors: 76%
# Unable to init server: Could not connect: Connection refused
#
# (predictions:2686): Gtk-WARNING **: 04:34:31.043: cannot open display:

# %% [markdown]
# ### 웹캠의 라이브 영상을 사용하여 객체인식하기

# %%
# Code from theAIGuysCode Github (https://github.com/theAIGuysCode/YOLOv4-Cloud-Tutorial/blob/master/yolov4_webcam.ipynb)
# Adjusted for my custom YOLOv4 trained weights, config and obj.data files

# import dependencies
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from google.colab.patches import cv2_imshow
from base64 import b64decode, b64encode
import cv2
import numpy as np
import PIL
import io
import html
import time
import matplotlib.pyplot as plt
# %matplotlib inline


# import darknet functions to perform object detections
from darknet import *
# load in our YOLOv4 architecture network
network, class_names, class_colors = load_network("cfg/yolov4-custom.cfg", "data/custom.data", "/mydrive/Advanced_AI/yolov4/training/yolov4-custom_best.weights")
width = network_width(network)
height = network_height(network)

# darknet helper function to run detection on image
def darknet_helper(img, width, height):
  darknet_image = make_image(width, height, 3)
  img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  img_resized = cv2.resize(img_rgb, (width, height),
                              interpolation=cv2.INTER_LINEAR)

  # get image ratios to convert bounding boxes to proper size
  img_height, img_width, _ = img.shape
  width_ratio = img_width/width
  height_ratio = img_height/height

  # run model on darknet style image to get detections
  copy_image_from_bytes(darknet_image, img_resized.tobytes())
  detections = detect_image(network, class_names, darknet_image)
  free_image(darknet_image)
  return detections, width_ratio, height_ratio

# function to convert the JavaScript object into an OpenCV image
def js_to_image(js_reply):
  """
  Params:
          js_reply: JavaScript object containing image from webcam
  Returns:
          img: OpenCV BGR image
  """
  # decode base64 image
  image_bytes = b64decode(js_reply.split(',')[1])
  # convert bytes to numpy array
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  # decode numpy array into OpenCV BGR image
  img = cv2.imdecode(jpg_as_np, flags=1)

  return img

# function to convert OpenCV Rectangle bounding box image into base64 byte string to be overlayed on video stream
def bbox_to_bytes(bbox_array):
  """
  Params:
          bbox_array: Numpy array (pixels) containing rectangle to overlay on video stream.
  Returns:
        bytes: Base64 image byte string
  """
  # convert array into PIL image
  bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
  iobuf = io.BytesIO()
  # format bbox into png for return
  bbox_PIL.save(iobuf, format='png')
  # format return string
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64encode(iobuf.getvalue()), 'utf-8')))

  return bbox_bytes  

# JavaScript to properly create our live video stream using our webcam as input
def video_stream():
  js = Javascript('''
    var video;
    var div = null;
    var stream;
    var captureCanvas;
    var imgElement;
    var labelElement;
    
    var pendingResolve = null;
    var shutdown = false;
    
    function removeDom() {
       stream.getVideoTracks()[0].stop();
       video.remove();
       div.remove();
       video = null;
       div = null;
       stream = null;
       imgElement = null;
       captureCanvas = null;
       labelElement = null;
    }
    
    function onAnimationFrame() {
      if (!shutdown) {
        window.requestAnimationFrame(onAnimationFrame);
      }
      if (pendingResolve) {
        var result = "";
        if (!shutdown) {
          captureCanvas.getContext('2d').drawImage(video, 0, 0, 640, 480);
          result = captureCanvas.toDataURL('image/jpeg', 0.8)
        }
        var lp = pendingResolve;
        pendingResolve = null;
        lp(result);
      }
    }
    
    async function createDom() {
      if (div !== null) {
        return stream;
      }

      div = document.createElement('div');
      div.style.border = '2px solid black';
      div.style.padding = '3px';
      div.style.width = '100%';
      div.style.maxWidth = '600px';
      document.body.appendChild(div);
      
      const modelOut = document.createElement('div');
      modelOut.innerHTML = "<span>Status:</span>";
      labelElement = document.createElement('span');
      labelElement.innerText = 'No data';
      labelElement.style.fontWeight = 'bold';
      modelOut.appendChild(labelElement);
      div.appendChild(modelOut);
           
      video = document.createElement('video');
      video.style.display = 'block';
      video.width = div.clientWidth - 6;
      video.setAttribute('playsinline', '');
      video.onclick = () => { shutdown = true; };
      stream = await navigator.mediaDevices.getUserMedia(
          {video: { facingMode: "environment"}});
      div.appendChild(video);

      imgElement = document.createElement('img');
      imgElement.style.position = 'absolute';
      imgElement.style.zIndex = 1;
      imgElement.onclick = () => { shutdown = true; };
      div.appendChild(imgElement);
      
      const instruction = document.createElement('div');
      instruction.innerHTML = 
          '<span style="color: red; font-weight: bold;">' +
          'When finished, click here or on the video to stop this demo</span>';
      div.appendChild(instruction);
      instruction.onclick = () => { shutdown = true; };
      
      video.srcObject = stream;
      await video.play();

      captureCanvas = document.createElement('canvas');
      captureCanvas.width = 640; //video.videoWidth;
      captureCanvas.height = 480; //video.videoHeight;
      window.requestAnimationFrame(onAnimationFrame);
      
      return stream;
    }
    async function stream_frame(label, imgData) {
      if (shutdown) {
        removeDom();
        shutdown = false;
        return '';
      }

      var preCreate = Date.now();
      stream = await createDom();
      
      var preShow = Date.now();
      if (label != "") {
        labelElement.innerHTML = label;
      }
            
      if (imgData != "") {
        var videoRect = video.getClientRects()[0];
        imgElement.style.top = videoRect.top + "px";
        imgElement.style.left = videoRect.left + "px";
        imgElement.style.width = videoRect.width + "px";
        imgElement.style.height = videoRect.height + "px";
        imgElement.src = imgData;
      }
      
      var preCapture = Date.now();
      var result = await new Promise(function(resolve, reject) {
        pendingResolve = resolve;
      });
      shutdown = false;
      
      return {'create': preShow - preCreate, 
              'show': preCapture - preShow, 
              'capture': Date.now() - preCapture,
              'img': result};
    }
    ''')

  display(js)
  
def video_frame(label, bbox):
  data = eval_js('stream_frame("{}", "{}")'.format(label, bbox))
  return data

# start streaming video from webcam
video_stream()
# label for video
label_html = 'Capturing...'
# initialze bounding box to empty
bbox = ''
count = 0 
while True:
    js_reply = video_frame(label_html, bbox)
    if not js_reply:
        break

    # convert JS response to OpenCV Image
    frame = js_to_image(js_reply["img"])

    # create transparent overlay for bounding box
    bbox_array = np.zeros([480,640,4], dtype=np.uint8)

    # call our darknet helper on video frame
    detections, width_ratio, height_ratio = darknet_helper(frame, width, height)

    # loop through detections and draw them on transparent overlay image
    for label, confidence, bbox in detections:
      left, top, right, bottom = bbox2points(bbox)
      left, top, right, bottom = int(left * width_ratio), int(top * height_ratio), int(right * width_ratio), int(bottom * height_ratio)
      bbox_array = cv2.rectangle(bbox_array, (left, top), (right, bottom), class_colors[label], 2)
      bbox_array = cv2.putText(bbox_array, "{} [{:.2f}]".format(label, float(confidence)),
                        (left, top - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                        class_colors[label], 2)

    bbox_array[:,:,3] = (bbox_array.max(axis = 2) > 0 ).astype(int) * 255
    # convert overlay of bbox into bytes
    bbox_bytes = bbox_to_bytes(bbox_array)
    # update bbox so next frame gets new overlay
    bbox = bbox_bytes

# %% [markdown]
# 참조사이트
# https://github.com/techzizou/yolov4-custom_Training

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/Advanced_AI/yolov4/darknet
